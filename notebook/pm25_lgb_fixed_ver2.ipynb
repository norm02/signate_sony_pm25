# %%
#sub46のnotebook

# %%
#!pip install optuna

# %%
# !pip install git+https://github.com/Yoshiki443/weather_parameters
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting git+https://github.com/Yoshiki443/weather_parameters
#   Cloning https://github.com/Yoshiki443/weather_parameters to /tmp/pip-req-build-5dvhkztw
#   Running command git clone -q https://github.com/Yoshiki443/weather_parameters /tmp/pip-req-build-5dvhkztw
# Building wheels for collected packages: wxparams
#   Building wheel for wxparams (setup.py) ... done
#   Created wheel for wxparams: filename=wxparams-1.5-py3-none-any.whl size=5346 sha256=b3bef3f401c36d8f523ce98594275783a60f3cd2bcc15dd9450c828078018b3e
#   Stored in directory: /tmp/pip-ephem-wheel-cache-s5004n1l/wheels/68/a0/d6/34526425f91c7ff8f31348ce51462a23d0399e4e4541704723
# Successfully built wxparams
# Installing collected packages: wxparams
# Successfully installed wxparams-1.5

# %%
class config:
    run_type = 'colab'
    random_seed = 2022
    nfold = 5
    target = 'pm25_mid'

# %%
import os
import re
from IPython.lib import kernel
from requests import get

if config.run_type == 'colab':
    from google.colab import drive, files
    
    drive.mount('/content/drive')
    #ご自身のフォルダパスを指定
    Drive = "/content/drive/My Drive/python/sony/"
    Exp = get('http://172.28.0.2:9000/api/sessions').json()[0]['name'][:-6]
    Exp = re.sub('.ip', '', Exp)
        
Input = os.path.join(Drive, 'input')
Output = os.path.join(Drive, 'output')
Output_Exp = os.path.join(Output, Exp)
Output_Model = os.path.join(Output_Exp, "model")
Output_Preds = os.path.join(Output_Exp, "preds")
Output_Feats = os.path.join(Output_Exp, "feats")

Submission = os.path.join(Drive, "submission")

dirs = [Output_Model, Output_Preds, Output_Feats]
for d in dirs:
    if not os.path.isdir(d):
        os.makedirs(d, exist_ok=True)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import joblib
import gc
from scipy.spatial.distance import pdist
from scipy.spatial.distance import squareform
import datetime

from sklearn.model_selection import KFold, GroupKFold
from sklearn.metrics import mean_squared_error

import lightgbm as lgb
#import optuna.integration.lightgbm as opt_lgb

pd.set_option('max_rows', 400)
pd.set_option('max_columns', 100)

# %%
train_data = pd.read_csv(os.path.join(Input, 'train.csv'))\
               .assign(timestamp=lambda d: pd.to_datetime(d['year'].astype(str) + '-' + d['month'].astype(str) + '-' + d['day'].astype(str)))
test_data = pd.read_csv(os.path.join(Input, 'test.csv'))\
               .assign(timestamp=lambda d: pd.to_datetime(d['year'].astype(str) + '-' + d['month'].astype(str) + '-' + d['day'].astype(str)))

# %%
def make_corr_array(df, cols):
    output = pd.DataFrame(1 - squareform(pdist(df[cols].T, 'correlation')),
                          columns=cols, index=cols)
    return output

# %%
corr_df = make_corr_array(train_data, [c for c in train_data.columns if re.search(r'mid|min|max|cnt|var|lat|lon', c)])

# %%
corr_top10 = corr_df.loc[:, ['pm25_mid']].assign(abs_value=lambda d: np.abs(d['pm25_mid']))\
                    .sort_values('abs_value', ascending=False)\
                    .iloc[1:11, :].index.tolist()

# %%
class AbstractBaseBlock:
    def fit(self, input_df: pd.DataFrame, y=None):
        return self.transform(input_df)
    
    def transform(self, input_df: pd.DataFrame) -> pd.DataFrame:
        raise NotImplementedError()

# %%
class NumericFeatBlock(AbstractBaseBlock):
    def __init__(self, col: str):
        self.col = col
        
    def fit(self, input_df, y=None):
        pass
        
    def transform(self, input_df):
        return input_df.loc[:, self.col]

# %%
class CategoricalFeatBlock(AbstractBaseBlock):
    def __init__(self, col: str, whole_df = None, threshold=0.001, is_label=True, is_dummy=False):
        self.col = col
        self.whole_df = whole_df
        self.threshold = threshold
        self.is_label = is_label
        self.is_dummy = is_dummy
    
    def fit(self, input_df, y=None):
        if self.whole_df == None:
            df = input_df.loc[:, self.col]
        else:
            df = self.whole_df.loc[:, self.col]
        vc = df.value_counts(normalize=True).reset_index()
        vc = vc.assign(thresh=lambda d: np.where(d[self.col].values >= self.threshold, 1, 0))\
               .assign(thresh=lambda d: d['thresh'].cumsum() - d['thresh'])
        self.label_dict_ = dict(vc[['index', 'thresh']].values)
        self.label_other_ = np.max(self.label_dict_.values())
        
        return self.transform(input_df)
        
    def transform(self, input_df):
        out_df = pd.DataFrame()
        label_df = pd.DataFrame()
        label_df[f'{self.col}_label_enc'] = np.vectorize(lambda x: self.label_dict_.get(x, self.label_other_))\
                                                        (input_df[self.col].values)
        if self.is_label:
            out_df = pd.concat([out_df, label_df], axis=1)
            
        if self.is_dummy:
            label_df[f'{self.col}_label_enc'] = label_df[f'{self.col}_label_enc'].astype(object)
            out_df = pd.concat([out_df, pd.get_dummies(label_df)], axis=1)
        
        return out_df

# %%
class DateFeatureBlock(AbstractBaseBlock):
    def __init__(self, is_get_weekday=True):
        self.is_get_weekday = is_get_weekday
        
    def fit(self, input_df, y=None):
        pass
        
    def transform(self, input_df):
        out_df = pd.DataFrame()
        out_df = input_df[['year', 'month', 'day']]
        if self.is_get_weekday:
            out_df = out_df.assign(weekday=[x.dayofweek for x in input_df['timestamp'].tolist()])
        
        return out_df

# %%
class AggregateValueBlock(AbstractBaseBlock):
    def __init__(self, key_col, agg_dict, whole_df=None):
        self.key_col = key_col
        self.agg_dict = agg_dict
        self.whole_df = whole_df
        
    def fit(self, input_df, y=None):
        if self.whole_df == None:
            df = input_df
        else:
            df = self.whole_df
        agg_df = df.groupby(self.key_col).agg(self.agg_dict)
        agg_df.columns = ['_'.join(c) for c in agg_df.columns]
        self.agg_df_ = agg_df.add_prefix('_')\
                             .add_prefix('_'.join(self.key_col))\
                             .add_prefix('agg_').reset_index()
        
        return self.transform(input_df)
    
    def transform(self, input_df):
        out_df = pd.DataFrame()
        out_df = pd.merge(input_df[self.key_col], self.agg_df_, how='left', on=self.key_col)\
                   .drop(self.key_col, axis=1)\
                   .fillna(0)
        
        return out_df

# %%
numeric_columns = [c for c in train_data.columns if re.search(r'max|mid|min|cnt|var|lat|lon', c) and not re.search(r'pm25', c)]
categorical_columns = ['Country']
agg_country_value = dict([(c, [np.mean, np.max, np.min, np.std, np.var]) for c in corr_top10])

# %%
run_blocks = [
    *[NumericFeatBlock(c) for c in [numeric_columns]],
    *[CategoricalFeatBlock(c) for c in categorical_columns],
    *[DateFeatureBlock()],
    *[AggregateValueBlock(['Country', 'month'], agg_country_value)],    
]

# %%
def get_train_data(input_df, feat_blocks, y=None, fit_df=None):
    if fit_df is None:
        fit_df = input_df.copy()
        
    for block in feat_blocks:
        block.fit(fit_df, y)
        
    out = [block.transform(input_df) for block in feat_blocks]
    out = pd.concat(out, axis=1)
    
    return out

def get_test_data(input_df, feat_blocks):
    
    out = [block.transform(input_df) for block in feat_blocks]
    out = pd.concat(out, axis=1)
    
    return out

# %%
df_train = get_train_data(train_data, run_blocks, fit_df=pd.concat([train_data, test_data], ignore_index=True))
df_train
# Out:
#              lat        lon  co_cnt  co_min  co_mid  co_max  co_var  o3_cnt  \
# 0      -27.46794  153.02809      38   0.749   2.590   2.633   0.850      29
# 1      -12.46113  130.84185      47   2.594   3.181   4.828   1.208      49
# 2      -37.81400  144.96332      17   1.190   1.197   2.200   0.248     123
# 3      -32.92953  151.78010      63   4.586  11.044  14.802  24.186      90
# 4      -31.95224  115.86140      47   4.689   8.681  11.100  10.011      83
# ...          ...        ...     ...     ...     ...     ...     ...     ...
# 195936  30.33218  -81.65565      12   0.694   0.995   1.301   0.090      26
# 195937  36.17497 -115.13722      14   0.528   1.256   3.226   1.743       8
# 195938  43.03890  -87.90647     171   1.975   6.627   6.639   5.293     112
# 195939  21.02450  105.84117      31   2.613   2.704   8.767   4.317     108
# 195940  20.95045  107.07336      26   0.069   0.120   0.184   0.003      20
#
#         o3_min  o3_mid  o3_max   o3_var  so2_cnt  so2_min  so2_mid  so2_max  \
# 0        2.397   4.295   5.916    3.017       11    0.149    0.468    0.900
# 1        3.092   7.572  12.332   20.524       31    0.096    0.102   16.152
# 2        0.736  12.527  23.432  125.224       36    1.392    1.464   47.652
# 3        1.917  14.141  38.374  304.731       50    2.957    3.230   14.056
# 4        0.349   2.349  38.600  353.549       47    0.422    5.794    9.972
# ...        ...     ...     ...      ...      ...      ...      ...      ...
# 195936   6.859   9.295  25.886   87.688        8    0.257    1.088    1.511
# 195937   4.435   7.450  23.110   84.730        9    0.288    0.671    1.292
# 195938   4.613   7.397  37.550   71.355      120    0.420    2.915    6.504
# 195939  12.694  15.474  37.831  149.726       27    0.702    2.538    4.193
# 195940   3.119   3.140  27.941  147.380       10    0.676    0.841    0.890
#
#         so2_var  no2_cnt  no2_min  no2_mid  no2_max  no2_var  temperature_cnt  \
# 0         0.137       36    0.000    0.529    2.188    1.167               36
# 1        61.550       45    0.099    0.301    5.411    6.401               71
# 2       515.570      111    0.972    2.751   12.230   30.518              148
# 3        25.630      176   14.959   17.471   24.221   20.883              101
# 4         9.234       80   14.911   21.140   32.584   74.298               55
# ...         ...      ...      ...      ...      ...      ...              ...
# 195936    0.376       26    0.000    1.071    1.148    0.180               40
# 195937    0.241       31    0.674    1.176    6.967    5.398               51
# 195938    4.479       66    2.668    4.844   34.490  141.786              170
# 195939    2.884      149    1.986    6.741   26.674  143.871              290
# 195940    0.011       51    0.885   12.055   25.679  149.594               55
#
#         temperature_min  temperature_mid  temperature_max  temperature_var  \
# 0                10.956           14.038           20.866           23.880
# 1                24.113           30.125           36.678           37.327
# 2                 0.000            0.000           23.226          131.280
# 3                16.423           19.819           20.044            3.188
# 4                10.297           11.822           13.377            2.311
# ...                 ...              ...              ...              ...
# 195936           22.355           27.235           28.335            8.710
# 195937           12.548           18.251           27.369           52.741
# 195938            1.574            5.054           15.515           45.069
# 195939            4.288            5.839           18.179           20.939
# 195940           19.866           24.896           27.725           15.020
#
#         humidity_cnt  humidity_min  humidity_mid  humidity_max  humidity_var  \
# 0                 45        30.207        70.426        94.202       994.051
# 1                 50        49.034        74.276        92.975       467.112
# 2                138        25.919        69.069       100.000      1292.191
# 3                111        73.504        86.920       100.000        85.028
# 4                155        51.918        76.736        96.533       484.188
# ...              ...           ...           ...           ...           ...
# 195936            48        58.021        88.372        99.875       425.264
# 195937            55        26.446        48.434        84.894       817.475
# 195938            91        48.625        75.506        80.429       245.963
# 195939           260        74.620        78.477        92.574        78.444
# 195940            71        73.216        83.655        99.708       162.663
#
#         pressure_cnt  pressure_min  pressure_mid  pressure_max  pressure_var  \
# 0                 59      1004.137      1015.721      1023.398        89.588
# 1                 69       938.085       970.252      1080.000         7.320
# 2                153       880.000       880.000      1018.200      4655.348
# 3                141      1011.703      1016.545      1018.364        10.898
# 4                124      1019.521      1022.992      1027.611        15.142
# ...              ...           ...           ...           ...           ...
# 195936            55      1006.476      1008.095      1016.593        17.690
# 195937            67      1001.251      1014.241      1016.000        26.348
# 195938           194      1014.899      1028.344      1028.429         9.313
# 195939           293      1013.957      1027.707      1034.228        25.054
# 195940            70      1008.326      1019.149      1021.731        42.129
#
#         ws_cnt  ws_min  ws_mid  ws_max  ws_var  dew_cnt  dew_min  dew_mid  \
# 0           42   0.241   1.088   3.101   1.983       17    7.671   10.358
# 1           48   0.828   3.473   7.396  10.411       62   21.324   23.813
# 2          125   0.000   2.107   8.089  15.719       22   10.309   13.133
# 3           52   0.284   0.503   3.592   2.485      116    7.146   10.685
# 4          102   0.500   0.755   3.396   1.937       93    1.091    3.277
# ...        ...     ...     ...     ...     ...      ...      ...      ...
# 195936      22   2.195   2.710   6.125   3.757       12   16.774   22.679
# 195937      51   1.002   2.974   6.861   8.354       12   10.432   14.741
# 195938     125   0.994   1.087   2.578   0.612       26    2.049    3.531
# 195939     266   1.005   3.058   6.005   6.085       51    1.922    7.443
# 195940      32   0.190   2.775   3.412   2.528       16    8.448   10.372
#
#         dew_max  dew_var  Country_label_enc  year  month  ...  \
# 0        15.112   13.424                 10  2019      1  ...
# 1        24.221    2.021                 10  2019      1  ...
# 2        15.422    6.355                 10  2019      1  ...
# 3        13.344    9.417                 10  2019      1  ...
# 4        12.272    4.109                 10  2019      1  ...
# ...         ...      ...                ...   ...    ...  ...
# 195936   26.058   13.252                  5  2021     12  ...
# 195937   15.827    7.078                  5  2021     12  ...
# 195938    6.686    5.286                  5  2021     12  ...
# 195939    7.716    4.642                 22  2021     12  ...
# 195940   18.886   11.536                 22  2021     12  ...
#
#         agg_Country_month_no2_mid_mean  agg_Country_month_no2_mid_amax  \
# 0                             6.669456                          38.018
# 1                             6.669456                          38.018
# 2                             6.669456                          38.018
# 3                             6.669456                          38.018
# 4                             6.669456                          38.018
# ...                                ...                             ...
# 195936                       10.352565                          49.931
# 195937                       10.352565                          49.931
# 195938                       10.352565                          49.931
# 195939                       11.745539                          32.873
# 195940                       11.745539                          32.873
#
#         agg_Country_month_no2_mid_amin  agg_Country_month_no2_mid_std  \
# 0                                0.095                       6.389357
# 1                                0.095                       6.389357
# 2                                0.095                       6.389357
# 3                                0.095                       6.389357
# 4                                0.095                       6.389357
# ...                                ...                            ...
# 195936                           0.604                       7.073820
# 195937                           0.604                       7.073820
# 195938                           0.604                       7.073820
# 195939                           0.408                       6.495702
# 195940                           0.408                       6.495702
#
#         agg_Country_month_no2_mid_var  agg_Country_month_co_mid_mean  \
# 0                           40.823877                       3.256152
# 1                           40.823877                       3.256152
# 2                           40.823877                       3.256152
# 3                           40.823877                       3.256152
# 4                           40.823877                       3.256152
# ...                               ...                            ...
# 195936                      50.038926                       3.561830
# 195937                      50.038926                       3.561830
# 195938                      50.038926                       3.561830
# 195939                      42.194143                       4.323143
# 195940                      42.194143                       4.323143
#
#         agg_Country_month_co_mid_amax  agg_Country_month_co_mid_amin  \
# 0                              20.272                          0.040
# 1                              20.272                          0.040
# 2                              20.272                          0.040
# 3                              20.272                          0.040
# 4                              20.272                          0.040
# ...                               ...                            ...
# 195936                         18.567                          0.025
# 195937                         18.567                          0.025
# 195938                         18.567                          0.025
# 195939                         12.386                          0.053
# 195940                         12.386                          0.053
#
#         agg_Country_month_co_mid_std  agg_Country_month_co_mid_var  \
# 0                           3.104306                      9.636714
# 1                           3.104306                      9.636714
# 2                           3.104306                      9.636714
# 3                           3.104306                      9.636714
# 4                           3.104306                      9.636714
# ...                              ...                           ...
# 195936                      2.420175                      5.857249
# 195937                      2.420175                      5.857249
# 195938                      2.420175                      5.857249
# 195939                      3.063893                      9.387442
# 195940                      3.063893                      9.387442
#
#         agg_Country_month_no2_max_mean  agg_Country_month_no2_max_amax  \
# 0                            17.718835                          67.282
# 1                            17.718835                          67.282
# 2                            17.718835                          67.282
# 3                            17.718835                          67.282
# 4                            17.718835                          67.282
# ...                                ...                             ...
# 195936                       26.174598                          97.749
# 195937                       26.174598                          97.749
# 195938                       26.174598                          97.749
# 195939                       32.203755                         107.800
# 195940                       32.203755                         107.800
#
#         agg_Country_month_no2_max_amin  agg_Country_month_no2_max_std  \
# 0                                0.096                      13.110455
# 1                                0.096                      13.110455
# 2                                0.096                      13.110455
# 3                                0.096                      13.110455
# 4                                0.096                      13.110455
# ...                                ...                            ...
# 195936                           1.148                      13.972281
# 195937                           1.148                      13.972281
# 195938                           1.148                      13.972281
# 195939                           2.377                      19.022846
# 195940                           2.377                      19.022846
#
#         agg_Country_month_no2_max_var  agg_Country_month_no2_min_mean  \
# 0                          171.884028                        2.492414
# 1                          171.884028                        2.492414
# 2                          171.884028                        2.492414
# 3                          171.884028                        2.492414
# 4                          171.884028                        2.492414
# ...                               ...                             ...
# 195936                     195.224646                        3.210986
# 195937                     195.224646                        3.210986
# 195938                     195.224646                        3.210986
# 195939                     361.868687                        4.322363
# 195940                     361.868687                        4.322363
#
#         agg_Country_month_no2_min_amax  agg_Country_month_no2_min_amin  \
# 0                               17.962                           0.000
# 1                               17.962                           0.000
# 2                               17.962                           0.000
# 3                               17.962                           0.000
# 4                               17.962                           0.000
# ...                                ...                             ...
# 195936                          31.114                           0.000
# 195937                          31.114                           0.000
# 195938                          31.114                           0.000
# 195939                          16.456                           0.284
# 195940                          16.456                           0.284
#
#         agg_Country_month_no2_min_std  agg_Country_month_no2_min_var  \
# 0                            3.422229                      11.711652
# 1                            3.422229                      11.711652
# 2                            3.422229                      11.711652
# 3                            3.422229                      11.711652
# 4                            3.422229                      11.711652
# ...                               ...                            ...
# 195936                       3.068996                       9.418738
# 195937                       3.068996                       9.418738
# 195938                       3.068996                       9.418738
# 195939                       3.375140                      11.391571
# 195940                       3.375140                      11.391571
#
#         agg_Country_month_co_max_mean  agg_Country_month_co_max_amax  \
# 0                            6.240017                         42.192
# 1                            6.240017                         42.192
# 2                            6.240017                         42.192
# 3                            6.240017                         42.192
# 4                            6.240017                         42.192
# ...                               ...                            ...
# 195936                       8.477598                         44.428
# 195937                       8.477598                         44.428
# 195938                       8.477598                         44.428
# 195939                      12.485510                         60.046
# 195940                      12.485510                         60.046
#
#         agg_Country_month_co_max_amin  agg_Country_month_co_max_std  \
# 0                               0.069                      5.745370
# 1                               0.069                      5.745370
# 2                               0.069                      5.745370
# 3                               0.069                      5.745370
# 4                               0.069                      5.745370
# ...                               ...                           ...
# 195936                          0.043                      6.121746
# 195937                          0.043                      6.121746
# 195938                          0.043                      6.121746
# 195939                          0.087                      9.715117
# 195940                          0.087                      9.715117
#
#         agg_Country_month_co_max_var  agg_Country_month_so2_max_mean  \
# 0                          33.009279                        7.232384
# 1                          33.009279                        7.232384
# 2                          33.009279                        7.232384
# 3                          33.009279                        7.232384
# 4                          33.009279                        7.232384
# ...                              ...                             ...
# 195936                     37.475780                        5.929579
# 195937                     37.475780                        5.929579
# 195938                     37.475780                        5.929579
# 195939                     94.383493                       12.529061
# 195940                     94.383493                       12.529061
#
#         agg_Country_month_so2_max_amax  agg_Country_month_so2_max_amin  \
# 0                               54.925                           0.099
# 1                               54.925                           0.099
# 2                               54.925                           0.099
# 3                               54.925                           0.099
# 4                               54.925                           0.099
# ...                                ...                             ...
# 195936                          64.849                           0.099
# 195937                          64.849                           0.099
# 195938                          64.849                           0.099
# 195939                          92.457                           0.890
# 195940                          92.457                           0.890
#
#         agg_Country_month_so2_max_std  agg_Country_month_so2_max_var  \
# 0                            8.029337                      64.470248
# 1                            8.029337                      64.470248
# 2                            8.029337                      64.470248
# 3                            8.029337                      64.470248
# 4                            8.029337                      64.470248
# ...                               ...                            ...
# 195936                       7.932629                      62.926597
# 195937                       7.932629                      62.926597
# 195938                       7.932629                      62.926597
# 195939                      13.011806                     169.307083
# 195940                      13.011806                     169.307083
#
#         agg_Country_month_ws_mid_mean  agg_Country_month_ws_mid_amax  \
# 0                            2.669814                          8.075
# 1                            2.669814                          8.075
# 2                            2.669814                          8.075
# 3                            2.669814                          8.075
# 4                            2.669814                          8.075
# ...                               ...                            ...
# 195936                       2.448317                          7.558
# 195937                       2.448317                          7.558
# 195938                       2.448317                          7.558
# 195939                       2.342678                          5.860
# 195940                       2.342678                          5.860
#
#         agg_Country_month_ws_mid_amin  agg_Country_month_ws_mid_std  \
# 0                               0.000                      1.469563
# 1                               0.000                      1.469563
# 2                               0.000                      1.469563
# 3                               0.000                      1.469563
# 4                               0.000                      1.469563
# ...                               ...                           ...
# 195936                          0.100                      1.206111
# 195937                          0.100                      1.206111
# 195938                          0.100                      1.206111
# 195939                          0.086                      1.168136
# 195940                          0.086                      1.168136
#
#         agg_Country_month_ws_mid_var  agg_Country_month_so2_mid_mean  \
# 0                           2.159616                        2.385929
# 1                           2.159616                        2.385929
# 2                           2.159616                        2.385929
# 3                           2.159616                        2.385929
# 4                           2.159616                        2.385929
# ...                              ...                             ...
# 195936                      1.454703                        1.983204
# 195937                      1.454703                        1.983204
# 195938                      1.454703                        1.983204
# 195939                      1.364541                        5.818959
# 195940                      1.364541                        5.818959
#
#         agg_Country_month_so2_mid_amax  agg_Country_month_so2_mid_amin  \
# 0                               18.539                           0.094
# 1                               18.539                           0.094
# 2                               18.539                           0.094
# 3                               18.539                           0.094
# 4                               18.539                           0.094
# ...                                ...                             ...
# 195936                           8.944                           0.095
# 195937                           8.944                           0.095
# 195938                           8.944                           0.095
# 195939                          30.609                           0.360
# 195940                          30.609                           0.360
#
#         agg_Country_month_so2_mid_std  agg_Country_month_so2_mid_var  \
# 0                            2.142337                       4.589608
# 1                            2.142337                       4.589608
# 2                            2.142337                       4.589608
# 3                            2.142337                       4.589608
# 4                            2.142337                       4.589608
# ...                               ...                            ...
# 195936                       1.609612                       2.590852
# 195937                       1.609612                       2.590852
# 195938                       1.609612                       2.590852
# 195939                       6.506570                      42.335452
# 195940                       6.506570                      42.335452
#
#         agg_Country_month_o3_max_mean  agg_Country_month_o3_max_amax  \
# 0                           28.888395                        113.124
# 1                           28.888395                        113.124
# 2                           28.888395                        113.124
# 3                           28.888395                        113.124
# 4                           28.888395                        113.124
# ...                               ...                            ...
# 195936                      30.679241                        107.420
# 195937                      30.679241                        107.420
# 195938                      30.679241                        107.420
# 195939                      29.697192                         95.057
# 195940                      29.697192                         95.057
#
#         agg_Country_month_o3_max_amin  agg_Country_month_o3_max_std  \
# 0                               0.000                     18.787270
# 1                               0.000                     18.787270
# 2                               0.000                     18.787270
# 3                               0.000                     18.787270
# 4                               0.000                     18.787270
# ...                               ...                           ...
# 195936                          0.823                     13.721792
# 195937                          0.823                     13.721792
# 195938                          0.823                     13.721792
# 195939                          4.142                     15.115373
# 195940                          4.142                     15.115373
#
#         agg_Country_month_o3_max_var  agg_Country_month_co_min_mean  \
# 0                         352.961502                       1.723688
# 1                         352.961502                       1.723688
# 2                         352.961502                       1.723688
# 3                         352.961502                       1.723688
# 4                         352.961502                       1.723688
# ...                              ...                            ...
# 195936                    188.287585                       1.658364
# 195937                    188.287585                       1.658364
# 195938                    188.287585                       1.658364
# 195939                    228.474499                       1.709996
# 195940                    228.474499                       1.709996
#
#         agg_Country_month_co_min_amax  agg_Country_month_co_min_amin  \
# 0                              14.106                            0.0
# 1                              14.106                            0.0
# 2                              14.106                            0.0
# 3                              14.106                            0.0
# 4                              14.106                            0.0
# ...                               ...                            ...
# 195936                         10.271                            0.0
# 195937                         10.271                            0.0
# 195938                         10.271                            0.0
# 195939                          8.354                            0.0
# 195940                          8.354                            0.0
#
#         agg_Country_month_co_min_std  agg_Country_month_co_min_var
# 0                           1.844704                      3.402933
# 1                           1.844704                      3.402933
# 2                           1.844704                      3.402933
# 3                           1.844704                      3.402933
# 4                           1.844704                      3.402933
# ...                              ...                           ...
# 195936                      1.408436                      1.983691
# 195937                      1.408436                      1.983691
# 195938                      1.408436                      1.983691
# 195939                      1.822142                      3.320202
# 195940                      1.822142                      3.320202
#
# [195941 rows x 102 columns]

# %%
df_test = get_test_data(test_data, run_blocks)
df_test
# Out:
#             lat        lon  co_cnt  co_min  co_mid  co_max  co_var  o3_cnt  \
# 0     -34.92866  138.59863     155   0.091   0.101   0.195   0.003     167
# 1     -33.86785  151.20732      23   1.037   2.272   3.391   1.347     142
# 2      50.85045    4.34878      28   0.096   0.101   0.104   0.000     114
# 3      43.84864   18.35644     122   0.479   4.589  16.560  60.820     118
# 4     -23.17944  -45.88694     158   6.198  13.478  20.327  36.498     129
# ...         ...        ...     ...     ...     ...     ...     ...     ...
# 53504  36.98615   35.32531      97   4.674   9.034  14.650  23.900      90
# 53505  40.19559   29.06013     123  17.621  18.156  21.877   4.390     116
# 53506  41.00500   39.72694     150   0.128  14.275  21.124   0.315     108
# 53507  51.50853   -0.12574      21   0.057   0.111   2.088   0.988      54
# 53508  20.86481  106.68345      47   0.060   0.071   0.136   0.000     134
#
#        o3_min  o3_mid  o3_max   o3_var  so2_cnt  so2_min  so2_mid  so2_max  \
# 0       0.000   0.000   0.000    0.000       12    0.095    0.098    0.106
# 1       7.797  34.414  59.489  630.329       54    1.476    1.531    5.380
# 2       7.064  16.576  27.246   97.445        9    0.566    0.600    0.626
# 3       0.513  22.445  51.638  625.291      138    1.551   12.523   60.551
# 4       1.063   1.845  27.894  166.269       92    1.568    4.365   14.958
# ...       ...     ...     ...      ...      ...      ...      ...      ...
# 53504  11.798  21.871  28.693   67.294       88    3.699    7.816   44.080
# 53505   0.882   6.559  14.794   46.421      109    4.295    8.558   59.418
# 53506   0.476   9.539  33.956  175.614      100    0.074    2.970    7.959
# 53507   0.301   2.029  24.479  138.410       40    0.230    0.478    0.884
# 53508   9.491  19.852  24.678   55.554       19    1.544    2.441    6.277
#
#        so2_var  no2_cnt  no2_min  no2_mid  no2_max  no2_var  temperature_cnt  \
# 0        0.000      118    0.097    0.099    0.105    0.000              168
# 1        3.709      147    1.139    4.117   24.680  132.975              176
# 2        0.000      151    1.362    5.372   16.268   53.080              172
# 3      819.667      141    0.467    7.609   30.975  221.357              132
# 4       42.456      126    9.118   16.171   48.517  354.133              102
# ...        ...      ...      ...      ...      ...      ...              ...
# 53504  391.178       83    0.829    5.287   42.481  417.102               92
# 53505  706.550      104    8.884   14.335   30.304  111.588              112
# 53506   14.297      263    2.800   10.818   32.341  208.883              202
# 53507    0.102       77    1.326    9.441    9.838   17.650              111
# 53508    5.352       44    1.153    8.646   14.952   44.975              427
#
#        temperature_min  temperature_mid  temperature_max  temperature_var  \
# 0               13.226           23.461           33.922          104.054
# 1               21.676           27.487           36.453           52.606
# 2                5.402            7.786            9.754            4.564
# 3               -4.840            0.976            4.849           22.794
# 4                5.526            7.388           21.291           57.069
# ...                ...              ...              ...              ...
# 53504            8.354           12.533           18.784           26.241
# 53505            5.241            9.273           11.543            9.674
# 53506            6.784           12.701           16.167           21.408
# 53507           10.690           16.795           18.424           14.548
# 53508           20.111           25.368           28.187           15.394
#
#        humidity_cnt  humidity_min  humidity_mid  humidity_max  humidity_var  \
# 0               180        17.795        34.081        90.636      1282.735
# 1               177        30.139        55.590        87.970       805.448
# 2               163        70.948        80.069        96.067       148.232
# 3               139        55.585       100.000       100.000       479.874
# 4               123        68.233        87.176        99.879       237.783
# ...             ...           ...           ...           ...           ...
# 53504            94        34.495        47.605        73.066       352.286
# 53505           118        71.775        83.258       100.000       190.221
# 53506           112        43.466        75.428        87.317       466.464
# 53507            66        44.049        84.531        94.643       603.074
# 53508           107        63.503        83.249        94.011       223.148
#
#        pressure_cnt  pressure_min  pressure_mid  pressure_max  pressure_var  \
# 0               154       934.478       944.740      1029.990        11.067
# 1               184       979.216      1008.498      1014.100        65.343
# 2               159       936.950      1047.096      1080.000        19.318
# 3               132       950.173       985.215      1043.932        76.454
# 4               131      1001.341      1015.044      1017.836        50.092
# ...             ...           ...           ...           ...           ...
# 53504            95       914.666       963.444      1080.000         3.863
# 53505           105       989.638      1008.551      1024.879        35.258
# 53506           111      1002.984      1009.004      1025.333        37.266
# 53507           118      1012.094      1019.240      1024.880        28.607
# 53508           280      1005.977      1008.091      1013.454         8.356
#
#        ws_cnt  ws_min  ws_mid  ws_max  ws_var  dew_cnt  dew_min  dew_mid  \
# 0         111   0.098   2.411  10.213  24.608       26    3.057    8.180
# 1         158   0.101   2.982   8.261  15.957       47   11.090   15.361
# 2          64   0.218   1.200   5.802   7.584       44    1.055    4.411
# 3         149   0.504   1.172   3.861   2.696       16    0.482    0.484
# 4         164   0.409   1.412   3.132   1.754      165    6.253   11.440
# ...       ...     ...     ...     ...     ...      ...      ...      ...
# 53504      93   0.201   2.878   7.397  12.130       86    0.451    3.112
# 53505     114   0.473   1.491   2.974   1.468      115    3.894    6.823
# 53506     179   1.001   3.605   5.040   3.965       12    5.269    8.772
# 53507      41   0.077   0.803   3.884   3.268       34   10.906   10.959
# 53508     178   0.105   2.931  15.303  22.760       58    9.825   15.037
#
#        dew_max  dew_var  Country_label_enc  year  month  ...  \
# 0       15.841   39.705                 10  2019      1  ...
# 1       19.227   15.857                 10  2019      1  ...
# 2        6.955    8.415                 17  2019      1  ...
# 3        0.932    0.049                 27  2019      1  ...
# 4       12.473    3.546                 20  2019      1  ...
# ...        ...      ...                ...   ...    ...  ...
# 53504    4.512    3.938                  4  2021     12  ...
# 53505    6.861    2.145                  4  2021     12  ...
# 53506   12.661   13.201                  4  2021     12  ...
# 53507   12.744    0.822                 15  2021     12  ...
# 53508   22.294   11.189                 22  2021     12  ...
#
#        agg_Country_month_no2_mid_mean  agg_Country_month_no2_mid_amax  \
# 0                            6.669456                          38.018
# 1                            6.669456                          38.018
# 2                           10.718637                          34.456
# 3                           13.466500                          30.539
# 4                            9.873532                          31.797
# ...                               ...                             ...
# 53504                       16.835147                          65.910
# 53505                       16.835147                          65.910
# 53506                       16.835147                          65.910
# 53507                       11.130621                          37.752
# 53508                       11.745539                          32.873
#
#        agg_Country_month_no2_mid_amin  agg_Country_month_no2_mid_std  \
# 0                               0.095                       6.389357
# 1                               0.095                       6.389357
# 2                               0.701                       6.124120
# 3                               2.522                       6.787323
# 4                               0.734                       6.905423
# ...                               ...                            ...
# 53504                           0.096                       9.586174
# 53505                           0.096                       9.586174
# 53506                           0.096                       9.586174
# 53507                           0.532                       6.047230
# 53508                           0.408                       6.495702
#
#        agg_Country_month_no2_mid_var  agg_Country_month_co_mid_mean  \
# 0                          40.823877                       3.256152
# 1                          40.823877                       3.256152
# 2                          37.504847                       2.430248
# 3                          46.067748                       5.921730
# 4                          47.684868                       3.506133
# ...                              ...                            ...
# 53504                      91.894726                       9.267824
# 53505                      91.894726                       9.267824
# 53506                      91.894726                       9.267824
# 53507                      36.568994                       3.285987
# 53508                      42.194143                       4.323143
#
#        agg_Country_month_co_mid_amax  agg_Country_month_co_mid_amin  \
# 0                             20.272                          0.040
# 1                             20.272                          0.040
# 2                             24.154                          0.055
# 3                             16.151                          0.041
# 4                             16.564                          0.048
# ...                              ...                            ...
# 53504                         45.129                          0.060
# 53505                         45.129                          0.060
# 53506                         45.129                          0.060
# 53507                         17.057                          0.062
# 53508                         12.386                          0.053
#
#        agg_Country_month_co_mid_std  agg_Country_month_co_mid_var  \
# 0                          3.104306                      9.636714
# 1                          3.104306                      9.636714
# 2                          3.311313                     10.964791
# 3                          3.754441                     14.095825
# 4                          3.148044                      9.910182
# ...                             ...                           ...
# 53504                      7.283935                     53.055707
# 53505                      7.283935                     53.055707
# 53506                      7.283935                     53.055707
# 53507                      2.660291                      7.077151
# 53508                      3.063893                      9.387442
#
#        agg_Country_month_no2_max_mean  agg_Country_month_no2_max_amax  \
# 0                           17.718835                          67.282
# 1                           17.718835                          67.282
# 2                           23.987704                          70.249
# 3                           33.368284                          97.362
# 4                           26.736515                         151.632
# ...                               ...                             ...
# 53504                       45.301176                         127.826
# 53505                       45.301176                         127.826
# 53506                       45.301176                         127.826
# 53507                       32.897039                          80.557
# 53508                       32.203755                         107.800
#
#        agg_Country_month_no2_max_amin  agg_Country_month_no2_max_std  \
# 0                               0.096                      13.110455
# 1                               0.096                      13.110455
# 2                               0.796                      11.040255
# 3                               6.709                      17.067107
# 4                               1.637                      19.480391
# ...                               ...                            ...
# 53504                           0.101                      26.362827
# 53505                           0.101                      26.362827
# 53506                           0.101                      26.362827
# 53507                           1.555                      14.795336
# 53508                           2.377                      19.022846
#
#        agg_Country_month_no2_max_var  agg_Country_month_no2_min_mean  \
# 0                         171.884028                        2.492414
# 1                         171.884028                        2.492414
# 2                         121.887233                        3.781977
# 3                         291.286136                        3.835730
# 4                         379.485645                        2.967365
# ...                              ...                             ...
# 53504                     694.998637                        4.387565
# 53505                     694.998637                        4.387565
# 53506                     694.998637                        4.387565
# 53507                     218.901966                        2.577155
# 53508                     361.868687                        4.322363
#
#        agg_Country_month_no2_min_amax  agg_Country_month_no2_min_amin  \
# 0                              17.962                           0.000
# 1                              17.962                           0.000
# 2                              27.271                           0.000
# 3                              10.426                           0.451
# 4                              19.456                           0.000
# ...                               ...                             ...
# 53504                          35.777                           0.000
# 53505                          35.777                           0.000
# 53506                          35.777                           0.000
# 53507                          15.876                           0.000
# 53508                          16.456                           0.284
#
#        agg_Country_month_no2_min_std  agg_Country_month_no2_min_var  \
# 0                           3.422229                      11.711652
# 1                           3.422229                      11.711652
# 2                           3.899824                      15.208628
# 3                           2.774948                       7.700338
# 4                           3.803494                      14.466565
# ...                              ...                            ...
# 53504                       4.014080                      16.112841
# 53505                       4.014080                      16.112841
# 53506                       4.014080                      16.112841
# 53507                       2.606031                       6.791398
# 53508                       3.375140                      11.391571
#
#        agg_Country_month_co_max_mean  agg_Country_month_co_max_amax  \
# 0                           6.240017                         42.192
# 1                           6.240017                         42.192
# 2                           4.990093                         33.494
# 3                          15.039973                         47.792
# 4                           8.900245                         84.643
# ...                              ...                            ...
# 53504                      21.548997                        500.000
# 53505                      21.548997                        500.000
# 53506                      21.548997                        500.000
# 53507                       6.801492                         42.568
# 53508                      12.485510                         60.046
#
#        agg_Country_month_co_max_amin  agg_Country_month_co_max_std  \
# 0                              0.069                      5.745370
# 1                              0.069                      5.745370
# 2                              0.065                      6.365361
# 3                              0.063                     10.621241
# 4                              0.084                      8.623782
# ...                              ...                           ...
# 53504                          0.076                     25.068515
# 53505                          0.076                     25.068515
# 53506                          0.076                     25.068515
# 53507                          0.073                      5.836017
# 53508                          0.087                      9.715117
#
#        agg_Country_month_co_max_var  agg_Country_month_so2_max_mean  \
# 0                         33.009279                        7.232384
# 1                         33.009279                        7.232384
# 2                         40.517821                        5.325174
# 3                        112.810757                       41.671446
# 4                         74.369621                        9.785940
# ...                             ...                             ...
# 53504                    628.430444                       26.595882
# 53505                    628.430444                       26.595882
# 53506                    628.430444                       26.595882
# 53507                     34.059089                        8.209395
# 53508                     94.383493                       12.529061
#
#        agg_Country_month_so2_max_amax  agg_Country_month_so2_max_amin  \
# 0                              54.925                           0.099
# 1                              54.925                           0.099
# 2                              43.985                           0.522
# 3                             163.836                           0.935
# 4                              72.007                           0.608
# ...                               ...                             ...
# 53504                         135.179                           0.550
# 53505                         135.179                           0.550
# 53506                         135.179                           0.550
# 53507                         110.637                           0.554
# 53508                          92.457                           0.890
#
#        agg_Country_month_so2_max_std  agg_Country_month_so2_max_var  \
# 0                           8.029337                      64.470248
# 1                           8.029337                      64.470248
# 2                           6.509809                      42.377615
# 3                          34.787009                    1210.135997
# 4                          10.447206                     109.144106
# ...                              ...                            ...
# 53504                      20.364573                     414.715823
# 53505                      20.364573                     414.715823
# 53506                      20.364573                     414.715823
# 53507                      11.218140                     125.846665
# 53508                      13.011806                     169.307083
#
#        agg_Country_month_ws_mid_mean  agg_Country_month_ws_mid_amax  \
# 0                           2.669814                          8.075
# 1                           2.669814                          8.075
# 2                           2.651849                          9.842
# 3                           1.729054                          6.139
# 4                           2.410099                          8.161
# ...                              ...                            ...
# 53504                       2.384074                         12.061
# 53505                       2.384074                         12.061
# 53506                       2.384074                         12.061
# 53507                       3.071361                         13.085
# 53508                       2.342678                          5.860
#
#        agg_Country_month_ws_mid_amin  agg_Country_month_ws_mid_std  \
# 0                              0.000                      1.469563
# 1                              0.000                      1.469563
# 2                              0.201                      1.687567
# 3                              0.481                      1.130903
# 4                              0.051                      1.568472
# ...                              ...                           ...
# 53504                          0.207                      1.533982
# 53505                          0.207                      1.533982
# 53506                          0.207                      1.533982
# 53507                          0.319                      1.912120
# 53508                          0.086                      1.168136
#
#        agg_Country_month_ws_mid_var  agg_Country_month_so2_mid_mean  \
# 0                          2.159616                        2.385929
# 1                          2.159616                        2.385929
# 2                          2.847882                        1.810601
# 3                          1.278942                       15.246203
# 4                          2.460103                        3.238652
# ...                             ...                             ...
# 53504                      2.353101                        9.093545
# 53505                      2.353101                        9.093545
# 53506                      2.353101                        9.093545
# 53507                      3.656204                        2.399239
# 53508                      1.364541                        5.818959
#
#        agg_Country_month_so2_mid_amax  agg_Country_month_so2_mid_amin  \
# 0                              18.539                           0.094
# 1                              18.539                           0.094
# 2                               9.339                           0.122
# 3                              66.278                           0.388
# 4                              31.476                           0.256
# ...                               ...                             ...
# 53504                          60.678                           0.245
# 53505                          60.678                           0.245
# 53506                          60.678                           0.245
# 53507                           9.138                           0.207
# 53508                          30.609                           0.360
#
#        agg_Country_month_so2_mid_std  agg_Country_month_so2_mid_var  \
# 0                           2.142337                       4.589608
# 1                           2.142337                       4.589608
# 2                           1.615454                       2.609690
# 3                          15.173100                     230.222949
# 4                           3.806475                      14.489255
# ...                              ...                            ...
# 53504                      11.710108                     137.126635
# 53505                      11.710108                     137.126635
# 53506                      11.710108                     137.126635
# 53507                       1.630593                       2.658834
# 53508                       6.506570                      42.335452
#
#        agg_Country_month_o3_max_mean  agg_Country_month_o3_max_amax  \
# 0                          28.888395                        113.124
# 1                          28.888395                        113.124
# 2                          28.934386                        121.344
# 3                          35.956865                         95.880
# 4                          41.866798                        280.087
# ...                              ...                            ...
# 53504                      26.828379                        133.883
# 53505                      26.828379                        133.883
# 53506                      26.828379                        133.883
# 53507                      31.205768                        108.095
# 53508                      29.697192                         95.057
#
#        agg_Country_month_o3_max_amin  agg_Country_month_o3_max_std  \
# 0                              0.000                     18.787270
# 1                              0.000                     18.787270
# 2                              3.089                     16.736326
# 3                              8.838                     18.260599
# 4                              8.949                     28.191124
# ...                              ...                           ...
# 53504                          1.250                     16.051804
# 53505                          1.250                     16.051804
# 53506                          1.250                     16.051804
# 53507                          3.529                     14.281725
# 53508                          4.142                     15.115373
#
#        agg_Country_month_o3_max_var  agg_Country_month_co_min_mean  \
# 0                        352.961502                       1.723688
# 1                        352.961502                       1.723688
# 2                        280.104603                       1.098125
# 3                        333.449480                       2.513649
# 4                        794.739449                       1.504077
# ...                             ...                            ...
# 53504                    257.660426                       4.797071
# 53505                    257.660426                       4.797071
# 53506                    257.660426                       4.797071
# 53507                    203.967668                       1.552839
# 53508                    228.474499                       1.709996
#
#        agg_Country_month_co_min_amax  agg_Country_month_co_min_amin  \
# 0                             14.106                          0.000
# 1                             14.106                          0.000
# 2                             10.519                          0.000
# 3                              7.407                          0.016
# 4                              8.704                          0.025
# ...                              ...                            ...
# 53504                         36.110                          0.015
# 53505                         36.110                          0.015
# 53506                         36.110                          0.015
# 53507                          7.688                          0.000
# 53508                          8.354                          0.000
#
#        agg_Country_month_co_min_std  agg_Country_month_co_min_var
# 0                          1.844704                      3.402933
# 1                          1.844704                      3.402933
# 2                          1.723400                      2.970108
# 3                          1.833767                      3.362700
# 4                          1.683958                      2.835713
# ...                             ...                           ...
# 53504                      5.587682                     31.222187
# 53505                      5.587682                     31.222187
# 53506                      5.587682                     31.222187
# 53507                      1.437501                      2.066410
# 53508                      1.822142                      3.320202
#
# [53509 rows x 102 columns]

# %%
df_all = pd.concat([df_train,df_test],sort=False)

# %%
#df_all['diff_no2_mid_aggmean'] = df_all['agg_Country_month_no2_mid_mean'] - df_all['no2_mid']
#df_all['diff_no2_mid_aggamax'] = df_all['agg_Country_month_no2_mid_amax'] - df_all['no2_mid']
df_all['diff_no2_mid_aggamin'] = df_all['agg_Country_month_no2_mid_amin'] - df_all['no2_mid']

#df_all['diff_no2_mid_aggminmax'] = df_all['diff_no2_mid_aggamax'] - df_all['diff_no2_mid_aggamin']
#df_all['ratio_no2_mid_aggminmax_mean'] = df_all['diff_no2_mid_aggminmax'] / df_all['diff_no2_mid_aggmean']

#df_all['diff_no2_max_aggmean'] = df_all['agg_Country_month_no2_max_mean'] - df_all['no2_max']
#df_all['diff_no2_max_aggamax'] = df_all['agg_Country_month_no2_max_amax'] - df_all['no2_max']
#df_all['diff_no2_max_aggamin'] = df_all['agg_Country_month_no2_max_amin'] - df_all['no2_max']

#df_all['diff_no2_max_aggminmax'] = df_all['diff_no2_max_aggamax'] - df_all['diff_no2_max_aggamin']
#df_all['ratio_no2_max_aggminmax_mean'] = df_all['diff_no2_max_aggminmax'] / df_all['diff_no2_max_aggmean']

#df_all['diff_no2_min_aggmean'] = df_all['agg_Country_month_no2_min_mean'] - df_all['no2_min']
#df_all['diff_no2_min_aggamax'] = df_all['agg_Country_month_no2_min_amax'] - df_all['no2_min']
#df_all['diff_no2_min_aggamin'] = df_all['agg_Country_month_no2_min_amin'] - df_all['no2_min']

#df_all['diff_no2_min_aggminmax'] = df_all['diff_no2_min_aggamax'] - df_all['diff_no2_min_aggamin']
#df_all['ratio_no2_min_aggminmax_mean'] = df_all['diff_no2_min_aggminmax'] / df_all['diff_no2_min_aggmean']

#df_all['diff_no2_minmax_aggmean'] = df_all['diff_no2_max_aggmean'] -df_all['diff_no2_min_aggmean']
#df_all['diff_no2_minmax_aggamax'] = df_all['diff_no2_max_aggamax'] -df_all['diff_no2_min_aggamax']
#df_all['diff_no2_minmax_aggamin'] = df_all['diff_no2_max_aggamin'] -df_all['diff_no2_min_aggamin']

#df_all['diff_co_mid_aggmean'] = df_all['agg_Country_month_co_mid_mean'] - df_all['co_mid']
#df_all['diff_co_mid_aggamax'] = df_all['agg_Country_month_co_mid_amax'] - df_all['co_mid']
df_all['diff_co_mid_aggamin'] = df_all['agg_Country_month_co_mid_amin'] - df_all['co_mid']

#df_all['diff_co_mid_aggminmax'] = df_all['diff_co_mid_aggamax'] - df_all['diff_co_mid_aggamin']
#df_all['ratio_co_mid_aggminmax_mean'] = df_all['diff_co_mid_aggminmax'] / df_all['diff_co_mid_aggmean']

#df_all['diff_co_max_aggmean'] = df_all['agg_Country_month_co_max_mean'] - df_all['co_max']
#df_all['diff_co_max_aggamax'] = df_all['agg_Country_month_co_max_amax'] - df_all['co_max']
df_all['diff_co_max_aggamin'] = df_all['agg_Country_month_co_max_amin'] - df_all['co_max']

#df_all['diff_co_max_aggminmax'] = df_all['diff_co_max_aggamax'] - df_all['diff_co_max_aggamin']
#df_all['ratio_co_max_aggminmax_mean'] = df_all['diff_co_max_aggminmax'] / df_all['diff_co_max_aggmean']

#df_all['diff_co_min_aggmean'] = df_all['agg_Country_month_co_min_mean'] - df_all['co_min']
#df_all['diff_co_min_aggamax'] = df_all['agg_Country_month_co_min_amax'] - df_all['co_min']
#df_all['diff_co_min_aggamin'] = df_all['agg_Country_month_co_min_amin'] - df_all['co_min']
'''

#df_all['diff_co_min_aggminmax'] = df_all['diff_co_min_aggamax'] - df_all['diff_co_min_aggamin']
#df_all['ratio_co_min_aggminmax_mean'] = df_all['diff_co_min_aggminmax'] / df_all['diff_co_min_aggmean']

#df_all['diff_co_minmax_aggmean'] = df_all['diff_co_max_aggmean'] -df_all['diff_co_min_aggmean']
#df_all['diff_co_minmax_aggamax'] = df_all['diff_co_max_aggamax'] -df_all['diff_co_min_aggamax']
#df_all['diff_co_minmax_aggamin'] = df_all['diff_co_max_aggamin'] -df_all['diff_co_min_aggamin']

#df_all['diff_so2_max_aggmean'] = df_all['agg_Country_month_so2_max_mean'] - df_all['so2_max']
#df_all['diff_so2_max_aggamax'] = df_all['agg_Country_month_so2_max_amax'] - df_all['so2_max']
df_all['diff_so2_max_aggamin'] = df_all['agg_Country_month_so2_max_amin'] - df_all['so2_max']

#df_all['diff_so2_max_aggminmax'] = df_all['diff_so2_max_aggamax'] - df_all['diff_so2_max_aggamin']
#df_all['ratio_so2_max_aggminmax_mean'] = df_all['diff_so2_max_aggminmax'] / df_all['diff_so2_max_aggmean']

#df_all['diff_so2_mid_aggmean'] = df_all['agg_Country_month_so2_mid_mean'] - df_all['so2_mid']
#df_all['diff_so2_mid_aggamax'] = df_all['agg_Country_month_so2_mid_amax'] - df_all['so2_mid']
df_all['diff_so2_mid_aggamin'] = df_all['agg_Country_month_so2_mid_amin'] - df_all['so2_mid']

#df_all['diff_so2_mid_aggminmax'] = df_all['diff_so2_mid_aggamax'] - df_all['diff_so2_mid_aggamin']
#df_all['ratio_so2_mid_aggminmax_mean'] = df_all['diff_so2_mid_aggminmax'] / df_all['diff_so2_mid_aggmean']

df_all['diff_o3_max_aggmean'] = df_all['agg_Country_month_o3_max_mean'] - df_all['o3_max']
#df_all['diff_o3_max_aggamax'] = df_all['agg_Country_month_o3_max_amax'] - df_all['o3_max']
df_all['diff_o3_max_aggamin'] = df_all['agg_Country_month_o3_max_amin'] - df_all['o3_max']

df_all['diff_o3_max_aggminmax'] = df_all['diff_o3_max_aggamax'] - df_all['diff_o3_max_aggamin']
df_all['ratio_o3_max_aggminmax_mean'] = df_all['diff_o3_max_aggminmax'] / df_all['diff_o3_max_aggmean']

df_all['diff_ws_mid_aggmean'] = df_all['agg_Country_month_ws_mid_mean'] - df_all['ws_mid']
df_all['diff_ws_mid_aggamax'] = df_all['agg_Country_month_ws_mid_amax'] - df_all['ws_mid']
df_all['diff_ws_mid_aggamin'] = df_all['agg_Country_month_ws_mid_amin'] - df_all['ws_mid']

df_all['diff_ws_mid_aggminmax'] = df_all['diff_ws_mid_aggamax'] - df_all['diff_ws_mid_aggamin']
df_all['ratio_ws_mid_aggminmax_mean'] = df_all['diff_ws_mid_aggminmax'] / df_all['diff_ws_mid_aggmean']
'''
# Out:
# "\n\n#df_all['diff_co_min_aggminmax'] = df_all['diff_co_min_aggamax'] - df_all['diff_co_min_aggamin']\n#df_all['ratio_co_min_aggminmax_mean'] = df_all['diff_co_min_aggminmax'] / df_all['diff_co_min_aggmean']\n\n#df_all['diff_co_minmax_aggmean'] = df_all['diff_co_max_aggmean'] -df_all['diff_co_min_aggmean']\n#df_all['diff_co_minmax_aggamax'] = df_all['diff_co_max_aggamax'] -df_all['diff_co_min_aggamax']\n#df_all['diff_co_minmax_aggamin'] = df_all['diff_co_max_aggamin'] -df_all['diff_co_min_aggamin']\n\n#df_all['diff_so2_max_aggmean'] = df_all['agg_Country_month_so2_max_mean'] - df_all['so2_max']\n#df_all['diff_so2_max_aggamax'] = df_all['agg_Country_month_so2_max_amax'] - df_all['so2_max']\ndf_all['diff_so2_max_aggamin'] = df_all['agg_Country_month_so2_max_amin'] - df_all['so2_max']\n\n#df_all['diff_so2_max_aggminmax'] = df_all['diff_so2_max_aggamax'] - df_all['diff_so2_max_aggamin']\n#df_all['ratio_so2_max_aggminmax_mean'] = df_all['diff_so2_max_aggminmax'] / df_all['diff_so2_max_aggmean']\n\n#df_all['diff_so2_mid_aggmean'] = df_all['agg_Country_month_so2_mid_mean'] - df_all['so2_mid']\n#df_all['diff_so2_mid_aggamax'] = df_all['agg_Country_month_so2_mid_amax'] - df_all['so2_mid']\ndf_all['diff_so2_mid_aggamin'] = df_all['agg_Country_month_so2_mid_amin'] - df_all['so2_mid']\n\n#df_all['diff_so2_mid_aggminmax'] = df_all['diff_so2_mid_aggamax'] - df_all['diff_so2_mid_aggamin']\n#df_all['ratio_so2_mid_aggminmax_mean'] = df_all['diff_so2_mid_aggminmax'] / df_all['diff_so2_mid_aggmean']\n\ndf_all['diff_o3_max_aggmean'] = df_all['agg_Country_month_o3_max_mean'] - df_all['o3_max']\n#df_all['diff_o3_max_aggamax'] = df_all['agg_Country_month_o3_max_amax'] - df_all['o3_max']\ndf_all['diff_o3_max_aggamin'] = df_all['agg_Country_month_o3_max_amin'] - df_all['o3_max']\n\ndf_all['diff_o3_max_aggminmax'] = df_all['diff_o3_max_aggamax'] - df_all['diff_o3_max_aggamin']\ndf_all['ratio_o3_max_aggminmax_mean'] = df_all['diff_o3_max_aggminmax'] / df_all['diff_o3_max_aggmean']\n\ndf_all['diff_ws_mid_aggmean'] = df_all['agg_Country_month_ws_mid_mean'] - df_all['ws_mid']\ndf_all['diff_ws_mid_aggamax'] = df_all['agg_Country_month_ws_mid_amax'] - df_all['ws_mid']\ndf_all['diff_ws_mid_aggamin'] = df_all['agg_Country_month_ws_mid_amin'] - df_all['ws_mid']\n\ndf_all['diff_ws_mid_aggminmax'] = df_all['diff_ws_mid_aggamax'] - df_all['diff_ws_mid_aggamin']\ndf_all['ratio_ws_mid_aggminmax_mean'] = df_all['diff_ws_mid_aggminmax'] / df_all['diff_ws_mid_aggmean']\n"

# %%
import wxparams as wx
'''
df_all['mix_ratio'] = wx.Mixing_Ratio(df_all['dew_mid'], df_all['pressure_mid'], formula="Bolton")
df_all['spec_humidity'] = wx.Specific_Humidity(df_all['dew_mid'], df_all['pressure_mid'], formula="Bolton")
df_all['abs_humidity'] = wx.Absolute_Humidity(df_all['temperature_mid'], df_all['dew_mid'], formula="Bolton")
df_all['vir_temperature'] = wx.Virtual_Temperature(df_all['temperature_mid'], df_all['dew_mid'], df_all['pressure_mid'], formula="Bolton")
'''
df_all['theta'] = wx.Theta(df_all['temperature_mid'], df_all['pressure_mid'])
df_all['tlcl'] = wx.Tlcl(df_all['temperature_mid'], df_all['dew_mid'])
'''
df_all['theta_e'] = wx.Theta_e(df_all['temperature_mid'], df_all['dew_mid'], df_all['pressure_mid'], formula="Bolton")
df_all['di'] = 0.81*df_all['temperature_mid']+0.01*df_all['humidity_mid']*(0.99*df_all['temperature_mid']-14.3)+4
'''

df_all['co_minmax'] = df_all['co_max'] - df_all['co_min']
df_all['o3_minmax'] = df_all['o3_max'] - df_all['o3_min']
df_all['so2_minmax'] = df_all['so2_max'] - df_all['so2_min']
df_all['no2_minmax'] = df_all['no2_max'] - df_all['no2_min']

df_all['temperature_minmax'] = df_all['temperature_max'] - df_all['temperature_min']
df_all['humidity_minmax'] = df_all['humidity_max'] - df_all['humidity_min']
df_all['pressure_minmax'] = df_all['pressure_max'] - df_all['pressure_min']
df_all['ws_minmax'] = df_all['ws_max'] - df_all['ws_min']
df_all['dew_minmax'] = df_all['dew_max'] - df_all['dew_min']

df_all['co_mean_mid'] = df_all['co_min'] + df_all['co_minmax']/2 - df_all['co_mid']
df_all['o3_mean_mid'] = df_all['o3_min'] + df_all['o3_minmax']/2 - df_all['o3_mid']
df_all['so2_mean_mid'] = df_all['so2_min'] + df_all['so2_minmax']/2 - df_all['so2_mid']
df_all['no2_mean_mid'] = df_all['no2_min'] + df_all['no2_minmax']/2 - df_all['no2_mid']

df_all['temperature_mean_mid'] = df_all['temperature_min'] + df_all['temperature_minmax']/2 - df_all['temperature_mid']
df_all['humidity_mean_mid'] = df_all['humidity_min'] + df_all['humidity_minmax']/2 - df_all['humidity_mid']
df_all['pressure_mean_mid'] = df_all['pressure_min'] + df_all['pressure_minmax']/2 - df_all['pressure_mid']
df_all['ws_mean_mid'] = df_all['ws_min'] + df_all['ws_minmax']/2 - df_all['ws_mid']

df_all['co_humidity'] = df_all['co_mid']*df_all['humidity_mid']/100
df_all['o3_humidity'] = df_all['o3_mid']*df_all['humidity_mid']/100
df_all['so2_humidity'] = df_all['so2_mid']*df_all['humidity_mid']/100
df_all['no2_humidity'] = df_all['no2_mid']*df_all['humidity_mid']/100
'''
df_all['co_ws'] = df_all['co_mid']*df_all['ws_mid']
df_all['o3_ws'] = df_all['o3_mid']*df_all['ws_mid']
df_all['so2_ws'] = df_all['so2_mid']*df_all['ws_mid']
df_all['no2_ws'] = df_all['no2_mid']*df_all['ws_mid']

df_all['temperature_humidity'] = df_all['temperature_mid']*df_all['humidity_mid']

df_all['cnt'] = df_all['co_cnt']*df_all['o3_cnt']*df_all['so2_cnt']*df_all['no2_cnt']*df_all['temperature_cnt']*df_all['humidity_cnt']*df_all['pressure_cnt']*df_all['ws_cnt']
'''
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/arraylike.py:364: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /usr/local/lib/python3.7/dist-packages/pandas/core/arraylike.py:364: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# "\ndf_all['co_ws'] = df_all['co_mid']*df_all['ws_mid']\ndf_all['o3_ws'] = df_all['o3_mid']*df_all['ws_mid']\ndf_all['so2_ws'] = df_all['so2_mid']*df_all['ws_mid']\ndf_all['no2_ws'] = df_all['no2_mid']*df_all['ws_mid']\n\ndf_all['temperature_humidity'] = df_all['temperature_mid']*df_all['humidity_mid']\n\ndf_all['cnt'] = df_all['co_cnt']*df_all['o3_cnt']*df_all['so2_cnt']*df_all['no2_cnt']*df_all['temperature_cnt']*df_all['humidity_cnt']*df_all['pressure_cnt']*df_all['ws_cnt']\n"

# %%
def encode(df, col):
    # この方法だと場合によって最大値が変化するデータでは正確な値は出ない
    # 例：月の日数が30日や31日の場合がある
    df[col + '_cos'] = np.cos(2 * np.pi * df[col] / df[col].max())
    df[col + '_sin'] = np.sin(2 * np.pi * df[col] / df[col].max())
    return df

df_all = encode(df_all, 'weekday')
df_all = encode(df_all, 'day')
df_all = encode(df_all, 'month')
df_all = encode(df_all, 'year')

# %%
'''
group =['Country_label_enc']
feature_cols = ['co_mid', 'no2_mid']

outputs = [df_all]
grp_df = df_all.groupby(group)[feature_cols]

for lag in [-3,-2, -1, 1, 2,3]:
   # shift
   outputs.append(grp_df.shift(lag).add_prefix(f'shift{lag}_'))
   # diff
   outputs.append(grp_df.diff(lag).add_prefix(f'diff{lag}_'))


# rolling
for window in [3,30]:
    tmp_df = grp_df.rolling(window, min_periods=1)
    # 移動平均を取る
    tmp_df = tmp_df.mean().add_prefix(f'rolling{window}_mean_')
    outputs.append(tmp_df.reset_index(drop=True))


df_all = df_all.loc[~df_all.index.duplicated(keep='first')]
df_all = pd.concat(outputs,axis=1)

#https://stackoverflow.com/questions/71240439/reindexing-only-valid-with-uniquely-valued-index-objects
'''
# Out:
# "\ngroup =['Country_label_enc']\nfeature_cols = ['co_mid', 'no2_mid']\n\noutputs = [df_all]\ngrp_df = df_all.groupby(group)[feature_cols]\n\nfor lag in [-3,-2, -1, 1, 2,3]:\n   # shift\n   outputs.append(grp_df.shift(lag).add_prefix(f'shift{lag}_'))\n   # diff\n   outputs.append(grp_df.diff(lag).add_prefix(f'diff{lag}_'))\n\n\n# rolling\nfor window in [3,30]:\n    tmp_df = grp_df.rolling(window, min_periods=1)\n    # 移動平均を取る\n    tmp_df = tmp_df.mean().add_prefix(f'rolling{window}_mean_')\n    outputs.append(tmp_df.reset_index(drop=True))\n\n\ndf_all = df_all.loc[~df_all.index.duplicated(keep='first')]\ndf_all = pd.concat(outputs,axis=1)\n\n#https://stackoverflow.com/questions/71240439/reindexing-only-valid-with-uniquely-valued-index-objects\n"

# %%
print(df_all)
# Out:
#             lat        lon  co_cnt  co_min  co_mid  co_max  co_var  o3_cnt  \
# 0     -27.46794  153.02809      38   0.749   2.590   2.633   0.850      29
# 1     -12.46113  130.84185      47   2.594   3.181   4.828   1.208      49
# 2     -37.81400  144.96332      17   1.190   1.197   2.200   0.248     123
# 3     -32.92953  151.78010      63   4.586  11.044  14.802  24.186      90
# 4     -31.95224  115.86140      47   4.689   8.681  11.100  10.011      83
# ...         ...        ...     ...     ...     ...     ...     ...     ...
# 53504  36.98615   35.32531      97   4.674   9.034  14.650  23.900      90
# 53505  40.19559   29.06013     123  17.621  18.156  21.877   4.390     116
# 53506  41.00500   39.72694     150   0.128  14.275  21.124   0.315     108
# 53507  51.50853   -0.12574      21   0.057   0.111   2.088   0.988      54
# 53508  20.86481  106.68345      47   0.060   0.071   0.136   0.000     134
#
#        o3_min  o3_mid  o3_max   o3_var  so2_cnt  so2_min  so2_mid  so2_max  \
# 0       2.397   4.295   5.916    3.017       11    0.149    0.468    0.900
# 1       3.092   7.572  12.332   20.524       31    0.096    0.102   16.152
# 2       0.736  12.527  23.432  125.224       36    1.392    1.464   47.652
# 3       1.917  14.141  38.374  304.731       50    2.957    3.230   14.056
# 4       0.349   2.349  38.600  353.549       47    0.422    5.794    9.972
# ...       ...     ...     ...      ...      ...      ...      ...      ...
# 53504  11.798  21.871  28.693   67.294       88    3.699    7.816   44.080
# 53505   0.882   6.559  14.794   46.421      109    4.295    8.558   59.418
# 53506   0.476   9.539  33.956  175.614      100    0.074    2.970    7.959
# 53507   0.301   2.029  24.479  138.410       40    0.230    0.478    0.884
# 53508   9.491  19.852  24.678   55.554       19    1.544    2.441    6.277
#
#        so2_var  no2_cnt  no2_min  no2_mid  no2_max  no2_var  temperature_cnt  \
# 0        0.137       36    0.000    0.529    2.188    1.167               36
# 1       61.550       45    0.099    0.301    5.411    6.401               71
# 2      515.570      111    0.972    2.751   12.230   30.518              148
# 3       25.630      176   14.959   17.471   24.221   20.883              101
# 4        9.234       80   14.911   21.140   32.584   74.298               55
# ...        ...      ...      ...      ...      ...      ...              ...
# 53504  391.178       83    0.829    5.287   42.481  417.102               92
# 53505  706.550      104    8.884   14.335   30.304  111.588              112
# 53506   14.297      263    2.800   10.818   32.341  208.883              202
# 53507    0.102       77    1.326    9.441    9.838   17.650              111
# 53508    5.352       44    1.153    8.646   14.952   44.975              427
#
#        temperature_min  temperature_mid  temperature_max  temperature_var  \
# 0               10.956           14.038           20.866           23.880
# 1               24.113           30.125           36.678           37.327
# 2                0.000            0.000           23.226          131.280
# 3               16.423           19.819           20.044            3.188
# 4               10.297           11.822           13.377            2.311
# ...                ...              ...              ...              ...
# 53504            8.354           12.533           18.784           26.241
# 53505            5.241            9.273           11.543            9.674
# 53506            6.784           12.701           16.167           21.408
# 53507           10.690           16.795           18.424           14.548
# 53508           20.111           25.368           28.187           15.394
#
#        humidity_cnt  humidity_min  humidity_mid  humidity_max  humidity_var  \
# 0                45        30.207        70.426        94.202       994.051
# 1                50        49.034        74.276        92.975       467.112
# 2               138        25.919        69.069       100.000      1292.191
# 3               111        73.504        86.920       100.000        85.028
# 4               155        51.918        76.736        96.533       484.188
# ...             ...           ...           ...           ...           ...
# 53504            94        34.495        47.605        73.066       352.286
# 53505           118        71.775        83.258       100.000       190.221
# 53506           112        43.466        75.428        87.317       466.464
# 53507            66        44.049        84.531        94.643       603.074
# 53508           107        63.503        83.249        94.011       223.148
#
#        pressure_cnt  pressure_min  pressure_mid  pressure_max  pressure_var  \
# 0                59      1004.137      1015.721      1023.398        89.588
# 1                69       938.085       970.252      1080.000         7.320
# 2               153       880.000       880.000      1018.200      4655.348
# 3               141      1011.703      1016.545      1018.364        10.898
# 4               124      1019.521      1022.992      1027.611        15.142
# ...             ...           ...           ...           ...           ...
# 53504            95       914.666       963.444      1080.000         3.863
# 53505           105       989.638      1008.551      1024.879        35.258
# 53506           111      1002.984      1009.004      1025.333        37.266
# 53507           118      1012.094      1019.240      1024.880        28.607
# 53508           280      1005.977      1008.091      1013.454         8.356
#
#        ws_cnt  ws_min  ws_mid  ws_max  ws_var  dew_cnt  dew_min  dew_mid  \
# 0          42   0.241   1.088   3.101   1.983       17    7.671   10.358
# 1          48   0.828   3.473   7.396  10.411       62   21.324   23.813
# 2         125   0.000   2.107   8.089  15.719       22   10.309   13.133
# 3          52   0.284   0.503   3.592   2.485      116    7.146   10.685
# 4         102   0.500   0.755   3.396   1.937       93    1.091    3.277
# ...       ...     ...     ...     ...     ...      ...      ...      ...
# 53504      93   0.201   2.878   7.397  12.130       86    0.451    3.112
# 53505     114   0.473   1.491   2.974   1.468      115    3.894    6.823
# 53506     179   1.001   3.605   5.040   3.965       12    5.269    8.772
# 53507      41   0.077   0.803   3.884   3.268       34   10.906   10.959
# 53508     178   0.105   2.931  15.303  22.760       58    9.825   15.037
#
#        dew_max  dew_var  Country_label_enc  year  month  ...  \
# 0       15.112   13.424                 10  2019      1  ...
# 1       24.221    2.021                 10  2019      1  ...
# 2       15.422    6.355                 10  2019      1  ...
# 3       13.344    9.417                 10  2019      1  ...
# 4       12.272    4.109                 10  2019      1  ...
# ...        ...      ...                ...   ...    ...  ...
# 53504    4.512    3.938                  4  2021     12  ...
# 53505    6.861    2.145                  4  2021     12  ...
# 53506   12.661   13.201                  4  2021     12  ...
# 53507   12.744    0.822                 15  2021     12  ...
# 53508   22.294   11.189                 22  2021     12  ...
#
#        agg_Country_month_ws_mid_var  agg_Country_month_so2_mid_mean  \
# 0                          2.159616                        2.385929
# 1                          2.159616                        2.385929
# 2                          2.159616                        2.385929
# 3                          2.159616                        2.385929
# 4                          2.159616                        2.385929
# ...                             ...                             ...
# 53504                      2.353101                        9.093545
# 53505                      2.353101                        9.093545
# 53506                      2.353101                        9.093545
# 53507                      3.656204                        2.399239
# 53508                      1.364541                        5.818959
#
#        agg_Country_month_so2_mid_amax  agg_Country_month_so2_mid_amin  \
# 0                              18.539                           0.094
# 1                              18.539                           0.094
# 2                              18.539                           0.094
# 3                              18.539                           0.094
# 4                              18.539                           0.094
# ...                               ...                             ...
# 53504                          60.678                           0.245
# 53505                          60.678                           0.245
# 53506                          60.678                           0.245
# 53507                           9.138                           0.207
# 53508                          30.609                           0.360
#
#        agg_Country_month_so2_mid_std  agg_Country_month_so2_mid_var  \
# 0                           2.142337                       4.589608
# 1                           2.142337                       4.589608
# 2                           2.142337                       4.589608
# 3                           2.142337                       4.589608
# 4                           2.142337                       4.589608
# ...                              ...                            ...
# 53504                      11.710108                     137.126635
# 53505                      11.710108                     137.126635
# 53506                      11.710108                     137.126635
# 53507                       1.630593                       2.658834
# 53508                       6.506570                      42.335452
#
#        agg_Country_month_o3_max_mean  agg_Country_month_o3_max_amax  \
# 0                          28.888395                        113.124
# 1                          28.888395                        113.124
# 2                          28.888395                        113.124
# 3                          28.888395                        113.124
# 4                          28.888395                        113.124
# ...                              ...                            ...
# 53504                      26.828379                        133.883
# 53505                      26.828379                        133.883
# 53506                      26.828379                        133.883
# 53507                      31.205768                        108.095
# 53508                      29.697192                         95.057
#
#        agg_Country_month_o3_max_amin  agg_Country_month_o3_max_std  \
# 0                              0.000                     18.787270
# 1                              0.000                     18.787270
# 2                              0.000                     18.787270
# 3                              0.000                     18.787270
# 4                              0.000                     18.787270
# ...                              ...                           ...
# 53504                          1.250                     16.051804
# 53505                          1.250                     16.051804
# 53506                          1.250                     16.051804
# 53507                          3.529                     14.281725
# 53508                          4.142                     15.115373
#
#        agg_Country_month_o3_max_var  agg_Country_month_co_min_mean  \
# 0                        352.961502                       1.723688
# 1                        352.961502                       1.723688
# 2                        352.961502                       1.723688
# 3                        352.961502                       1.723688
# 4                        352.961502                       1.723688
# ...                             ...                            ...
# 53504                    257.660426                       4.797071
# 53505                    257.660426                       4.797071
# 53506                    257.660426                       4.797071
# 53507                    203.967668                       1.552839
# 53508                    228.474499                       1.709996
#
#        agg_Country_month_co_min_amax  agg_Country_month_co_min_amin  \
# 0                             14.106                          0.000
# 1                             14.106                          0.000
# 2                             14.106                          0.000
# 3                             14.106                          0.000
# 4                             14.106                          0.000
# ...                              ...                            ...
# 53504                         36.110                          0.015
# 53505                         36.110                          0.015
# 53506                         36.110                          0.015
# 53507                          7.688                          0.000
# 53508                          8.354                          0.000
#
#        agg_Country_month_co_min_std  agg_Country_month_co_min_var  \
# 0                          1.844704                      3.402933
# 1                          1.844704                      3.402933
# 2                          1.844704                      3.402933
# 3                          1.844704                      3.402933
# 4                          1.844704                      3.402933
# ...                             ...                           ...
# 53504                      5.587682                     31.222187
# 53505                      5.587682                     31.222187
# 53506                      5.587682                     31.222187
# 53507                      1.437501                      2.066410
# 53508                      1.822142                      3.320202
#
#        diff_no2_mid_aggamin  diff_co_mid_aggamin  diff_co_max_aggamin  \
# 0                    -0.434               -2.550               -2.564
# 1                    -0.206               -3.141               -4.759
# 2                    -2.656               -1.157               -2.131
# 3                   -17.376              -11.004              -14.733
# 4                   -21.045               -8.641              -11.031
# ...                     ...                  ...                  ...
# 53504                -5.191               -8.974              -14.574
# 53505               -14.239              -18.096              -21.801
# 53506               -10.722              -14.215              -21.048
# 53507                -8.909               -0.049               -2.015
# 53508                -8.238               -0.018               -0.049
#
#             theta       tlcl  co_minmax  o3_minmax  so2_minmax  no2_minmax  \
# 0      285.910980   9.552391      1.884      3.519       0.751       2.188
# 1      305.902972  23.505606      2.234      9.240      16.056       5.312
# 2      283.310392  56.000000      1.010     22.696      46.260      11.258
# 3      291.598709   9.041717     10.216     36.457      11.099       9.262
# 4      283.127264  -1.592865      6.411     38.251       9.550      17.673
# ...           ...        ...        ...        ...         ...         ...
# 53504  288.738817  -2.252971      9.976     16.895      40.381      41.652
# 53505  281.736803   5.877701      4.256     13.912      55.123      21.420
# 53506  285.119892   7.717027     20.996     33.480       7.885      29.541
# 53507  288.370639   9.849726      2.031     24.178       0.654       8.512
# 53508  297.831513  13.909900      0.076     15.187       4.733      13.799
#
#        temperature_minmax  humidity_minmax  pressure_minmax  ws_minmax  \
# 0                   9.910           63.995           19.261      2.860
# 1                  12.565           43.941          141.915      6.568
# 2                  23.226           74.081          138.200      8.089
# 3                   3.621           26.496            6.661      3.308
# 4                   3.080           44.615            8.090      2.896
# ...                   ...              ...              ...        ...
# 53504              10.430           38.571          165.334      7.196
# 53505               6.302           28.225           35.241      2.501
# 53506               9.383           43.851           22.349      4.039
# 53507               7.734           50.594           12.786      3.807
# 53508               8.076           30.508            7.477     15.198
#
#        dew_minmax  co_mean_mid  o3_mean_mid  so2_mean_mid  no2_mean_mid  \
# 0           7.441      -0.8990      -0.1385        0.0565        0.5650
# 1           2.897       0.5300       0.1400        8.0220        2.4540
# 2           5.113       0.4980      -0.4430       23.0580        3.8500
# 3           6.198      -1.3500       6.0045        5.2765        2.1190
# 4          11.181      -0.7865      17.1255       -0.5970        2.6075
# ...           ...          ...          ...           ...           ...
# 53504       4.061       0.6280      -1.6255       16.0735       16.3680
# 53505       2.967       1.5930       1.2790       23.2985        5.2590
# 53506       7.392      -3.6490       7.6770        1.0465        6.7525
# 53507       1.838       0.9615      10.3610        0.0790       -3.8590
# 53508      12.469       0.0270      -2.7675        1.4695       -0.5935
#
#        temperature_mean_mid  humidity_mean_mid  pressure_mean_mid  \
# 0                    1.8730            -8.2215            -1.9535
# 1                    0.2705            -3.2715            38.7905
# 2                   11.6130            -6.1095            69.1000
# 3                   -1.5855            -0.1680            -1.5115
# 4                    0.0150            -2.5105             0.5740
# ...                     ...                ...                ...
# 53504                1.0360             6.1755            33.8890
# 53505               -0.8810             2.6295            -1.2925
# 53506               -1.2255           -10.0365             5.1545
# 53507               -2.2380           -15.1850            -0.7530
# 53508               -1.2190            -4.4920             1.6245
#
#        ws_mean_mid  co_humidity  o3_humidity  so2_humidity  no2_humidity  \
# 0           0.5830     1.824033     3.024797      0.329594      0.372554
# 1           0.6390     2.362720     5.624179      0.075762      0.223571
# 2           1.9375     0.826756     8.652274      1.011170      1.900088
# 3           1.4350     9.599445    12.291357      2.807516     15.185793
# 4           1.1930     6.661452     1.802529      4.446084     16.221990
# ...            ...          ...          ...           ...           ...
# 53504       0.9210     4.300636    10.411690      3.720807      2.516876
# 53505       0.2325    15.116322     5.460892      7.125220     11.935034
# 53506      -0.5845    10.767347     7.195077      2.240212      8.159801
# 53507       1.1775     0.093829     1.715134      0.404058      7.980572
# 53508       4.7730     0.059107    16.526591      2.032108      7.197709
#
#        weekday_cos  weekday_sin  day_cos       day_sin  month_cos  \
# 0              0.5     0.866025  0.97953  2.012985e-01   0.866025
# 1              0.5     0.866025  0.97953  2.012985e-01   0.866025
# 2              0.5     0.866025  0.97953  2.012985e-01   0.866025
# 3              0.5     0.866025  0.97953  2.012985e-01   0.866025
# 4              0.5     0.866025  0.97953  2.012985e-01   0.866025
# ...            ...          ...      ...           ...        ...
# 53504         -0.5    -0.866025  1.00000 -2.449294e-16   1.000000
# 53505         -0.5    -0.866025  1.00000 -2.449294e-16   1.000000
# 53506         -0.5    -0.866025  1.00000 -2.449294e-16   1.000000
# 53507         -0.5    -0.866025  1.00000 -2.449294e-16   1.000000
# 53508         -0.5    -0.866025  1.00000 -2.449294e-16   1.000000
#
#           month_sin  year_cos      year_sin
# 0      5.000000e-01  0.999981 -6.217857e-03
# 1      5.000000e-01  0.999981 -6.217857e-03
# 2      5.000000e-01  0.999981 -6.217857e-03
# 3      5.000000e-01  0.999981 -6.217857e-03
# 4      5.000000e-01  0.999981 -6.217857e-03
# ...             ...       ...           ...
# 53504 -2.449294e-16  1.000000 -2.449294e-16
# 53505 -2.449294e-16  1.000000 -2.449294e-16
# 53506 -2.449294e-16  1.000000 -2.449294e-16
# 53507 -2.449294e-16  1.000000 -2.449294e-16
# 53508 -2.449294e-16  1.000000 -2.449294e-16
#
# [249450 rows x 136 columns]

# %%
#df_all.plot.scatter('month_sin', 'month_cos').set_aspect('equal')

# %%
df_train = df_all.iloc[:len(df_train)]
df_test = df_all.iloc[len(df_train):].reset_index(drop=True)

# %%
target = train_data[config.target]

# %%
'''
# LightGBM用のデータセットに変換
trainval = opt_lgb.Dataset(df_train, target)

# ハイパーパラメータサーチ&モデル構築
params = {'objective': 'regression',
          'metric': 'rmse',
          'random_seed':42} 

# クロスバリデーションによるハイパーパラメータの探索 3fold
tuner = opt_lgb.LightGBMTunerCV(params, trainval, verbose_eval=100, early_stopping_rounds=100, folds=KFold(n_splits=5))

# ハイパーパラメータ探索の実行
tuner.run()

# サーチしたパラメータの表示
best_params = tuner.best_params
print("  Params: ")
for key, value in best_params.items():
    print("    {}: {}".format(key, value))
'''
# Out:
# '\n# LightGBM用のデータセットに変換\ntrainval = opt_lgb.Dataset(df_train, target)\n\n# ハイパーパラメータサーチ&モデル構築\nparams = {\'objective\': \'regression\',\n          \'metric\': \'rmse\',\n          \'random_seed\':42} \n\n# クロスバリデーションによるハイパーパラメータの探索 3fold\ntuner = opt_lgb.LightGBMTunerCV(params, trainval, verbose_eval=100, early_stopping_rounds=100, folds=KFold(n_splits=5))\n\n# ハイパーパラメータ探索の実行\ntuner.run()\n\n# サーチしたパラメータの表示\nbest_params = tuner.best_params\nprint("  Params: ")\nfor key, value in best_params.items():\n    print("    {}: {}".format(key, value))\n'

# %%
def group_kfold_split(df, col_group, n_splits, random_state):

    group_id = df[col_group].value_counts().reset_index()
    group_id.columns = [col_group, 'count']
    group_id_list = group_id[col_group].unique()

    kf = KFold(n_splits=n_splits, shuffle=True, random_state=random_state)
    kf_list = list(kf.split(group_id_list))
    cv_idx = [(df[col_group].isin(group_id_list[idx_trn]), df[col_group].isin(group_id_list[idx_val])) for idx_trn, idx_val in kf_list]

    return [(df[idx_trn].index.tolist(), df[idx_val].index.tolist()) for idx_trn, idx_val in cv_idx]

# %%
#cross validation strategy
kf = KFold(n_splits=config.nfold, shuffle=True, random_state=config.random_seed)
kf_cv = list(kf.split(train_data))
gkf_cv = group_kfold_split(train_data, 'City', n_splits=config.nfold, random_state=config.random_seed)

# %%
def cal_rmse(y_true, y_pred):
  return np.sqrt(mean_squared_error(y_true, y_pred))

# %%
def fit_lgb(x, y, cv, model_params, fit_params, fobj=None, feval=None):

    models = []
    n_records = y.shape[0]
    oof_pred = np.zeros(n_records, dtype=np.float32)
    fold = 0
    data_labels = [re.sub(r'[",\[\]{}:()]', '_', c) for c in x.columns.tolist()]

    model_params.update(deterministic = True)

    for trn_idx, val_idx in cv:

        fold += 1
        x_train, x_valid = x.iloc[trn_idx].values, x.iloc[val_idx].values
        y_train, y_valid = np.array(y.iloc[trn_idx]), np.array(y.iloc[val_idx])

        lgb_train = lgb.Dataset(x_train, y_train, feature_name=data_labels)
        lgb_valid = lgb.Dataset(x_valid, y_valid, feature_name=data_labels, reference=lgb_train)

        lgb_model = lgb.train(model_params,
                              train_set=lgb_train,
                              valid_sets=[lgb_train, lgb_valid],
                              fobj=fobj,
                              feval=feval,
                              verbose_eval=fit_params['verbose_eval'],
                              num_boost_round=fit_params['num_boost_rounds'],
                              callbacks=[lgb.early_stopping(fit_params['early_stopping_rounds'])],
                              )

        pred_valid = lgb_model.predict(x_valid, num_iteration=lgb_model.best_iteration)
        oof_pred[val_idx] = pred_valid
        models.append(lgb_model)

        print(f' - fold{fold}_RMSE - {cal_rmse(y_valid, pred_valid):4f}')

    print(f' - CV_RMSE - {cal_rmse(oof_pred, np.array(y)):4f}') 

    return oof_pred, models

# %%
'''
#Params: 
    objective: regression
    metric: rmse
    random_seed: 42
    feature_pre_filter: False
    lambda_l1: 0.000338595481765331
    lambda_l2: 9.60230430368646
    num_leaves: 32
    feature_fraction: 0.6799999999999999
    bagging_fraction: 1.0
    bagging_freq: 0
    min_child_samples: 20
'''
# Out:
# '\n#Params: \n    objective: regression\n    metric: rmse\n    random_seed: 42\n    feature_pre_filter: False\n    lambda_l1: 0.000338595481765331\n    lambda_l2: 9.60230430368646\n    num_leaves: 32\n    feature_fraction: 0.6799999999999999\n    bagging_fraction: 1.0\n    bagging_freq: 0\n    min_child_samples: 20\n'

# %%
lgb_model_params = {'boosting_type': 'gbdt',
                
                    'objective': 'rmse',

                    'lambda_l1': 0.000338595481765331,
                    'lambda_l2': 9.60230430368646,
                    'feature_fraction': 0.6799999999999999,

                    'learning_rate': 0.05,
                    'max_depth': -1,
                    'num_leaves': 32,
                    'min_data_in_leaf': 20,
                    'max_bin': 255,
                    
                    'reg_lambda': 1.0,
                    'reg_alpha': 1.,
                   
                    'colsample_bytree': 0.8,
                    'subsample': 0.8,
                    'subsample_freq': 1,
                    
                    'random_state': config.random_seed,
                    'verbose': -1,
                    'n_jobs': -1,
                    }

lgb_fit_params ={'num_boost_rounds': 10000,
                 'early_stopping_rounds': 100,
                 'verbose_eval': 100,
                }

# %%
oof_valid_lgb1, lgb_models1 = fit_lgb(x=df_train, y=target, cv=kf_cv,
                                      model_params=lgb_model_params, fit_params=lgb_fit_params
                                     )
# Out:
# Training until validation scores don't improve for 100 rounds.
# [100]	training's rmse: 20.989	valid_1's rmse: 21.1559
# [200]	training's rmse: 19.8777	valid_1's rmse: 20.2907
# [300]	training's rmse: 19.264	valid_1's rmse: 19.9485
# [400]	training's rmse: 18.8239	valid_1's rmse: 19.7588
# [500]	training's rmse: 18.4548	valid_1's rmse: 19.6275
# [600]	training's rmse: 18.1208	valid_1's rmse: 19.5357
# [700]	training's rmse: 17.8191	valid_1's rmse: 19.4631
# [800]	training's rmse: 17.5376	valid_1's rmse: 19.3976
# [900]	training's rmse: 17.2646	valid_1's rmse: 19.3439
# [1000]	training's rmse: 17.0095	valid_1's rmse: 19.2961
# [1100]	training's rmse: 16.7705	valid_1's rmse: 19.2504
# [1200]	training's rmse: 16.552	valid_1's rmse: 19.2147
# [1300]	training's rmse: 16.328	valid_1's rmse: 19.1815
# [1400]	training's rmse: 16.117	valid_1's rmse: 19.1529
# [1500]	training's rmse: 15.9078	valid_1's rmse: 19.1263
# [1600]	training's rmse: 15.7119	valid_1's rmse: 19.1033
# [1700]	training's rmse: 15.5228	valid_1's rmse: 19.083
# [1800]	training's rmse: 15.3297	valid_1's rmse: 19.054
# [1900]	training's rmse: 15.1552	valid_1's rmse: 19.0357
# [2000]	training's rmse: 14.9833	valid_1's rmse: 19.023
# [2100]	training's rmse: 14.8189	valid_1's rmse: 19.0075
# [2200]	training's rmse: 14.6549	valid_1's rmse: 18.9873
# [2300]	training's rmse: 14.4933	valid_1's rmse: 18.9728
# [2400]	training's rmse: 14.3363	valid_1's rmse: 18.9598
# [2500]	training's rmse: 14.1823	valid_1's rmse: 18.9499
# [2600]	training's rmse: 14.0284	valid_1's rmse: 18.9371
# [2700]	training's rmse: 13.8834	valid_1's rmse: 18.9209
# [2800]	training's rmse: 13.7425	valid_1's rmse: 18.9105
# [2900]	training's rmse: 13.5971	valid_1's rmse: 18.9002
# [3000]	training's rmse: 13.4636	valid_1's rmse: 18.8892
# [3100]	training's rmse: 13.3221	valid_1's rmse: 18.8795
# [3200]	training's rmse: 13.1837	valid_1's rmse: 18.8687
# [3300]	training's rmse: 13.0506	valid_1's rmse: 18.8586
# [3400]	training's rmse: 12.9192	valid_1's rmse: 18.8514
# [3500]	training's rmse: 12.7931	valid_1's rmse: 18.844
# [3600]	training's rmse: 12.6687	valid_1's rmse: 18.84
# [3700]	training's rmse: 12.5468	valid_1's rmse: 18.8367
# [3800]	training's rmse: 12.4264	valid_1's rmse: 18.8329
# [3900]	training's rmse: 12.3039	valid_1's rmse: 18.824
# [4000]	training's rmse: 12.1854	valid_1's rmse: 18.8177
# [4100]	training's rmse: 12.0664	valid_1's rmse: 18.8109
# [4200]	training's rmse: 11.953	valid_1's rmse: 18.8081
# [4300]	training's rmse: 11.8427	valid_1's rmse: 18.801
# [4400]	training's rmse: 11.7352	valid_1's rmse: 18.7943
# [4500]	training's rmse: 11.6279	valid_1's rmse: 18.7908
# [4600]	training's rmse: 11.5234	valid_1's rmse: 18.7863
# [4700]	training's rmse: 11.4153	valid_1's rmse: 18.7805
# [4800]	training's rmse: 11.3146	valid_1's rmse: 18.7737
# [4900]	training's rmse: 11.2115	valid_1's rmse: 18.7705
# [5000]	training's rmse: 11.1095	valid_1's rmse: 18.767
# [5100]	training's rmse: 11.0094	valid_1's rmse: 18.7629
# [5200]	training's rmse: 10.9098	valid_1's rmse: 18.7572
# [5300]	training's rmse: 10.815	valid_1's rmse: 18.7542
# [5400]	training's rmse: 10.7205	valid_1's rmse: 18.7508
# [5500]	training's rmse: 10.6243	valid_1's rmse: 18.748
# [5600]	training's rmse: 10.5326	valid_1's rmse: 18.7446
# [5700]	training's rmse: 10.4389	valid_1's rmse: 18.7433
# [5800]	training's rmse: 10.3492	valid_1's rmse: 18.7379
# [5900]	training's rmse: 10.2597	valid_1's rmse: 18.7335
# [6000]	training's rmse: 10.1709	valid_1's rmse: 18.732
# [6100]	training's rmse: 10.0827	valid_1's rmse: 18.7295
# [6200]	training's rmse: 9.99521	valid_1's rmse: 18.729
# [6300]	training's rmse: 9.91204	valid_1's rmse: 18.7264
# [6400]	training's rmse: 9.82946	valid_1's rmse: 18.7251
# Early stopping, best iteration is:
# [6357]	training's rmse: 9.86531	valid_1's rmse: 18.7234
#  - fold1_RMSE - 18.723350
# Training until validation scores don't improve for 100 rounds.
# [100]	training's rmse: 20.9173	valid_1's rmse: 21.3594
# [200]	training's rmse: 19.7969	valid_1's rmse: 20.5301
# [300]	training's rmse: 19.2014	valid_1's rmse: 20.2188
# [400]	training's rmse: 18.7432	valid_1's rmse: 20.018
# [500]	training's rmse: 18.3622	valid_1's rmse: 19.8936
# [600]	training's rmse: 18.0412	valid_1's rmse: 19.8075
# [700]	training's rmse: 17.739	valid_1's rmse: 19.734
# [800]	training's rmse: 17.4605	valid_1's rmse: 19.6825
# [900]	training's rmse: 17.1876	valid_1's rmse: 19.6222
# [1000]	training's rmse: 16.9398	valid_1's rmse: 19.5758
# [1100]	training's rmse: 16.7031	valid_1's rmse: 19.5401
# [1200]	training's rmse: 16.4769	valid_1's rmse: 19.5084
# [1300]	training's rmse: 16.2537	valid_1's rmse: 19.4742
# [1400]	training's rmse: 16.0442	valid_1's rmse: 19.4487
# [1500]	training's rmse: 15.8409	valid_1's rmse: 19.4228
# [1600]	training's rmse: 15.6466	valid_1's rmse: 19.3947
# [1700]	training's rmse: 15.4592	valid_1's rmse: 19.3693
# [1800]	training's rmse: 15.2775	valid_1's rmse: 19.3484
# [1900]	training's rmse: 15.0965	valid_1's rmse: 19.3283
# [2000]	training's rmse: 14.9263	valid_1's rmse: 19.3115
# [2100]	training's rmse: 14.7614	valid_1's rmse: 19.2945
# [2200]	training's rmse: 14.6025	valid_1's rmse: 19.2805
# [2300]	training's rmse: 14.444	valid_1's rmse: 19.2648
# [2400]	training's rmse: 14.2905	valid_1's rmse: 19.2529
# [2500]	training's rmse: 14.1433	valid_1's rmse: 19.2435
# [2600]	training's rmse: 13.9936	valid_1's rmse: 19.2303
# [2700]	training's rmse: 13.8431	valid_1's rmse: 19.2167
# [2800]	training's rmse: 13.6996	valid_1's rmse: 19.2096
# [2900]	training's rmse: 13.561	valid_1's rmse: 19.201
# [3000]	training's rmse: 13.4189	valid_1's rmse: 19.1889
# [3100]	training's rmse: 13.283	valid_1's rmse: 19.1773
# [3200]	training's rmse: 13.1482	valid_1's rmse: 19.1704
# [3300]	training's rmse: 13.0192	valid_1's rmse: 19.1639
# [3400]	training's rmse: 12.8867	valid_1's rmse: 19.157
# [3500]	training's rmse: 12.7611	valid_1's rmse: 19.1504
# [3600]	training's rmse: 12.6391	valid_1's rmse: 19.1433
# [3700]	training's rmse: 12.5175	valid_1's rmse: 19.1399
# [3800]	training's rmse: 12.3983	valid_1's rmse: 19.1333
# [3900]	training's rmse: 12.28	valid_1's rmse: 19.128
# [4000]	training's rmse: 12.1631	valid_1's rmse: 19.1212
# [4100]	training's rmse: 12.0465	valid_1's rmse: 19.1171
# [4200]	training's rmse: 11.9379	valid_1's rmse: 19.1125
# [4300]	training's rmse: 11.8278	valid_1's rmse: 19.1084
# [4400]	training's rmse: 11.7196	valid_1's rmse: 19.1009
# [4500]	training's rmse: 11.6124	valid_1's rmse: 19.0952
# [4600]	training's rmse: 11.5105	valid_1's rmse: 19.0926
# [4700]	training's rmse: 11.411	valid_1's rmse: 19.0908
# [4800]	training's rmse: 11.3062	valid_1's rmse: 19.0879
# [4900]	training's rmse: 11.2077	valid_1's rmse: 19.0855
# [5000]	training's rmse: 11.1059	valid_1's rmse: 19.0847
# Early stopping, best iteration is:
# [4937]	training's rmse: 11.1714	valid_1's rmse: 19.0841
#  - fold2_RMSE - 19.084065
# Training until validation scores don't improve for 100 rounds.
# [100]	training's rmse: 20.8372	valid_1's rmse: 21.6814
# [200]	training's rmse: 19.7305	valid_1's rmse: 20.7958
# [300]	training's rmse: 19.1396	valid_1's rmse: 20.4721
# [400]	training's rmse: 18.7072	valid_1's rmse: 20.2733
# [500]	training's rmse: 18.334	valid_1's rmse: 20.1433
# [600]	training's rmse: 18.0074	valid_1's rmse: 20.0475
# [700]	training's rmse: 17.7001	valid_1's rmse: 19.9644
# [800]	training's rmse: 17.4201	valid_1's rmse: 19.9053
# [900]	training's rmse: 17.1575	valid_1's rmse: 19.8485
# [1000]	training's rmse: 16.9118	valid_1's rmse: 19.7952
# [1100]	training's rmse: 16.6764	valid_1's rmse: 19.7524
# [1200]	training's rmse: 16.4525	valid_1's rmse: 19.7183
# [1300]	training's rmse: 16.235	valid_1's rmse: 19.6864
# [1400]	training's rmse: 16.0224	valid_1's rmse: 19.6578
# [1500]	training's rmse: 15.8248	valid_1's rmse: 19.6315
# [1600]	training's rmse: 15.6305	valid_1's rmse: 19.606
# [1700]	training's rmse: 15.4395	valid_1's rmse: 19.5817
# [1800]	training's rmse: 15.256	valid_1's rmse: 19.5572
# [1900]	training's rmse: 15.0764	valid_1's rmse: 19.541
# [2000]	training's rmse: 14.9043	valid_1's rmse: 19.5227
# [2100]	training's rmse: 14.7381	valid_1's rmse: 19.5045
# [2200]	training's rmse: 14.5697	valid_1's rmse: 19.488
# [2300]	training's rmse: 14.4086	valid_1's rmse: 19.4803
# [2400]	training's rmse: 14.2487	valid_1's rmse: 19.4671
# [2500]	training's rmse: 14.0919	valid_1's rmse: 19.4532
# [2600]	training's rmse: 13.9452	valid_1's rmse: 19.4427
# [2700]	training's rmse: 13.8005	valid_1's rmse: 19.4314
# [2800]	training's rmse: 13.6554	valid_1's rmse: 19.4225
# [2900]	training's rmse: 13.512	valid_1's rmse: 19.408
# [3000]	training's rmse: 13.3758	valid_1's rmse: 19.3966
# [3100]	training's rmse: 13.2381	valid_1's rmse: 19.387
# [3200]	training's rmse: 13.1058	valid_1's rmse: 19.3763
# [3300]	training's rmse: 12.9765	valid_1's rmse: 19.3726
# [3400]	training's rmse: 12.8484	valid_1's rmse: 19.3645
# [3500]	training's rmse: 12.7235	valid_1's rmse: 19.3584
# [3600]	training's rmse: 12.6003	valid_1's rmse: 19.3484
# [3700]	training's rmse: 12.4784	valid_1's rmse: 19.3412
# [3800]	training's rmse: 12.3599	valid_1's rmse: 19.3347
# [3900]	training's rmse: 12.2403	valid_1's rmse: 19.3325
# [4000]	training's rmse: 12.127	valid_1's rmse: 19.3298
# [4100]	training's rmse: 12.0134	valid_1's rmse: 19.3227
# [4200]	training's rmse: 11.9018	valid_1's rmse: 19.3155
# [4300]	training's rmse: 11.793	valid_1's rmse: 19.3099
# [4400]	training's rmse: 11.6796	valid_1's rmse: 19.3029
# [4500]	training's rmse: 11.5711	valid_1's rmse: 19.2971
# [4600]	training's rmse: 11.4636	valid_1's rmse: 19.2916
# [4700]	training's rmse: 11.3602	valid_1's rmse: 19.2872
# [4800]	training's rmse: 11.2576	valid_1's rmse: 19.2812
# [4900]	training's rmse: 11.1569	valid_1's rmse: 19.278
# [5000]	training's rmse: 11.0592	valid_1's rmse: 19.2728
# [5100]	training's rmse: 10.9614	valid_1's rmse: 19.2694
# [5200]	training's rmse: 10.864	valid_1's rmse: 19.2642
# [5300]	training's rmse: 10.7663	valid_1's rmse: 19.2602
# [5400]	training's rmse: 10.6706	valid_1's rmse: 19.257
# [5500]	training's rmse: 10.575	valid_1's rmse: 19.2524
# [5600]	training's rmse: 10.4852	valid_1's rmse: 19.248
# [5700]	training's rmse: 10.3924	valid_1's rmse: 19.2445
# [5800]	training's rmse: 10.3045	valid_1's rmse: 19.2433
# [5900]	training's rmse: 10.2164	valid_1's rmse: 19.2406
# [6000]	training's rmse: 10.1279	valid_1's rmse: 19.2386
# [6100]	training's rmse: 10.0425	valid_1's rmse: 19.2363
# [6200]	training's rmse: 9.95948	valid_1's rmse: 19.2341
# [6300]	training's rmse: 9.87349	valid_1's rmse: 19.2311
# [6400]	training's rmse: 9.7879	valid_1's rmse: 19.229
# [6500]	training's rmse: 9.70436	valid_1's rmse: 19.2253
# [6600]	training's rmse: 9.62185	valid_1's rmse: 19.2233
# [6700]	training's rmse: 9.53954	valid_1's rmse: 19.2214
# [6800]	training's rmse: 9.45839	valid_1's rmse: 19.2209
# [6900]	training's rmse: 9.37901	valid_1's rmse: 19.2215
# [7000]	training's rmse: 9.30001	valid_1's rmse: 19.219
# [7100]	training's rmse: 9.22394	valid_1's rmse: 19.2179
# [7200]	training's rmse: 9.14558	valid_1's rmse: 19.2146
# [7300]	training's rmse: 9.0686	valid_1's rmse: 19.2127
# [7400]	training's rmse: 8.99262	valid_1's rmse: 19.2092
# [7500]	training's rmse: 8.9173	valid_1's rmse: 19.2071
# [7600]	training's rmse: 8.84586	valid_1's rmse: 19.2038
# [7700]	training's rmse: 8.77128	valid_1's rmse: 19.2025
# [7800]	training's rmse: 8.69834	valid_1's rmse: 19.202
# [7900]	training's rmse: 8.62794	valid_1's rmse: 19.2
# [8000]	training's rmse: 8.56005	valid_1's rmse: 19.1974
# [8100]	training's rmse: 8.48898	valid_1's rmse: 19.1949
# [8200]	training's rmse: 8.41868	valid_1's rmse: 19.1915
# [8300]	training's rmse: 8.35008	valid_1's rmse: 19.191
# [8400]	training's rmse: 8.28287	valid_1's rmse: 19.1885
# [8500]	training's rmse: 8.21514	valid_1's rmse: 19.188
# [8600]	training's rmse: 8.14972	valid_1's rmse: 19.1871
# [8700]	training's rmse: 8.0842	valid_1's rmse: 19.1865
# [8800]	training's rmse: 8.01792	valid_1's rmse: 19.1853
# [8900]	training's rmse: 7.95454	valid_1's rmse: 19.1841
# [9000]	training's rmse: 7.89125	valid_1's rmse: 19.183
# [9100]	training's rmse: 7.83	valid_1's rmse: 19.182
# Early stopping, best iteration is:
# [9057]	training's rmse: 7.85641	valid_1's rmse: 19.1817
#  - fold3_RMSE - 19.181703
# Training until validation scores don't improve for 100 rounds.
# [100]	training's rmse: 20.9162	valid_1's rmse: 21.335
# [200]	training's rmse: 19.8168	valid_1's rmse: 20.5163
# [300]	training's rmse: 19.2071	valid_1's rmse: 20.1757
# [400]	training's rmse: 18.7602	valid_1's rmse: 19.9846
# [500]	training's rmse: 18.3831	valid_1's rmse: 19.8558
# [600]	training's rmse: 18.0566	valid_1's rmse: 19.757
# [700]	training's rmse: 17.7641	valid_1's rmse: 19.6856
# [800]	training's rmse: 17.4808	valid_1's rmse: 19.6218
# [900]	training's rmse: 17.216	valid_1's rmse: 19.5631
# [1000]	training's rmse: 16.9687	valid_1's rmse: 19.5224
# [1100]	training's rmse: 16.7391	valid_1's rmse: 19.484
# [1200]	training's rmse: 16.5012	valid_1's rmse: 19.4457
# [1300]	training's rmse: 16.2873	valid_1's rmse: 19.4137
# [1400]	training's rmse: 16.0785	valid_1's rmse: 19.3797
# [1500]	training's rmse: 15.8768	valid_1's rmse: 19.3603
# [1600]	training's rmse: 15.6785	valid_1's rmse: 19.3364
# [1700]	training's rmse: 15.4907	valid_1's rmse: 19.3141
# [1800]	training's rmse: 15.3073	valid_1's rmse: 19.2878
# [1900]	training's rmse: 15.128	valid_1's rmse: 19.2682
# [2000]	training's rmse: 14.9507	valid_1's rmse: 19.2524
# [2100]	training's rmse: 14.785	valid_1's rmse: 19.2387
# [2200]	training's rmse: 14.6261	valid_1's rmse: 19.2248
# [2300]	training's rmse: 14.4583	valid_1's rmse: 19.2103
# [2400]	training's rmse: 14.3006	valid_1's rmse: 19.1972
# [2500]	training's rmse: 14.1455	valid_1's rmse: 19.1864
# [2600]	training's rmse: 13.9949	valid_1's rmse: 19.1725
# [2700]	training's rmse: 13.8535	valid_1's rmse: 19.1619
# [2800]	training's rmse: 13.7111	valid_1's rmse: 19.1517
# [2900]	training's rmse: 13.5687	valid_1's rmse: 19.1406
# [3000]	training's rmse: 13.4241	valid_1's rmse: 19.1293
# [3100]	training's rmse: 13.2884	valid_1's rmse: 19.121
# [3200]	training's rmse: 13.1598	valid_1's rmse: 19.1103
# [3300]	training's rmse: 13.032	valid_1's rmse: 19.103
# [3400]	training's rmse: 12.9032	valid_1's rmse: 19.0942
# [3500]	training's rmse: 12.7845	valid_1's rmse: 19.089
# [3600]	training's rmse: 12.661	valid_1's rmse: 19.0815
# [3700]	training's rmse: 12.5393	valid_1's rmse: 19.0747
# [3800]	training's rmse: 12.4222	valid_1's rmse: 19.0687
# [3900]	training's rmse: 12.3001	valid_1's rmse: 19.0604
# [4000]	training's rmse: 12.1848	valid_1's rmse: 19.0561
# [4100]	training's rmse: 12.0706	valid_1's rmse: 19.049
# [4200]	training's rmse: 11.9559	valid_1's rmse: 19.0474
# [4300]	training's rmse: 11.8417	valid_1's rmse: 19.045
# [4400]	training's rmse: 11.7305	valid_1's rmse: 19.0418
# [4500]	training's rmse: 11.6234	valid_1's rmse: 19.0365
# [4600]	training's rmse: 11.5159	valid_1's rmse: 19.0314
# [4700]	training's rmse: 11.4104	valid_1's rmse: 19.026
# [4800]	training's rmse: 11.3054	valid_1's rmse: 19.0219
# [4900]	training's rmse: 11.2019	valid_1's rmse: 19.0156
# [5000]	training's rmse: 11.1018	valid_1's rmse: 19.0088
# [5100]	training's rmse: 11.0053	valid_1's rmse: 19.0054
# [5200]	training's rmse: 10.9054	valid_1's rmse: 19.0044
# [5300]	training's rmse: 10.8111	valid_1's rmse: 19.0032
# [5400]	training's rmse: 10.7146	valid_1's rmse: 18.9995
# [5500]	training's rmse: 10.617	valid_1's rmse: 18.9988
# [5600]	training's rmse: 10.524	valid_1's rmse: 18.9932
# [5700]	training's rmse: 10.4321	valid_1's rmse: 18.9916
# Early stopping, best iteration is:
# [5634]	training's rmse: 10.4921	valid_1's rmse: 18.9909
#  - fold4_RMSE - 18.990855
# Training until validation scores don't improve for 100 rounds.
# [100]	training's rmse: 20.9703	valid_1's rmse: 21.0012
# [200]	training's rmse: 19.8564	valid_1's rmse: 20.1836
# [300]	training's rmse: 19.2514	valid_1's rmse: 19.8727
# [400]	training's rmse: 18.7981	valid_1's rmse: 19.6779
# [500]	training's rmse: 18.4251	valid_1's rmse: 19.564
# [600]	training's rmse: 18.0869	valid_1's rmse: 19.4671
# [700]	training's rmse: 17.7875	valid_1's rmse: 19.3923
# [800]	training's rmse: 17.5098	valid_1's rmse: 19.3255
# [900]	training's rmse: 17.2454	valid_1's rmse: 19.2649
# [1000]	training's rmse: 16.9988	valid_1's rmse: 19.2139
# [1100]	training's rmse: 16.7641	valid_1's rmse: 19.1751
# [1200]	training's rmse: 16.5348	valid_1's rmse: 19.1433
# [1300]	training's rmse: 16.3175	valid_1's rmse: 19.1096
# [1400]	training's rmse: 16.103	valid_1's rmse: 19.0799
# [1500]	training's rmse: 15.9018	valid_1's rmse: 19.0505
# [1600]	training's rmse: 15.7008	valid_1's rmse: 19.0239
# [1700]	training's rmse: 15.5096	valid_1's rmse: 19
# [1800]	training's rmse: 15.32	valid_1's rmse: 18.9772
# [1900]	training's rmse: 15.1398	valid_1's rmse: 18.9567
# [2000]	training's rmse: 14.97	valid_1's rmse: 18.9396
# [2100]	training's rmse: 14.7985	valid_1's rmse: 18.9232
# [2200]	training's rmse: 14.6328	valid_1's rmse: 18.9121
# [2300]	training's rmse: 14.4734	valid_1's rmse: 18.8986
# [2400]	training's rmse: 14.3181	valid_1's rmse: 18.8895
# [2500]	training's rmse: 14.1629	valid_1's rmse: 18.8795
# [2600]	training's rmse: 14.0144	valid_1's rmse: 18.868
# [2700]	training's rmse: 13.8653	valid_1's rmse: 18.8539
# [2800]	training's rmse: 13.7221	valid_1's rmse: 18.8475
# [2900]	training's rmse: 13.5805	valid_1's rmse: 18.8381
# [3000]	training's rmse: 13.4435	valid_1's rmse: 18.8305
# [3100]	training's rmse: 13.3071	valid_1's rmse: 18.8203
# [3200]	training's rmse: 13.1751	valid_1's rmse: 18.8133
# [3300]	training's rmse: 13.0463	valid_1's rmse: 18.8031
# [3400]	training's rmse: 12.9121	valid_1's rmse: 18.801
# [3500]	training's rmse: 12.7875	valid_1's rmse: 18.794
# [3600]	training's rmse: 12.6616	valid_1's rmse: 18.7872
# [3700]	training's rmse: 12.5422	valid_1's rmse: 18.7796
# [3800]	training's rmse: 12.4192	valid_1's rmse: 18.7753
# [3900]	training's rmse: 12.2996	valid_1's rmse: 18.7686
# [4000]	training's rmse: 12.1813	valid_1's rmse: 18.7631
# [4100]	training's rmse: 12.0653	valid_1's rmse: 18.757
# [4200]	training's rmse: 11.9526	valid_1's rmse: 18.7521
# [4300]	training's rmse: 11.8442	valid_1's rmse: 18.7496
# [4400]	training's rmse: 11.734	valid_1's rmse: 18.7494
# [4500]	training's rmse: 11.6256	valid_1's rmse: 18.7427
# [4600]	training's rmse: 11.5174	valid_1's rmse: 18.7402
# [4700]	training's rmse: 11.4099	valid_1's rmse: 18.7373
# [4800]	training's rmse: 11.3049	valid_1's rmse: 18.7305
# [4900]	training's rmse: 11.2001	valid_1's rmse: 18.7284
# [5000]	training's rmse: 11.101	valid_1's rmse: 18.726
# [5100]	training's rmse: 11.0007	valid_1's rmse: 18.7202
# [5200]	training's rmse: 10.902	valid_1's rmse: 18.7155
# [5300]	training's rmse: 10.8037	valid_1's rmse: 18.7124
# [5400]	training's rmse: 10.7119	valid_1's rmse: 18.7088
# [5500]	training's rmse: 10.6214	valid_1's rmse: 18.7095
# Early stopping, best iteration is:
# [5438]	training's rmse: 10.678	valid_1's rmse: 18.7082
#  - fold5_RMSE - 18.708205
#  - CV_RMSE - 18.938598

# %%
def visualize_importance(models, feat_train_df, file_name):
    
    feature_importance_df = pd.DataFrame()

    for i, model in enumerate(models):
        _df = pd.DataFrame()
        _df['feature_importance'] = model.feature_importance(importance_type='gain')
        _df['column'] = feat_train_df.columns
        _df['fold'] = i + 1
        feature_importance_df = pd.concat([feature_importance_df, _df],
                                          axis=0,
                                          ignore_index=True
                                         )
    
    mean_feature_importance = feature_importance_df.groupby('column').mean().sort_values('feature_importance', ascending=False)
    mean_feature_importance.to_csv(os.path.join(Output_Model, f'feature_importance_{file_name}.csv'), index=True)
    
    order = feature_importance_df.groupby('column')\
        .sum()[['feature_importance']]\
        .sort_values('feature_importance', ascending=False).index[:100]
    
    fig, ax = plt.subplots(figsize=(12, max(8, len(order) * 0.25)))
    sns.boxenplot(data=feature_importance_df,
                  x='feature_importance',
                  y='column',
                  order=order,
                  ax=ax,
                  palette='viridis',
                  orient='h'
                 )
    ax.tick_params(axis='x', rotation=90)
    ax.set_title('Importance')
    ax.grid()
    fig.tight_layout()
    
    return fig, ax

# %%
_ = visualize_importance(lgb_models1, df_train, 'lgb_model')

# %%
def predict_test(models, df):
    out = np.array([model.predict(df) for model in models])
    out = np.mean(out, axis=0)
    
    return out

# %%
pred_test = predict_test(lgb_models1, df_test)

# %%
y_true = target
min_values = y_true.min()
pred_test[pred_test<min_values] = min_values

# %%
#check distribution of train and test_pred data
def plot_prediction_distribution(y_true, y_pred, y_test):
    fig, ax = plt.subplots(figsize=(18, 6))
    sns.histplot(y_test, label='Test Predict', ax=ax, color='black', stat='density')
    sns.histplot(y_pred, label='Out Of Fold', ax=ax, color='C1', stat='density', alpha=0.5)
    sns.histplot(y_true, label='True Value', ax=ax, color='blue', stat='density', alpha=0.5)
    ax.legend()
    ax.grid()

# %%
plot_prediction_distribution(target, oof_valid_lgb1, pred_test)

# %%
submission = pd.read_csv(os.path.join(Input, 'submit_sample.csv'), header=None)
submission.iloc[:, 1] = pred_test
submission

# %%
submission.to_csv(os.path.join(Submission, 'sub.csv'), index=False)

# %%
#sub74は相対湿度とかいれたやつ
