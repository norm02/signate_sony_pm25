# %%
#sub49のnotebook

# %%
#!pip install optuna

# %%
# !pip install category_encoders
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting category_encoders
#   Downloading category_encoders-2.4.1-py2.py3-none-any.whl (80 kB)
#      |████████████████████████████████| 80 kB 2.2 MB/s
# Requirement already satisfied: scipy>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from category_encoders) (1.4.1)
# Requirement already satisfied: numpy>=1.14.0 in /usr/local/lib/python3.7/dist-packages (from category_encoders) (1.21.6)
# Requirement already satisfied: patsy>=0.5.1 in /usr/local/lib/python3.7/dist-packages (from category_encoders) (0.5.2)
# Requirement already satisfied: statsmodels>=0.9.0 in /usr/local/lib/python3.7/dist-packages (from category_encoders) (0.10.2)
# Requirement already satisfied: scikit-learn>=0.20.0 in /usr/local/lib/python3.7/dist-packages (from category_encoders) (1.0.2)
# Requirement already satisfied: pandas>=0.21.1 in /usr/local/lib/python3.7/dist-packages (from category_encoders) (1.3.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.21.1->category_encoders) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.21.1->category_encoders) (2022.1)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from patsy>=0.5.1->category_encoders) (1.15.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.20.0->category_encoders) (3.1.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.20.0->category_encoders) (1.1.0)
# Installing collected packages: category-encoders
# Successfully installed category-encoders-2.4.1

# %%
# !pip install pyproj
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pyproj
#   Downloading pyproj-3.2.1-cp37-cp37m-manylinux2010_x86_64.whl (6.3 MB)
#      |████████████████████████████████| 6.3 MB 5.0 MB/s
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from pyproj) (2022.5.18.1)
# Installing collected packages: pyproj
# Successfully installed pyproj-3.2.1

# %%
# !pip install utm
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting utm
#   Downloading utm-0.7.0.tar.gz (8.7 kB)
# Building wheels for collected packages: utm
#   Building wheel for utm (setup.py) ... done
#   Created wheel for utm: filename=utm-0.7.0-py3-none-any.whl size=6108 sha256=71c3ecfe62065262b5cdb367bed8895189878a5c9999083ab34601fb8e1aebe3
#   Stored in directory: /root/.cache/pip/wheels/a5/b0/12/7ee4fdb0f9fbb4157100bd02390436ed5d58ebfd3c6d6a0886
# Successfully built utm
# Installing collected packages: utm
# Successfully installed utm-0.7.0

# %%
# !pip install crs
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting crs
#   Downloading crs-0.1.1-py2.py3-none-any.whl (4.1 kB)
# Requirement already satisfied: gdal in /usr/local/lib/python3.7/dist-packages (from crs) (2.2.2)
# Requirement already satisfied: pyproj in /usr/local/lib/python3.7/dist-packages (from crs) (3.2.1)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from crs) (1.15.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from pyproj->crs) (2022.5.18.1)
# Installing collected packages: crs
# Successfully installed crs-0.1.1

# %%
class config:
    run_type = 'colab'
    random_seed = 2022
    nfold = 5
    target = 'pm25_mid'

# %%
import os
import re
from IPython.lib import kernel
from requests import get

if config.run_type == 'colab':
    from google.colab import drive, files
    
    drive.mount('/content/drive')
    #ご自身のフォルダパスを指定
    Drive = "/content/drive/My Drive/python/sony/"
    Exp = get('http://172.28.0.2:9000/api/sessions').json()[0]['name'][:-6]
    Exp = re.sub('.ip', '', Exp)
        
Input = os.path.join(Drive, 'input')
Output = os.path.join(Drive, 'output')
Output_Exp = os.path.join(Output, Exp)
Output_Model = os.path.join(Output_Exp, "model")
Output_Preds = os.path.join(Output_Exp, "preds")
Output_Feats = os.path.join(Output_Exp, "feats")

Submission = os.path.join(Drive, "submission")

dirs = [Output_Model, Output_Preds, Output_Feats]
for d in dirs:
    if not os.path.isdir(d):
        os.makedirs(d, exist_ok=True)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import joblib
import gc
from scipy.spatial.distance import pdist
from scipy.spatial.distance import squareform
import datetime

from sklearn.model_selection import KFold, GroupKFold
from sklearn.metrics import mean_squared_error

from category_encoders.target_encoder import TargetEncoder 

import lightgbm as lgb
#import optuna.integration.lightgbm as opt_lgb

pd.set_option('max_rows', 400)
pd.set_option('max_columns', 100)
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
train_data = pd.read_csv(os.path.join(Input, 'train.csv'))\
               .assign(timestamp=lambda d: pd.to_datetime(d['year'].astype(str) + '-' + d['month'].astype(str) + '-' + d['day'].astype(str)))
test_data = pd.read_csv(os.path.join(Input, 'test.csv'))\
               .assign(timestamp=lambda d: pd.to_datetime(d['year'].astype(str) + '-' + d['month'].astype(str) + '-' + d['day'].astype(str)))

# %%
df_all = pd.concat([train_data,test_data],sort=False)

# %%
import utm
from pyproj import Proj
import crs as CRS

lon = df_all['lon']
lat = df_all['lat']

df = pd.DataFrame({'lng': lon, 'lat': lat})

list_utm = []
xy_meters = [utm.from_latlon(lat,long) for (lat, long) in zip(df['lat'],df['lng'])]
for row in xy_meters:
    list_utm.append(row[2:4])

'''
list_utm = []
for lat,lon in zip(df['lat'], df['lon']):
    e2u_zone=int(divmod(lat, 6)[0])+31
    e2u_conv=Proj(proj='utm', zone=e2u_zone, ellps='WGS84')
   
    utmx, utmy=e2u_conv(lat, lon)
    list_utm.append(e2u_zone)

if lat<0:
    utmy=utmy+10000000

print(" UTM zone is ", e2u_zone, " \n", \
      "UTM Easting is", utmx, "[m]\n",\
      "UTM Northing is ", utmy, "[m]")
'''
# Out:
# '\nlist_utm = []\nfor lat,lon in zip(df[\'lat\'], df[\'lon\']):\n    e2u_zone=int(divmod(lat, 6)[0])+31\n    e2u_conv=Proj(proj=\'utm\', zone=e2u_zone, ellps=\'WGS84\')\n   \n    utmx, utmy=e2u_conv(lat, lon)\n    list_utm.append(e2u_zone)\n\nif lat<0:\n    utmy=utmy+10000000\n\nprint(" UTM zone is ", e2u_zone, " \n",       "UTM Easting is", utmx, "[m]\n",      "UTM Northing is ", utmy, "[m]")\n'

# %%
print(list_utm)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
lst = list_utm
df_zone = pd.DataFrame(lst, columns = ['utm_zone_x','utm_zone_y'])

# %%
df_zone.to_csv('drive/My Drive/python/sony/input/zone.csv', index=False)

# %%
df_all = df_all.reset_index()

# %%
df_all = pd.concat([df_all, df_zone], axis=1)
df_all = df_all.drop('index',axis=1)

# %%
df_all['utm_zone'] = (df_all['utm_zone_x']).astype(str) + df_all['utm_zone_y']

# %%
print(df_all)
# Out:
#             id  year  month  day         Country       City       lat  \
# 0            1  2019      1    1       Australia   Brisbane -27.46794
# 1            2  2019      1    1       Australia     Darwin -12.46113
# 2            3  2019      1    1       Australia  Melbourne -37.81400
# 3            4  2019      1    1       Australia  Newcastle -32.92953
# 4            5  2019      1    1       Australia      Perth -31.95224
# ...        ...   ...    ...  ...             ...        ...       ...
# 249445  249446  2021     12   31          Turkey      Adana  36.98615
# 249446  249447  2021     12   31          Turkey      Bursa  40.19559
# 249447  249448  2021     12   31          Turkey    Trabzon  41.00500
# 249448  249449  2021     12   31  United Kingdom     London  51.50853
# 249449  249450  2021     12   31         Vietnam   Haiphong  20.86481
#
#               lon  co_cnt  co_min  co_mid  co_max  co_var  o3_cnt  o3_min  \
# 0       153.02809      38   0.749   2.590   2.633   0.850      29   2.397
# 1       130.84185      47   2.594   3.181   4.828   1.208      49   3.092
# 2       144.96332      17   1.190   1.197   2.200   0.248     123   0.736
# 3       151.78010      63   4.586  11.044  14.802  24.186      90   1.917
# 4       115.86140      47   4.689   8.681  11.100  10.011      83   0.349
# ...           ...     ...     ...     ...     ...     ...     ...     ...
# 249445   35.32531      97   4.674   9.034  14.650  23.900      90  11.798
# 249446   29.06013     123  17.621  18.156  21.877   4.390     116   0.882
# 249447   39.72694     150   0.128  14.275  21.124   0.315     108   0.476
# 249448   -0.12574      21   0.057   0.111   2.088   0.988      54   0.301
# 249449  106.68345      47   0.060   0.071   0.136   0.000     134   9.491
#
#         o3_mid  o3_max   o3_var  so2_cnt  so2_min  so2_mid  so2_max  so2_var  \
# 0        4.295   5.916    3.017       11    0.149    0.468    0.900    0.137
# 1        7.572  12.332   20.524       31    0.096    0.102   16.152   61.550
# 2       12.527  23.432  125.224       36    1.392    1.464   47.652  515.570
# 3       14.141  38.374  304.731       50    2.957    3.230   14.056   25.630
# 4        2.349  38.600  353.549       47    0.422    5.794    9.972    9.234
# ...        ...     ...      ...      ...      ...      ...      ...      ...
# 249445  21.871  28.693   67.294       88    3.699    7.816   44.080  391.178
# 249446   6.559  14.794   46.421      109    4.295    8.558   59.418  706.550
# 249447   9.539  33.956  175.614      100    0.074    2.970    7.959   14.297
# 249448   2.029  24.479  138.410       40    0.230    0.478    0.884    0.102
# 249449  19.852  24.678   55.554       19    1.544    2.441    6.277    5.352
#
#         no2_cnt  no2_min  no2_mid  no2_max  no2_var  temperature_cnt  \
# 0            36    0.000    0.529    2.188    1.167               36
# 1            45    0.099    0.301    5.411    6.401               71
# 2           111    0.972    2.751   12.230   30.518              148
# 3           176   14.959   17.471   24.221   20.883              101
# 4            80   14.911   21.140   32.584   74.298               55
# ...         ...      ...      ...      ...      ...              ...
# 249445       83    0.829    5.287   42.481  417.102               92
# 249446      104    8.884   14.335   30.304  111.588              112
# 249447      263    2.800   10.818   32.341  208.883              202
# 249448       77    1.326    9.441    9.838   17.650              111
# 249449       44    1.153    8.646   14.952   44.975              427
#
#         temperature_min  temperature_mid  temperature_max  temperature_var  \
# 0                10.956           14.038           20.866           23.880
# 1                24.113           30.125           36.678           37.327
# 2                 0.000            0.000           23.226          131.280
# 3                16.423           19.819           20.044            3.188
# 4                10.297           11.822           13.377            2.311
# ...                 ...              ...              ...              ...
# 249445            8.354           12.533           18.784           26.241
# 249446            5.241            9.273           11.543            9.674
# 249447            6.784           12.701           16.167           21.408
# 249448           10.690           16.795           18.424           14.548
# 249449           20.111           25.368           28.187           15.394
#
#         humidity_cnt  humidity_min  humidity_mid  humidity_max  humidity_var  \
# 0                 45        30.207        70.426        94.202       994.051
# 1                 50        49.034        74.276        92.975       467.112
# 2                138        25.919        69.069       100.000      1292.191
# 3                111        73.504        86.920       100.000        85.028
# 4                155        51.918        76.736        96.533       484.188
# ...              ...           ...           ...           ...           ...
# 249445            94        34.495        47.605        73.066       352.286
# 249446           118        71.775        83.258       100.000       190.221
# 249447           112        43.466        75.428        87.317       466.464
# 249448            66        44.049        84.531        94.643       603.074
# 249449           107        63.503        83.249        94.011       223.148
#
#         pressure_cnt  pressure_min  pressure_mid  pressure_max  pressure_var  \
# 0                 59      1004.137      1015.721      1023.398        89.588
# 1                 69       938.085       970.252      1080.000         7.320
# 2                153       880.000       880.000      1018.200      4655.348
# 3                141      1011.703      1016.545      1018.364        10.898
# 4                124      1019.521      1022.992      1027.611        15.142
# ...              ...           ...           ...           ...           ...
# 249445            95       914.666       963.444      1080.000         3.863
# 249446           105       989.638      1008.551      1024.879        35.258
# 249447           111      1002.984      1009.004      1025.333        37.266
# 249448           118      1012.094      1019.240      1024.880        28.607
# 249449           280      1005.977      1008.091      1013.454         8.356
#
#         ws_cnt  ws_min  ws_mid  ws_max  ws_var  dew_cnt  dew_min  dew_mid  \
# 0           42   0.241   1.088   3.101   1.983       17    7.671   10.358
# 1           48   0.828   3.473   7.396  10.411       62   21.324   23.813
# 2          125   0.000   2.107   8.089  15.719       22   10.309   13.133
# 3           52   0.284   0.503   3.592   2.485      116    7.146   10.685
# 4          102   0.500   0.755   3.396   1.937       93    1.091    3.277
# ...        ...     ...     ...     ...     ...      ...      ...      ...
# 249445      93   0.201   2.878   7.397  12.130       86    0.451    3.112
# 249446     114   0.473   1.491   2.974   1.468      115    3.894    6.823
# 249447     179   1.001   3.605   5.040   3.965       12    5.269    8.772
# 249448      41   0.077   0.803   3.884   3.268       34   10.906   10.959
# 249449     178   0.105   2.931  15.303  22.760       58    9.825   15.037
#
#         dew_max  dew_var  pm25_mid  timestamp  utm_zone_x utm_zone_y utm_zone
# 0        15.112   13.424    19.901 2019-01-01          56          J      56J
# 1        24.221    2.021    13.741 2019-01-01          52          L      52L
# 2        15.422    6.355    25.918 2019-01-01          55          H      55H
# 3        13.344    9.417   174.370 2019-01-01          56          H      56H
# 4        12.272    4.109   167.063 2019-01-01          50          J      50J
# ...         ...      ...       ...        ...         ...        ...      ...
# 249445    4.512    3.938       NaN 2021-12-31          36          S      36S
# 249446    6.861    2.145       NaN 2021-12-31          35          T      35T
# 249447   12.661   13.201       NaN 2021-12-31          37          T      37T
# 249448   12.744    0.822       NaN 2021-12-31          30          U      30U
# 249449   22.294   11.189       NaN 2021-12-31          48          Q      48Q
#
# [249450 rows x 58 columns]

# %%
train_data = df_all.iloc[:len(train_data)]
test_data = df_all.iloc[len(train_data):].reset_index(drop=True)

# %%
def make_corr_array(df, cols):
    output = pd.DataFrame(1 - squareform(pdist(df[cols].T, 'correlation')),
                          columns=cols, index=cols)
    return output

# %%
corr_df = make_corr_array(train_data, [c for c in train_data.columns if re.search(r'mid|min|max|cnt|var|lat|lon', c)])

# %%
corr_top10 = corr_df.loc[:, ['pm25_mid']].assign(abs_value=lambda d: np.abs(d['pm25_mid']))\
                    .sort_values('abs_value', ascending=False)\
                    .iloc[1:11, :].index.tolist()

# %%
class AbstractBaseBlock:
    def fit(self, input_df: pd.DataFrame, y=None):
        return self.transform(input_df)
    
    def transform(self, input_df: pd.DataFrame) -> pd.DataFrame:
        raise NotImplementedError()

# %%
class NumericFeatBlock(AbstractBaseBlock):
    def __init__(self, col: str):
        self.col = col
        
    def fit(self, input_df, y=None):
        pass
        
    def transform(self, input_df):
        return input_df.loc[:, self.col]

# %%
class CategoricalFeatBlock(AbstractBaseBlock):
    def __init__(self, col: str, whole_df = None, threshold=0.001, is_label=True, is_dummy=False):
        self.col = col
        self.whole_df = whole_df
        self.threshold = threshold
        self.is_label = is_label
        self.is_dummy = is_dummy
    
    def fit(self, input_df, y=None):
        if self.whole_df == None:
            df = input_df.loc[:, self.col]
        else:
            df = self.whole_df.loc[:, self.col]
        vc = df.value_counts(normalize=True).reset_index()
        vc = vc.assign(thresh=lambda d: np.where(d[self.col].values >= self.threshold, 1, 0))\
               .assign(thresh=lambda d: d['thresh'].cumsum() - d['thresh'])
        self.label_dict_ = dict(vc[['index', 'thresh']].values)
        self.label_other_ = np.max(self.label_dict_.values())
        
        return self.transform(input_df)
        
    def transform(self, input_df):
        out_df = pd.DataFrame()
        label_df = pd.DataFrame()
        label_df[f'{self.col}_label_enc'] = np.vectorize(lambda x: self.label_dict_.get(x, self.label_other_))\
                                                        (input_df[self.col].values)
        if self.is_label:
            out_df = pd.concat([out_df, label_df], axis=1)
            
        if self.is_dummy:
            label_df[f'{self.col}_label_enc'] = label_df[f'{self.col}_label_enc'].astype(object)
            out_df = pd.concat([out_df, pd.get_dummies(label_df)], axis=1)
        
        return out_df

# %%
class DateFeatureBlock(AbstractBaseBlock):
    def __init__(self, is_get_weekday=True):
        self.is_get_weekday = is_get_weekday
        
    def fit(self, input_df, y=None):
        pass
        
    def transform(self, input_df):
        out_df = pd.DataFrame()
        out_df = input_df[['year', 'month', 'day']]
        if self.is_get_weekday:
            out_df = out_df.assign(weekday=[x.dayofweek for x in input_df['timestamp'].tolist()])
        
        return out_df

# %%
class AggregateValueBlock(AbstractBaseBlock):
    def __init__(self, key_col, agg_dict, whole_df=None):
        self.key_col = key_col
        self.agg_dict = agg_dict
        self.whole_df = whole_df
        
    def fit(self, input_df, y=None):
        if self.whole_df == None:
            df = input_df
        else:
            df = self.whole_df
        agg_df = df.groupby(self.key_col).agg(self.agg_dict)
        agg_df.columns = ['_'.join(c) for c in agg_df.columns]
        self.agg_df_ = agg_df.add_prefix('_')\
                             .add_prefix('_'.join(self.key_col))\
                             .add_prefix('agg_').reset_index()
        
        return self.transform(input_df)
    
    def transform(self, input_df):
        out_df = pd.DataFrame()
        out_df = pd.merge(input_df[self.key_col], self.agg_df_, how='left', on=self.key_col)\
                   .drop(self.key_col, axis=1)\
                   .fillna(0)
        
        return out_df

# %%
numeric_columns = [c for c in train_data.columns if re.search(r'max|mid|min|cnt|var|lat|lon', c) and not re.search(r'pm25', c)]
categorical_columns = ['Country','utm_zone']
agg_country_value = dict([(c, [np.mean, np.max, np.min, np.std, np.var]) for c in corr_top10])

# %%
run_blocks = [
    *[NumericFeatBlock(c) for c in [numeric_columns]],
    *[CategoricalFeatBlock(c) for c in categorical_columns],
    *[DateFeatureBlock()],
    *[AggregateValueBlock(['utm_zone', 'month'], agg_country_value)],    
]

# %%
def get_train_data(input_df, feat_blocks, y=None, fit_df=None):
    if fit_df is None:
        fit_df = input_df.copy()
        
    for block in feat_blocks:
        block.fit(fit_df, y)
        
    out = [block.transform(input_df) for block in feat_blocks]
    out = pd.concat(out, axis=1)
    
    return out

def get_test_data(input_df, feat_blocks):
    
    out = [block.transform(input_df) for block in feat_blocks]
    out = pd.concat(out, axis=1)
    
    return out

# %%
df_train = get_train_data(train_data, run_blocks, fit_df=pd.concat([train_data, test_data], ignore_index=True))
df_train
# Out:
#              lat        lon  co_cnt  co_min  co_mid  co_max  co_var  o3_cnt  \
# 0      -27.46794  153.02809      38   0.749   2.590   2.633   0.850      29
# 1      -12.46113  130.84185      47   2.594   3.181   4.828   1.208      49
# 2      -37.81400  144.96332      17   1.190   1.197   2.200   0.248     123
# 3      -32.92953  151.78010      63   4.586  11.044  14.802  24.186      90
# 4      -31.95224  115.86140      47   4.689   8.681  11.100  10.011      83
# ...          ...        ...     ...     ...     ...     ...     ...     ...
# 195936  30.33218  -81.65565      12   0.694   0.995   1.301   0.090      26
# 195937  36.17497 -115.13722      14   0.528   1.256   3.226   1.743       8
# 195938  43.03890  -87.90647     171   1.975   6.627   6.639   5.293     112
# 195939  21.02450  105.84117      31   2.613   2.704   8.767   4.317     108
# 195940  20.95045  107.07336      26   0.069   0.120   0.184   0.003      20
#
#         o3_min  o3_mid  o3_max   o3_var  so2_cnt  so2_min  so2_mid  so2_max  \
# 0        2.397   4.295   5.916    3.017       11    0.149    0.468    0.900
# 1        3.092   7.572  12.332   20.524       31    0.096    0.102   16.152
# 2        0.736  12.527  23.432  125.224       36    1.392    1.464   47.652
# 3        1.917  14.141  38.374  304.731       50    2.957    3.230   14.056
# 4        0.349   2.349  38.600  353.549       47    0.422    5.794    9.972
# ...        ...     ...     ...      ...      ...      ...      ...      ...
# 195936   6.859   9.295  25.886   87.688        8    0.257    1.088    1.511
# 195937   4.435   7.450  23.110   84.730        9    0.288    0.671    1.292
# 195938   4.613   7.397  37.550   71.355      120    0.420    2.915    6.504
# 195939  12.694  15.474  37.831  149.726       27    0.702    2.538    4.193
# 195940   3.119   3.140  27.941  147.380       10    0.676    0.841    0.890
#
#         so2_var  no2_cnt  no2_min  no2_mid  no2_max  no2_var  temperature_cnt  \
# 0         0.137       36    0.000    0.529    2.188    1.167               36
# 1        61.550       45    0.099    0.301    5.411    6.401               71
# 2       515.570      111    0.972    2.751   12.230   30.518              148
# 3        25.630      176   14.959   17.471   24.221   20.883              101
# 4         9.234       80   14.911   21.140   32.584   74.298               55
# ...         ...      ...      ...      ...      ...      ...              ...
# 195936    0.376       26    0.000    1.071    1.148    0.180               40
# 195937    0.241       31    0.674    1.176    6.967    5.398               51
# 195938    4.479       66    2.668    4.844   34.490  141.786              170
# 195939    2.884      149    1.986    6.741   26.674  143.871              290
# 195940    0.011       51    0.885   12.055   25.679  149.594               55
#
#         temperature_min  temperature_mid  temperature_max  temperature_var  \
# 0                10.956           14.038           20.866           23.880
# 1                24.113           30.125           36.678           37.327
# 2                 0.000            0.000           23.226          131.280
# 3                16.423           19.819           20.044            3.188
# 4                10.297           11.822           13.377            2.311
# ...                 ...              ...              ...              ...
# 195936           22.355           27.235           28.335            8.710
# 195937           12.548           18.251           27.369           52.741
# 195938            1.574            5.054           15.515           45.069
# 195939            4.288            5.839           18.179           20.939
# 195940           19.866           24.896           27.725           15.020
#
#         humidity_cnt  humidity_min  humidity_mid  humidity_max  humidity_var  \
# 0                 45        30.207        70.426        94.202       994.051
# 1                 50        49.034        74.276        92.975       467.112
# 2                138        25.919        69.069       100.000      1292.191
# 3                111        73.504        86.920       100.000        85.028
# 4                155        51.918        76.736        96.533       484.188
# ...              ...           ...           ...           ...           ...
# 195936            48        58.021        88.372        99.875       425.264
# 195937            55        26.446        48.434        84.894       817.475
# 195938            91        48.625        75.506        80.429       245.963
# 195939           260        74.620        78.477        92.574        78.444
# 195940            71        73.216        83.655        99.708       162.663
#
#         pressure_cnt  pressure_min  pressure_mid  pressure_max  pressure_var  \
# 0                 59      1004.137      1015.721      1023.398        89.588
# 1                 69       938.085       970.252      1080.000         7.320
# 2                153       880.000       880.000      1018.200      4655.348
# 3                141      1011.703      1016.545      1018.364        10.898
# 4                124      1019.521      1022.992      1027.611        15.142
# ...              ...           ...           ...           ...           ...
# 195936            55      1006.476      1008.095      1016.593        17.690
# 195937            67      1001.251      1014.241      1016.000        26.348
# 195938           194      1014.899      1028.344      1028.429         9.313
# 195939           293      1013.957      1027.707      1034.228        25.054
# 195940            70      1008.326      1019.149      1021.731        42.129
#
#         ws_cnt  ws_min  ws_mid  ws_max  ws_var  dew_cnt  dew_min  dew_mid  \
# 0           42   0.241   1.088   3.101   1.983       17    7.671   10.358
# 1           48   0.828   3.473   7.396  10.411       62   21.324   23.813
# 2          125   0.000   2.107   8.089  15.719       22   10.309   13.133
# 3           52   0.284   0.503   3.592   2.485      116    7.146   10.685
# 4          102   0.500   0.755   3.396   1.937       93    1.091    3.277
# ...        ...     ...     ...     ...     ...      ...      ...      ...
# 195936      22   2.195   2.710   6.125   3.757       12   16.774   22.679
# 195937      51   1.002   2.974   6.861   8.354       12   10.432   14.741
# 195938     125   0.994   1.087   2.578   0.612       26    2.049    3.531
# 195939     266   1.005   3.058   6.005   6.085       51    1.922    7.443
# 195940      32   0.190   2.775   3.412   2.528       16    8.448   10.372
#
#         dew_max  dew_var  Country_label_enc  utm_zone_label_enc  year  ...  \
# 0        15.112   13.424                 10                  59  2019  ...
# 1        24.221    2.021                 10                  53  2019  ...
# 2        15.422    6.355                 10                  56  2019  ...
# 3        13.344    9.417                 10                  30  2019  ...
# 4        12.272    4.109                 10                  63  2019  ...
# ...         ...      ...                ...                 ...   ...  ...
# 195936   26.058   13.252                  5                  72  2021  ...
# 195937   15.827    7.078                  5                  29  2021  ...
# 195938    6.686    5.286                  5                  42  2021  ...
# 195939    7.716    4.642                 22                  31  2021  ...
# 195940   18.886   11.536                 22                  31  2021  ...
#
#         agg_utm_zone_month_no2_mid_mean  agg_utm_zone_month_no2_mid_amax  \
# 0                              5.485395                           24.112
# 1                              4.206364                           25.041
# 2                              6.837213                           26.216
# 3                              8.330089                           31.153
# 4                              6.787493                           21.958
# ...                                 ...                              ...
# 195936                         6.642597                           28.019
# 195937                        12.780958                           49.931
# 195938                         9.679037                           32.128
# 195939                        11.745539                           32.873
# 195940                        11.745539                           32.873
#
#         agg_utm_zone_month_no2_mid_amin  agg_utm_zone_month_no2_mid_std  \
# 0                                 0.095                        6.136965
# 1                                 0.185                        6.400461
# 2                                 0.575                        5.382525
# 3                                 0.932                        6.457191
# 4                                 0.141                        5.476225
# ...                                 ...                             ...
# 195936                            0.930                        4.462963
# 195937                            0.986                        9.658499
# 195938                            1.091                        5.088022
# 195939                            0.408                        6.495702
# 195940                            0.408                        6.495702
#
#         agg_utm_zone_month_no2_mid_var  agg_utm_zone_month_co_mid_mean  \
# 0                            37.662337                        2.113803
# 1                            40.965900                        3.815584
# 2                            28.971580                        3.343467
# 3                            41.695320                        3.726747
# 4                            29.989038                        3.174014
# ...                                ...                             ...
# 195936                       19.918036                        4.182750
# 195937                       93.286602                        3.646288
# 195938                       25.887965                        3.358944
# 195939                       42.194143                        4.323143
# 195940                       42.194143                        4.323143
#
#         agg_utm_zone_month_co_mid_amax  agg_utm_zone_month_co_mid_amin  \
# 0                               17.932                           0.060
# 1                               18.424                           0.040
# 2                               20.272                           0.079
# 3                               18.124                           0.077
# 4                               14.287                           0.062
# ...                                ...                             ...
# 195936                           9.563                           0.038
# 195937                          18.567                           0.025
# 195938                          11.057                           0.074
# 195939                          12.386                           0.053
# 195940                          12.386                           0.053
#
#         agg_utm_zone_month_co_mid_std  agg_utm_zone_month_co_mid_var  \
# 0                            3.033226                       9.200458
# 1                            2.553271                       6.519191
# 2                            3.644677                      13.283667
# 3                            2.994160                       8.964996
# 4                            2.963477                       8.782194
# ...                               ...                            ...
# 195936                       2.349844                       5.521767
# 195937                       3.316641                      11.000109
# 195938                       1.971838                       3.888144
# 195939                       3.063893                       9.387442
# 195940                       3.063893                       9.387442
#
#         agg_utm_zone_month_no2_max_mean  agg_utm_zone_month_no2_max_amax  \
# 0                             14.511776                           67.282
# 1                             11.410584                           44.871
# 2                             19.742267                           55.427
# 3                             22.187416                           65.972
# 4                             17.494913                           49.353
# ...                                 ...                              ...
# 195936                        17.060611                           46.108
# 195937                        29.148051                           88.641
# 195938                        25.144731                           71.604
# 195939                        32.203755                          107.800
# 195940                        32.203755                          107.800
#
#         agg_utm_zone_month_no2_max_amin  agg_utm_zone_month_no2_max_std  \
# 0                                 0.096                       14.089122
# 1                                 0.810                       13.269352
# 2                                 0.841                       12.846495
# 3                                 2.905                       11.291320
# 4                                 1.027                       11.403412
# ...                                 ...                             ...
# 195936                            1.148                       10.819188
# 195937                            3.760                       16.579792
# 195938                            3.161                       12.106215
# 195939                            2.377                       19.022846
# 195940                            2.377                       19.022846
#
#         agg_utm_zone_month_no2_max_var  agg_utm_zone_month_no2_min_mean  \
# 0                           198.503345                         1.905000
# 1                           176.075704                         1.626792
# 2                           165.032445                         2.224493
# 3                           127.493916                         3.292168
# 4                           130.037814                         2.544957
# ...                                ...                              ...
# 195936                      117.054823                         2.003000
# 195937                      274.889499                         3.834465
# 195938                      146.560439                         3.082744
# 195939                      361.868687                         4.322363
# 195940                      361.868687                         4.322363
#
#         agg_utm_zone_month_no2_min_amax  agg_utm_zone_month_no2_min_amin  \
# 0                                17.962                            0.000
# 1                                16.674                            0.000
# 2                                 9.103                            0.000
# 3                                17.709                            0.000
# 4                                14.911                            0.000
# ...                                 ...                              ...
# 195936                           10.429                            0.000
# 195937                           31.114                            0.098
# 195938                            9.207                            0.000
# 195939                           16.456                            0.284
# 195940                           16.456                            0.284
#
#         agg_utm_zone_month_no2_min_std  agg_utm_zone_month_no2_min_var  \
# 0                             3.254166                       10.589596
# 1                             3.274371                       10.721502
# 2                             2.073264                        4.298424
# 3                             3.870281                       14.979077
# 4                             3.313818                       10.981389
# ...                                ...                             ...
# 195936                        2.069606                        4.283269
# 195937                        4.150001                       17.222506
# 195938                        1.974047                        3.896862
# 195939                        3.375140                       11.391571
# 195940                        3.375140                       11.391571
#
#         agg_utm_zone_month_co_max_mean  agg_utm_zone_month_co_max_amax  \
# 0                             4.316408                          28.185
# 1                             6.867312                          42.192
# 2                             6.424093                          21.938
# 3                             7.009542                          23.422
# 4                             5.916391                          22.539
# ...                                ...                             ...
# 195936                        7.650069                          21.135
# 195937                        7.875786                          39.556
# 195938                        7.298244                          33.538
# 195939                       12.485510                          60.046
# 195940                       12.485510                          60.046
#
#         agg_utm_zone_month_co_max_amin  agg_utm_zone_month_co_max_std  \
# 0                                0.069                       5.812408
# 1                                0.101                       6.098263
# 2                                0.116                       5.706434
# 3                                0.107                       5.299421
# 4                                0.096                       5.380446
# ...                                ...                            ...
# 195936                           0.043                       4.642189
# 195937                           0.053                       6.765533
# 195938                           0.088                       5.773420
# 195939                           0.087                       9.715117
# 195940                           0.087                       9.715117
#
#         agg_utm_zone_month_co_max_var  agg_utm_zone_month_so2_max_mean  \
# 0                           33.784084                         4.839763
# 1                           37.188806                         4.143234
# 2                           32.563390                         7.400747
# 3                           28.083864                        10.042568
# 4                           28.949197                         7.492261
# ...                               ...                              ...
# 195936                      21.549919                         4.862903
# 195937                      45.772432                         6.362693
# 195938                      33.332384                         5.819931
# 195939                      94.383493                        12.529061
# 195940                      94.383493                        12.529061
#
#         agg_utm_zone_month_so2_max_amax  agg_utm_zone_month_so2_max_amin  \
# 0                                49.865                            0.099
# 1                                54.925                            0.195
# 2                                47.652                            0.362
# 3                                53.353                            0.540
# 4                                50.541                            0.493
# ...                                 ...                              ...
# 195936                           33.203                            0.538
# 195937                           60.557                            0.099
# 195938                           64.849                            0.287
# 195939                           92.457                            0.890
# 195940                           92.457                            0.890
#
#         agg_utm_zone_month_so2_max_std  agg_utm_zone_month_so2_max_var  \
# 0                             8.211310                       67.425618
# 1                             7.357199                       54.128383
# 2                             7.278994                       52.983747
# 3                             8.230999                       67.749342
# 4                             7.369360                       54.307462
# ...                                ...                             ...
# 195936                        6.633892                       44.008525
# 195937                        8.646786                       74.766916
# 195938                        9.550066                       91.203756
# 195939                       13.011806                      169.307083
# 195940                       13.011806                      169.307083
#
#         agg_utm_zone_month_ws_mid_mean  agg_utm_zone_month_ws_mid_amax  \
# 0                             1.782487                           6.524
# 1                             2.842753                           5.905
# 2                             2.893027                           6.334
# 3                             2.628847                           8.075
# 4                             3.289696                           7.948
# ...                                ...                             ...
# 195936                        2.167500                           5.061
# 195937                        2.135167                           6.313
# 195938                        2.945744                           7.558
# 195939                        2.342678                           5.860
# 195940                        2.342678                           5.860
#
#         agg_utm_zone_month_ws_mid_amin  agg_utm_zone_month_ws_mid_std  \
# 0                                0.000                       1.348519
# 1                                0.494                       1.323586
# 2                                0.508                       1.305944
# 3                                0.299                       1.475221
# 4                                0.755                       1.572765
# ...                                ...                            ...
# 195936                           0.265                       1.022097
# 195937                           0.136                       1.140408
# 195938                           0.691                       1.254386
# 195939                           0.086                       1.168136
# 195940                           0.086                       1.168136
#
#         agg_utm_zone_month_ws_mid_var  agg_utm_zone_month_so2_mid_mean  \
# 0                            1.818503                         1.765092
# 1                            1.751881                         1.058649
# 2                            1.705490                         2.930600
# 3                            2.176277                         2.920058
# 4                            2.473589                         3.014899
# ...                               ...                              ...
# 195936                       1.044682                         1.269125
# 195937                       1.300530                         2.272935
# 195938                       1.573485                         1.564787
# 195939                       1.364541                         5.818959
# 195940                       1.364541                         5.818959
#
#         agg_utm_zone_month_so2_mid_amax  agg_utm_zone_month_so2_mid_amin  \
# 0                                18.539                            0.095
# 1                                 5.678                            0.098
# 2                                10.536                            0.177
# 3                                11.959                            0.267
# 4                                10.557                            0.186
# ...                                 ...                              ...
# 195936                            4.550                            0.144
# 195937                            8.712                            0.095
# 195938                            8.702                            0.190
# 195939                           30.609                            0.360
# 195940                           30.609                            0.360
#
#         agg_utm_zone_month_so2_mid_std  agg_utm_zone_month_so2_mid_var  \
# 0                             2.742112                        7.519179
# 1                             1.369169                        1.874625
# 2                             2.280347                        5.199982
# 3                             1.822722                        3.322315
# 4                             1.932086                        3.732956
# ...                                ...                             ...
# 195936                        0.994567                        0.989163
# 195937                        1.885784                        3.556180
# 195938                        1.737947                        3.020460
# 195939                        6.506570                       42.335452
# 195940                        6.506570                       42.335452
#
#         agg_utm_zone_month_o3_max_mean  agg_utm_zone_month_o3_max_amax  \
# 0                            19.701211                          58.443
# 1                            21.289156                          74.567
# 2                            31.605307                         113.124
# 3                            36.718768                         104.535
# 4                            28.624159                          88.670
# ...                                ...                             ...
# 195936                       24.059375                          96.996
# 195937                       30.478014                          92.564
# 195938                       28.585156                          86.820
# 195939                       29.697192                          95.057
# 195940                       29.697192                          95.057
#
#         agg_utm_zone_month_o3_max_amin  agg_utm_zone_month_o3_max_std  \
# 0                                0.096                      15.296717
# 1                                2.562                      15.657755
# 2                                6.342                      16.646464
# 3                                6.430                      17.420901
# 4                                0.000                      20.248588
# ...                                ...                            ...
# 195936                           5.586                      12.993005
# 195937                           7.411                      13.474399
# 195938                           0.823                      12.586428
# 195939                           4.142                      15.115373
# 195940                           4.142                      15.115373
#
#         agg_utm_zone_month_o3_max_var  agg_utm_zone_month_co_min_mean  \
# 0                          233.989545                        1.175803
# 1                          245.165291                        2.238675
# 2                          277.104761                        1.436227
# 3                          303.487797                        2.026226
# 4                          410.005297                        1.780014
# ...                               ...                             ...
# 195936                     168.818185                        2.474889
# 195937                     181.559440                        1.635502
# 195938                     158.418170                        1.756962
# 195939                     228.474499                        1.709996
# 195940                     228.474499                        1.709996
#
#         agg_utm_zone_month_co_min_amax  agg_utm_zone_month_co_min_amin  \
# 0                               11.789                           0.002
# 1                               14.106                           0.000
# 2                                9.998                           0.028
# 3                               10.394                           0.000
# 4                                9.952                           0.018
# ...                                ...                             ...
# 195936                           7.964                           0.018
# 195937                          10.271                           0.000
# 195938                           7.838                           0.010
# 195939                           8.354                           0.000
# 195940                           8.354                           0.000
#
#         agg_utm_zone_month_co_min_std  agg_utm_zone_month_co_min_var
# 0                            1.764483                       3.113400
# 1                            2.012904                       4.051781
# 2                            1.719874                       2.957967
# 3                            1.818423                       3.306663
# 4                            1.881121                       3.538615
# ...                               ...                            ...
# 195936                       1.808346                       3.270114
# 195937                       1.665658                       2.774417
# 195938                       1.273629                       1.622132
# 195939                       1.822142                       3.320202
# 195940                       1.822142                       3.320202
#
# [195941 rows x 103 columns]

# %%
df_train = pd.concat([df_train,train_data['Country']],axis=1)
df_train = df_train.drop('Country_label_enc',axis=1)

# %%
TE = TargetEncoder(smoothing=0.1)
df_train["target_enc"] = TE.fit_transform(df_train['Country'],train_data[config.target])

# %%
df_test = get_test_data(test_data, run_blocks)
df_test
# Out:
#             lat        lon  co_cnt  co_min  co_mid  co_max  co_var  o3_cnt  \
# 0     -34.92866  138.59863     155   0.091   0.101   0.195   0.003     167
# 1     -33.86785  151.20732      23   1.037   2.272   3.391   1.347     142
# 2      50.85045    4.34878      28   0.096   0.101   0.104   0.000     114
# 3      43.84864   18.35644     122   0.479   4.589  16.560  60.820     118
# 4     -23.17944  -45.88694     158   6.198  13.478  20.327  36.498     129
# ...         ...        ...     ...     ...     ...     ...     ...     ...
# 53504  36.98615   35.32531      97   4.674   9.034  14.650  23.900      90
# 53505  40.19559   29.06013     123  17.621  18.156  21.877   4.390     116
# 53506  41.00500   39.72694     150   0.128  14.275  21.124   0.315     108
# 53507  51.50853   -0.12574      21   0.057   0.111   2.088   0.988      54
# 53508  20.86481  106.68345      47   0.060   0.071   0.136   0.000     134
#
#        o3_min  o3_mid  o3_max   o3_var  so2_cnt  so2_min  so2_mid  so2_max  \
# 0       0.000   0.000   0.000    0.000       12    0.095    0.098    0.106
# 1       7.797  34.414  59.489  630.329       54    1.476    1.531    5.380
# 2       7.064  16.576  27.246   97.445        9    0.566    0.600    0.626
# 3       0.513  22.445  51.638  625.291      138    1.551   12.523   60.551
# 4       1.063   1.845  27.894  166.269       92    1.568    4.365   14.958
# ...       ...     ...     ...      ...      ...      ...      ...      ...
# 53504  11.798  21.871  28.693   67.294       88    3.699    7.816   44.080
# 53505   0.882   6.559  14.794   46.421      109    4.295    8.558   59.418
# 53506   0.476   9.539  33.956  175.614      100    0.074    2.970    7.959
# 53507   0.301   2.029  24.479  138.410       40    0.230    0.478    0.884
# 53508   9.491  19.852  24.678   55.554       19    1.544    2.441    6.277
#
#        so2_var  no2_cnt  no2_min  no2_mid  no2_max  no2_var  temperature_cnt  \
# 0        0.000      118    0.097    0.099    0.105    0.000              168
# 1        3.709      147    1.139    4.117   24.680  132.975              176
# 2        0.000      151    1.362    5.372   16.268   53.080              172
# 3      819.667      141    0.467    7.609   30.975  221.357              132
# 4       42.456      126    9.118   16.171   48.517  354.133              102
# ...        ...      ...      ...      ...      ...      ...              ...
# 53504  391.178       83    0.829    5.287   42.481  417.102               92
# 53505  706.550      104    8.884   14.335   30.304  111.588              112
# 53506   14.297      263    2.800   10.818   32.341  208.883              202
# 53507    0.102       77    1.326    9.441    9.838   17.650              111
# 53508    5.352       44    1.153    8.646   14.952   44.975              427
#
#        temperature_min  temperature_mid  temperature_max  temperature_var  \
# 0               13.226           23.461           33.922          104.054
# 1               21.676           27.487           36.453           52.606
# 2                5.402            7.786            9.754            4.564
# 3               -4.840            0.976            4.849           22.794
# 4                5.526            7.388           21.291           57.069
# ...                ...              ...              ...              ...
# 53504            8.354           12.533           18.784           26.241
# 53505            5.241            9.273           11.543            9.674
# 53506            6.784           12.701           16.167           21.408
# 53507           10.690           16.795           18.424           14.548
# 53508           20.111           25.368           28.187           15.394
#
#        humidity_cnt  humidity_min  humidity_mid  humidity_max  humidity_var  \
# 0               180        17.795        34.081        90.636      1282.735
# 1               177        30.139        55.590        87.970       805.448
# 2               163        70.948        80.069        96.067       148.232
# 3               139        55.585       100.000       100.000       479.874
# 4               123        68.233        87.176        99.879       237.783
# ...             ...           ...           ...           ...           ...
# 53504            94        34.495        47.605        73.066       352.286
# 53505           118        71.775        83.258       100.000       190.221
# 53506           112        43.466        75.428        87.317       466.464
# 53507            66        44.049        84.531        94.643       603.074
# 53508           107        63.503        83.249        94.011       223.148
#
#        pressure_cnt  pressure_min  pressure_mid  pressure_max  pressure_var  \
# 0               154       934.478       944.740      1029.990        11.067
# 1               184       979.216      1008.498      1014.100        65.343
# 2               159       936.950      1047.096      1080.000        19.318
# 3               132       950.173       985.215      1043.932        76.454
# 4               131      1001.341      1015.044      1017.836        50.092
# ...             ...           ...           ...           ...           ...
# 53504            95       914.666       963.444      1080.000         3.863
# 53505           105       989.638      1008.551      1024.879        35.258
# 53506           111      1002.984      1009.004      1025.333        37.266
# 53507           118      1012.094      1019.240      1024.880        28.607
# 53508           280      1005.977      1008.091      1013.454         8.356
#
#        ws_cnt  ws_min  ws_mid  ws_max  ws_var  dew_cnt  dew_min  dew_mid  \
# 0         111   0.098   2.411  10.213  24.608       26    3.057    8.180
# 1         158   0.101   2.982   8.261  15.957       47   11.090   15.361
# 2          64   0.218   1.200   5.802   7.584       44    1.055    4.411
# 3         149   0.504   1.172   3.861   2.696       16    0.482    0.484
# 4         164   0.409   1.412   3.132   1.754      165    6.253   11.440
# ...       ...     ...     ...     ...     ...      ...      ...      ...
# 53504      93   0.201   2.878   7.397  12.130       86    0.451    3.112
# 53505     114   0.473   1.491   2.974   1.468      115    3.894    6.823
# 53506     179   1.001   3.605   5.040   3.965       12    5.269    8.772
# 53507      41   0.077   0.803   3.884   3.268       34   10.906   10.959
# 53508     178   0.105   2.931  15.303  22.760       58    9.825   15.037
#
#        dew_max  dew_var  Country_label_enc  utm_zone_label_enc  year  ...  \
# 0       15.841   39.705                 10                  71  2019  ...
# 1       19.227   15.857                 10                  30  2019  ...
# 2        6.955    8.415                 17                   8  2019  ...
# 3        0.932    0.049                 27                   5  2019  ...
# 4       12.473    3.546                 20                  36  2019  ...
# ...        ...      ...                ...                 ...   ...  ...
# 53504    4.512    3.938                  4                   6  2021  ...
# 53505    6.861    2.145                  4                  26  2021  ...
# 53506   12.661   13.201                  4                  38  2021  ...
# 53507   12.744    0.822                 15                  18  2021  ...
# 53508   22.294   11.189                 22                  31  2021  ...
#
#        agg_utm_zone_month_no2_mid_mean  agg_utm_zone_month_no2_mid_amax  \
# 0                             5.581000                           38.018
# 1                             8.330089                           31.153
# 2                            11.486941                           34.456
# 3                            11.384835                           36.025
# 4                            10.563673                           30.607
# ...                                ...                              ...
# 53504                        16.625133                           68.399
# 53505                        18.976222                           41.964
# 53506                        16.663311                           43.947
# 53507                        11.167748                           37.752
# 53508                        11.745539                           32.873
#
#        agg_utm_zone_month_no2_mid_amin  agg_utm_zone_month_no2_mid_std  \
# 0                                0.095                        7.408600
# 1                                0.932                        6.457191
# 2                                0.701                        6.478391
# 3                                0.491                        6.575350
# 4                                0.904                        6.447096
# ...                                ...                             ...
# 53504                            0.096                       10.942805
# 53505                            1.712                        7.822995
# 53506                            0.634                        9.336713
# 53507                            0.532                        6.053775
# 53508                            0.408                        6.495702
#
#        agg_utm_zone_month_no2_mid_var  agg_utm_zone_month_co_mid_mean  \
# 0                           54.887361                        2.360923
# 1                           41.695320                        3.726747
# 2                           41.969544                        2.431204
# 3                           43.235229                        5.443752
# 4                           41.565045                        3.483272
# ...                               ...                             ...
# 53504                      119.744979                        5.992913
# 53505                       61.199246                       14.298833
# 53506                       87.174205                        6.493412
# 53507                       36.648187                        3.269637
# 53508                       42.194143                        4.323143
#
#        agg_utm_zone_month_co_mid_amax  agg_utm_zone_month_co_mid_amin  \
# 0                              15.781                           0.055
# 1                              18.124                           0.077
# 2                              24.154                           0.055
# 3                              30.736                           0.041
# 4                              16.564                           0.048
# ...                               ...                             ...
# 53504                          30.517                           0.023
# 53505                          45.129                           0.071
# 53506                          23.400                           0.060
# 53507                          17.057                           0.062
# 53508                          12.386                           0.053
#
#        agg_utm_zone_month_co_mid_std  agg_utm_zone_month_co_mid_var  \
# 0                           3.182149                      10.126072
# 1                           2.994160                       8.964996
# 2                           3.122816                       9.751978
# 3                           3.431318                      11.773941
# 4                           3.015440                       9.092880
# ...                              ...                            ...
# 53504                       4.812726                      23.162336
# 53505                       9.193549                      84.521347
# 53506                       3.646047                      13.293656
# 53507                       2.660114                       7.076209
# 53508                       3.063893                       9.387442
#
#        agg_utm_zone_month_no2_max_mean  agg_utm_zone_month_no2_max_amax  \
# 0                            12.798346                           51.066
# 1                            22.187416                           65.972
# 2                            27.590745                           82.149
# 3                            27.114687                           99.571
# 4                            30.578358                          151.632
# ...                                ...                              ...
# 53504                        52.100702                          235.969
# 53505                        54.606607                          115.850
# 53506                        52.361983                          127.826
# 53507                        32.999037                           80.557
# 53508                        32.203755                          107.800
#
#        agg_utm_zone_month_no2_max_amin  agg_utm_zone_month_no2_max_std  \
# 0                                0.096                       13.892789
# 1                                2.905                       11.291320
# 2                                0.796                       14.376570
# 3                                0.708                       13.994598
# 4                                1.637                       20.359732
# ...                                ...                             ...
# 53504                            0.101                       41.278764
# 53505                            2.200                       25.322101
# 53506                            2.056                       30.424837
# 53507                            1.555                       14.805619
# 53508                            2.377                       19.022846
#
#        agg_utm_zone_month_no2_max_var  agg_utm_zone_month_no2_min_mean  \
# 0                          193.009587                         2.027250
# 1                          127.493916                         3.292168
# 2                          206.685751                         3.674725
# 3                          195.848766                         4.112076
# 4                          414.518676                         2.841537
# ...                               ...                              ...
# 53504                     1703.936331                         4.553677
# 53505                      641.208790                         3.244589
# 53506                      925.670690                         4.234531
# 53507                      219.206353                         2.585347
# 53508                      361.868687                         4.322363
#
#        agg_utm_zone_month_no2_min_amax  agg_utm_zone_month_no2_min_amin  \
# 0                               17.337                            0.000
# 1                               17.709                            0.000
# 2                               27.271                            0.000
# 3                               18.431                            0.000
# 4                               18.075                            0.000
# ...                                ...                              ...
# 53504                           35.777                            0.090
# 53505                           16.622                            0.090
# 53506                           23.049                            0.097
# 53507                           15.876                            0.000
# 53508                           16.456                            0.284
#
#        agg_utm_zone_month_no2_min_std  agg_utm_zone_month_no2_min_var  \
# 0                            3.353898                       11.248634
# 1                            3.870281                       14.979077
# 2                            3.647001                       13.300615
# 3                            3.386831                       11.470623
# 4                            3.422335                       11.712376
# ...                               ...                             ...
# 53504                        4.467212                       19.955986
# 53505                        3.021794                        9.131237
# 53506                        3.728028                       13.898189
# 53507                        2.613870                        6.832318
# 53508                        3.375140                       11.391571
#
#        agg_utm_zone_month_co_max_mean  agg_utm_zone_month_co_max_amax  \
# 0                            5.474769                          25.644
# 1                            7.009542                          23.422
# 2                            4.898747                          33.494
# 3                           12.328761                          89.161
# 4                            9.604488                          84.643
# ...                               ...                             ...
# 53504                       16.474615                         477.297
# 53505                       32.751552                         500.000
# 53506                       16.934542                          98.662
# 53507                        6.796828                          42.568
# 53508                       12.485510                          60.046
#
#        agg_utm_zone_month_co_max_amin  agg_utm_zone_month_co_max_std  \
# 0                               0.088                       6.639895
# 1                               0.107                       5.299421
# 2                               0.065                       6.059716
# 3                               0.063                       9.248007
# 4                               0.084                       9.454186
# ...                               ...                            ...
# 53504                           0.035                      23.953649
# 53505                           0.090                      34.415445
# 53506                           0.094                      11.594983
# 53507                           0.073                       5.858475
# 53508                           0.087                       9.715117
#
#        agg_utm_zone_month_co_max_var  agg_utm_zone_month_so2_max_mean  \
# 0                          44.088210                         4.447962
# 1                          28.083864                        10.042568
# 2                          36.720162                         5.295346
# 3                          85.525636                        13.805640
# 4                          89.381633                         7.429747
# ...                              ...                              ...
# 53504                     573.777316                        18.038535
# 53505                    1184.422841                        33.068278
# 53506                     134.443626                        22.601006
# 53507                      34.321724                         8.220692
# 53508                      94.383493                        12.529061
#
#        agg_utm_zone_month_so2_max_amax  agg_utm_zone_month_so2_max_amin  \
# 0                               28.000                            0.100
# 1                               53.353                            0.540
# 2                               43.985                            0.198
# 3                               96.821                            0.318
# 4                               72.007                            0.608
# ...                                ...                              ...
# 53504                          125.817                            0.507
# 53505                           73.686                            0.550
# 53506                          106.891                            0.998
# 53507                          110.637                            0.554
# 53508                           92.457                            0.890
#
#        agg_utm_zone_month_so2_max_std  agg_utm_zone_month_so2_max_var  \
# 0                            6.286797                       39.523822
# 1                            8.230999                       67.749342
# 2                            6.416941                       41.177129
# 3                           16.667260                      277.797561
# 4                            9.332414                       87.093958
# ...                               ...                             ...
# 53504                       17.679027                      312.547992
# 53505                       17.965359                      322.754126
# 53506                       20.138337                      405.552620
# 53507                       11.252424                      126.617045
# 53508                       13.011806                      169.307083
#
#        agg_utm_zone_month_ws_mid_mean  agg_utm_zone_month_ws_mid_amax  \
# 0                            2.715808                           6.991
# 1                            2.628847                           8.075
# 2                            2.812923                          10.658
# 3                            2.259362                           9.305
# 4                            2.147420                           5.467
# ...                               ...                             ...
# 53504                        2.308059                          12.061
# 53505                        2.885941                           9.120
# 53506                        2.341706                           7.113
# 53507                        3.078236                          13.085
# 53508                        2.342678                           5.860
#
#        agg_utm_zone_month_ws_mid_amin  agg_utm_zone_month_ws_mid_std  \
# 0                               0.617                       1.356142
# 1                               0.299                       1.475221
# 2                               0.201                       1.834497
# 3                               0.099                       1.417022
# 4                               0.051                       1.061972
# ...                               ...                            ...
# 53504                           0.151                       1.328479
# 53505                           0.500                       1.877652
# 53506                           0.230                       1.334191
# 53507                           0.319                       1.917630
# 53508                           0.086                       1.168136
#
#        agg_utm_zone_month_ws_mid_var  agg_utm_zone_month_so2_mid_mean  \
# 0                           1.839122                         1.686904
# 1                           2.176277                         2.920058
# 2                           3.365378                         1.719919
# 3                           2.007952                         4.527678
# 4                           1.127784                         1.985833
# ...                              ...                              ...
# 53504                       1.764856                         4.187830
# 53505                       3.525578                         6.375333
# 53506                       1.780065                         4.957051
# 53507                       3.677305                         2.396541
# 53508                       1.364541                         5.818959
#
#        agg_utm_zone_month_so2_mid_amax  agg_utm_zone_month_so2_mid_amin  \
# 0                                8.281                            0.094
# 1                               11.959                            0.267
# 2                                9.339                            0.094
# 3                               41.528                            0.134
# 4                                7.154                            0.260
# ...                                ...                              ...
# 53504                           16.156                            0.261
# 53505                           21.069                            0.337
# 53506                           15.524                            0.283
# 53507                            9.138                            0.207
# 53508                           30.609                            0.360
#
#        agg_utm_zone_month_so2_mid_std  agg_utm_zone_month_so2_mid_var  \
# 0                            1.990854                        3.963499
# 1                            1.822722                        3.322315
# 2                            1.572038                        2.471303
# 3                            5.638748                       31.795478
# 4                            1.563453                        2.444387
# ...                               ...                             ...
# 53504                        2.703100                        7.306749
# 53505                        4.446169                       19.768423
# 53506                        3.170206                       10.050207
# 53507                        1.632712                        2.665748
# 53508                        6.506570                       42.335452
#
#        agg_utm_zone_month_o3_max_mean  agg_utm_zone_month_o3_max_amax  \
# 0                           21.389558                          79.643
# 1                           36.718768                         104.535
# 2                           28.966749                         121.344
# 3                           32.840474                         104.304
# 4                           48.222111                         280.087
# ...                               ...                             ...
# 53504                       33.892420                         261.606
# 53505                       28.835381                         133.883
# 53506                       22.595932                          98.058
# 53507                       31.233342                         108.095
# 53508                       29.697192                          95.057
#
#        agg_utm_zone_month_o3_max_amin  agg_utm_zone_month_o3_max_std  \
# 0                               0.000                      20.756530
# 1                               6.430                      17.420901
# 2                               3.089                      15.337050
# 3                               5.993                      16.019901
# 4                               8.949                      30.399240
# ...                               ...                            ...
# 53504                           1.680                      22.516599
# 53505                           5.058                      15.475765
# 53506                           1.250                      15.171066
# 53507                           3.529                      14.304675
# 53508                           4.142                      15.115373
#
#        agg_utm_zone_month_o3_max_var  agg_utm_zone_month_co_min_mean  \
# 0                         430.833519                        0.996308
# 1                         303.487797                        2.026226
# 2                         235.225096                        1.182796
# 3                         256.637227                        2.657179
# 4                         924.113764                        1.449086
# ...                              ...                             ...
# 53504                     506.997226                        2.427723
# 53505                     239.499307                        8.759911
# 53506                     230.161235                        2.749277
# 53507                     204.623718                        1.555833
# 53508                     228.474499                        1.709996
#
#        agg_utm_zone_month_co_min_amax  agg_utm_zone_month_co_min_amin  \
# 0                               6.001                           0.026
# 1                              10.394                           0.000
# 2                              11.345                           0.000
# 3                              14.455                           0.000
# 4                               8.704                           0.043
# ...                               ...                             ...
# 53504                          15.361                           0.000
# 53505                          36.110                           0.060
# 53506                           8.117                           0.041
# 53507                           7.688                           0.000
# 53508                           8.354                           0.000
#
#        agg_utm_zone_month_co_min_std  agg_utm_zone_month_co_min_var
# 0                           1.470686                       2.162917
# 1                           1.818423                       3.306663
# 2                           1.706443                       2.911947
# 3                           2.087456                       4.357473
# 4                           1.493784                       2.231392
# ...                              ...                            ...
# 53504                       2.186005                       4.778620
# 53505                       8.953697                      80.168690
# 53506                       1.654128                       2.736140
# 53507                       1.442069                       2.079562
# 53508                       1.822142                       3.320202
#
# [53509 rows x 103 columns]

# %%
df_test = pd.concat([df_test,test_data['Country']],axis=1)
df_test = df_test.drop('Country_label_enc',axis=1)

# %%
df_test["target_enc"] = TE.transform(df_test['Country'])

# %%
df_all = pd.concat([df_train,df_test],sort=False)

# %%
#df_all['diff_no2_mid_aggmean'] = df_all['agg_Country_month_no2_mid_mean'] - df_all['no2_mid']
#df_all['diff_no2_mid_aggamax'] = df_all['agg_Country_month_no2_mid_amax'] - df_all['no2_mid']
df_all['diff_no2_mid_aggamin'] = df_all['agg_utm_zone_month_no2_mid_amin'] - df_all['no2_mid']

#df_all['diff_no2_mid_aggminmax'] = df_all['diff_no2_mid_aggamax'] - df_all['diff_no2_mid_aggamin']
#df_all['ratio_no2_mid_aggminmax_mean'] = df_all['diff_no2_mid_aggminmax'] / df_all['diff_no2_mid_aggmean']

#df_all['diff_no2_max_aggmean'] = df_all['agg_Country_month_no2_max_mean'] - df_all['no2_max']
#df_all['diff_no2_max_aggamax'] = df_all['agg_Country_month_no2_max_amax'] - df_all['no2_max']
#df_all['diff_no2_max_aggamin'] = df_all['agg_Country_month_no2_max_amin'] - df_all['no2_max']

#df_all['diff_no2_max_aggminmax'] = df_all['diff_no2_max_aggamax'] - df_all['diff_no2_max_aggamin']
#df_all['ratio_no2_max_aggminmax_mean'] = df_all['diff_no2_max_aggminmax'] / df_all['diff_no2_max_aggmean']

#df_all['diff_no2_min_aggmean'] = df_all['agg_Country_month_no2_min_mean'] - df_all['no2_min']
#df_all['diff_no2_min_aggamax'] = df_all['agg_Country_month_no2_min_amax'] - df_all['no2_min']
#df_all['diff_no2_min_aggamin'] = df_all['agg_Country_month_no2_min_amin'] - df_all['no2_min']

#df_all['diff_no2_min_aggminmax'] = df_all['diff_no2_min_aggamax'] - df_all['diff_no2_min_aggamin']
#df_all['ratio_no2_min_aggminmax_mean'] = df_all['diff_no2_min_aggminmax'] / df_all['diff_no2_min_aggmean']

#df_all['diff_no2_minmax_aggmean'] = df_all['diff_no2_max_aggmean'] -df_all['diff_no2_min_aggmean']
#df_all['diff_no2_minmax_aggamax'] = df_all['diff_no2_max_aggamax'] -df_all['diff_no2_min_aggamax']
#df_all['diff_no2_minmax_aggamin'] = df_all['diff_no2_max_aggamin'] -df_all['diff_no2_min_aggamin']

#df_all['diff_co_mid_aggmean'] = df_all['agg_Country_month_co_mid_mean'] - df_all['co_mid']
#df_all['diff_co_mid_aggamax'] = df_all['agg_Country_month_co_mid_amax'] - df_all['co_mid']
df_all['diff_co_mid_aggamin'] = df_all['agg_utm_zone_month_co_mid_amin'] - df_all['co_mid']

#df_all['diff_co_mid_aggminmax'] = df_all['diff_co_mid_aggamax'] - df_all['diff_co_mid_aggamin']
#df_all['ratio_co_mid_aggminmax_mean'] = df_all['diff_co_mid_aggminmax'] / df_all['diff_co_mid_aggmean']

#df_all['diff_co_max_aggmean'] = df_all['agg_Country_month_co_max_mean'] - df_all['co_max']
#df_all['diff_co_max_aggamax'] = df_all['agg_Country_month_co_max_amax'] - df_all['co_max']
df_all['diff_co_max_aggamin'] = df_all['agg_utm_zone_month_co_max_amin'] - df_all['co_max']

#df_all['diff_co_max_aggminmax'] = df_all['diff_co_max_aggamax'] - df_all['diff_co_max_aggamin']
#df_all['ratio_co_max_aggminmax_mean'] = df_all['diff_co_max_aggminmax'] / df_all['diff_co_max_aggmean']

#df_all['diff_co_min_aggmean'] = df_all['agg_Country_month_co_min_mean'] - df_all['co_min']
#df_all['diff_co_min_aggamax'] = df_all['agg_Country_month_co_min_amax'] - df_all['co_min']
#df_all['diff_co_min_aggamin'] = df_all['agg_Country_month_co_min_amin'] - df_all['co_min']
'''

#df_all['diff_co_min_aggminmax'] = df_all['diff_co_min_aggamax'] - df_all['diff_co_min_aggamin']
#df_all['ratio_co_min_aggminmax_mean'] = df_all['diff_co_min_aggminmax'] / df_all['diff_co_min_aggmean']

#df_all['diff_co_minmax_aggmean'] = df_all['diff_co_max_aggmean'] -df_all['diff_co_min_aggmean']
#df_all['diff_co_minmax_aggamax'] = df_all['diff_co_max_aggamax'] -df_all['diff_co_min_aggamax']
#df_all['diff_co_minmax_aggamin'] = df_all['diff_co_max_aggamin'] -df_all['diff_co_min_aggamin']

#df_all['diff_so2_max_aggmean'] = df_all['agg_Country_month_so2_max_mean'] - df_all['so2_max']
#df_all['diff_so2_max_aggamax'] = df_all['agg_Country_month_so2_max_amax'] - df_all['so2_max']
df_all['diff_so2_max_aggamin'] = df_all['agg_Country_month_so2_max_amin'] - df_all['so2_max']

#df_all['diff_so2_max_aggminmax'] = df_all['diff_so2_max_aggamax'] - df_all['diff_so2_max_aggamin']
#df_all['ratio_so2_max_aggminmax_mean'] = df_all['diff_so2_max_aggminmax'] / df_all['diff_so2_max_aggmean']

#df_all['diff_so2_mid_aggmean'] = df_all['agg_Country_month_so2_mid_mean'] - df_all['so2_mid']
#df_all['diff_so2_mid_aggamax'] = df_all['agg_Country_month_so2_mid_amax'] - df_all['so2_mid']
df_all['diff_so2_mid_aggamin'] = df_all['agg_Country_month_so2_mid_amin'] - df_all['so2_mid']

#df_all['diff_so2_mid_aggminmax'] = df_all['diff_so2_mid_aggamax'] - df_all['diff_so2_mid_aggamin']
#df_all['ratio_so2_mid_aggminmax_mean'] = df_all['diff_so2_mid_aggminmax'] / df_all['diff_so2_mid_aggmean']

df_all['diff_o3_max_aggmean'] = df_all['agg_Country_month_o3_max_mean'] - df_all['o3_max']
#df_all['diff_o3_max_aggamax'] = df_all['agg_Country_month_o3_max_amax'] - df_all['o3_max']
df_all['diff_o3_max_aggamin'] = df_all['agg_Country_month_o3_max_amin'] - df_all['o3_max']

df_all['diff_o3_max_aggminmax'] = df_all['diff_o3_max_aggamax'] - df_all['diff_o3_max_aggamin']
df_all['ratio_o3_max_aggminmax_mean'] = df_all['diff_o3_max_aggminmax'] / df_all['diff_o3_max_aggmean']

df_all['diff_ws_mid_aggmean'] = df_all['agg_Country_month_ws_mid_mean'] - df_all['ws_mid']
df_all['diff_ws_mid_aggamax'] = df_all['agg_Country_month_ws_mid_amax'] - df_all['ws_mid']
df_all['diff_ws_mid_aggamin'] = df_all['agg_Country_month_ws_mid_amin'] - df_all['ws_mid']

df_all['diff_ws_mid_aggminmax'] = df_all['diff_ws_mid_aggamax'] - df_all['diff_ws_mid_aggamin']
df_all['ratio_ws_mid_aggminmax_mean'] = df_all['diff_ws_mid_aggminmax'] / df_all['diff_ws_mid_aggmean']
'''
# Out:
# "\n\n#df_all['diff_co_min_aggminmax'] = df_all['diff_co_min_aggamax'] - df_all['diff_co_min_aggamin']\n#df_all['ratio_co_min_aggminmax_mean'] = df_all['diff_co_min_aggminmax'] / df_all['diff_co_min_aggmean']\n\n#df_all['diff_co_minmax_aggmean'] = df_all['diff_co_max_aggmean'] -df_all['diff_co_min_aggmean']\n#df_all['diff_co_minmax_aggamax'] = df_all['diff_co_max_aggamax'] -df_all['diff_co_min_aggamax']\n#df_all['diff_co_minmax_aggamin'] = df_all['diff_co_max_aggamin'] -df_all['diff_co_min_aggamin']\n\n#df_all['diff_so2_max_aggmean'] = df_all['agg_Country_month_so2_max_mean'] - df_all['so2_max']\n#df_all['diff_so2_max_aggamax'] = df_all['agg_Country_month_so2_max_amax'] - df_all['so2_max']\ndf_all['diff_so2_max_aggamin'] = df_all['agg_Country_month_so2_max_amin'] - df_all['so2_max']\n\n#df_all['diff_so2_max_aggminmax'] = df_all['diff_so2_max_aggamax'] - df_all['diff_so2_max_aggamin']\n#df_all['ratio_so2_max_aggminmax_mean'] = df_all['diff_so2_max_aggminmax'] / df_all['diff_so2_max_aggmean']\n\n#df_all['diff_so2_mid_aggmean'] = df_all['agg_Country_month_so2_mid_mean'] - df_all['so2_mid']\n#df_all['diff_so2_mid_aggamax'] = df_all['agg_Country_month_so2_mid_amax'] - df_all['so2_mid']\ndf_all['diff_so2_mid_aggamin'] = df_all['agg_Country_month_so2_mid_amin'] - df_all['so2_mid']\n\n#df_all['diff_so2_mid_aggminmax'] = df_all['diff_so2_mid_aggamax'] - df_all['diff_so2_mid_aggamin']\n#df_all['ratio_so2_mid_aggminmax_mean'] = df_all['diff_so2_mid_aggminmax'] / df_all['diff_so2_mid_aggmean']\n\ndf_all['diff_o3_max_aggmean'] = df_all['agg_Country_month_o3_max_mean'] - df_all['o3_max']\n#df_all['diff_o3_max_aggamax'] = df_all['agg_Country_month_o3_max_amax'] - df_all['o3_max']\ndf_all['diff_o3_max_aggamin'] = df_all['agg_Country_month_o3_max_amin'] - df_all['o3_max']\n\ndf_all['diff_o3_max_aggminmax'] = df_all['diff_o3_max_aggamax'] - df_all['diff_o3_max_aggamin']\ndf_all['ratio_o3_max_aggminmax_mean'] = df_all['diff_o3_max_aggminmax'] / df_all['diff_o3_max_aggmean']\n\ndf_all['diff_ws_mid_aggmean'] = df_all['agg_Country_month_ws_mid_mean'] - df_all['ws_mid']\ndf_all['diff_ws_mid_aggamax'] = df_all['agg_Country_month_ws_mid_amax'] - df_all['ws_mid']\ndf_all['diff_ws_mid_aggamin'] = df_all['agg_Country_month_ws_mid_amin'] - df_all['ws_mid']\n\ndf_all['diff_ws_mid_aggminmax'] = df_all['diff_ws_mid_aggamax'] - df_all['diff_ws_mid_aggamin']\ndf_all['ratio_ws_mid_aggminmax_mean'] = df_all['diff_ws_mid_aggminmax'] / df_all['diff_ws_mid_aggmean']\n"

# %%
'''
import wxparams as wx

df_all['mix_ratio'] = wx.Mixing_Ratio(df_all['dew_mid'], df_all['pressure_mid'], formula="Bolton")
df_all['spec_humidity'] = wx.Specific_Humidity(df_all['dew_mid'], df_all['pressure_mid'], formula="Bolton")
df_all['abs_humidity'] = wx.Absolute_Humidity(df_all['temperature_mid'], df_all['dew_mid'], formula="Bolton")
df_all['vir_temperature'] = wx.Virtual_Temperature(df_all['temperature_mid'], df_all['dew_mid'], df_all['pressure_mid'], formula="Bolton")

df_all['theta'] = wx.Theta(df_all['temperature_mid'], df_all['pressure_mid'])
df_all['tlcl'] = wx.Tlcl(df_all['temperature_mid'], df_all['dew_mid'])

df_all['theta_e'] = wx.Theta_e(df_all['temperature_mid'], df_all['dew_mid'], df_all['pressure_mid'], formula="Bolton")
df_all['di'] = 0.81*df_all['temperature_mid']+0.01*df_all['humidity_mid']*(0.99*df_all['temperature_mid']-14.3)+4
'''

df_all['co_minmax'] = df_all['co_max'] - df_all['co_min']
df_all['o3_minmax'] = df_all['o3_max'] - df_all['o3_min']
df_all['so2_minmax'] = df_all['so2_max'] - df_all['so2_min']
df_all['no2_minmax'] = df_all['no2_max'] - df_all['no2_min']

df_all['temperature_minmax'] = df_all['temperature_max'] - df_all['temperature_min']
df_all['humidity_minmax'] = df_all['humidity_max'] - df_all['humidity_min']
df_all['pressure_minmax'] = df_all['pressure_max'] - df_all['pressure_min']
df_all['ws_minmax'] = df_all['ws_max'] - df_all['ws_min']
df_all['dew_minmax'] = df_all['dew_max'] - df_all['dew_min']


df_all['co_mean_mid'] = df_all['co_min'] + df_all['co_minmax']/2 - df_all['co_mid']
df_all['o3_mean_mid'] = df_all['o3_min'] + df_all['o3_minmax']/2 - df_all['o3_mid']
df_all['so2_mean_mid'] = df_all['so2_min'] + df_all['so2_minmax']/2 - df_all['so2_mid']
df_all['no2_mean_mid'] = df_all['no2_min'] + df_all['no2_minmax']/2 - df_all['no2_mid']

df_all['temperature_mean_mid'] = df_all['temperature_min'] + df_all['temperature_minmax']/2 - df_all['temperature_mid']
df_all['humidity_mean_mid'] = df_all['humidity_min'] + df_all['humidity_minmax']/2 - df_all['humidity_mid']
df_all['pressure_mean_mid'] = df_all['pressure_min'] + df_all['pressure_minmax']/2 - df_all['pressure_mid']
df_all['ws_mean_mid'] = df_all['ws_min'] + df_all['ws_minmax']/2 - df_all['ws_mid']

df_all['co_humidity'] = df_all['co_mid']*df_all['humidity_mid']/100
df_all['o3_humidity'] = df_all['o3_mid']*df_all['humidity_mid']/100
df_all['so2_humidity'] = df_all['so2_mid']*df_all['humidity_mid']/100
df_all['no2_humidity'] = df_all['no2_mid']*df_all['humidity_mid']/100
'''
df_all['co_ws'] = df_all['co_mid']*df_all['ws_mid']
df_all['o3_ws'] = df_all['o3_mid']*df_all['ws_mid']
df_all['so2_ws'] = df_all['so2_mid']*df_all['ws_mid']
df_all['no2_ws'] = df_all['no2_mid']*df_all['ws_mid']

df_all['temperature_humidity'] = df_all['temperature_mid']*df_all['humidity_mid']

df_all['cnt'] = df_all['co_cnt']*df_all['o3_cnt']*df_all['so2_cnt']*df_all['no2_cnt']*df_all['temperature_cnt']*df_all['humidity_cnt']*df_all['pressure_cnt']*df_all['ws_cnt']
'''
# Out:
# "\ndf_all['co_ws'] = df_all['co_mid']*df_all['ws_mid']\ndf_all['o3_ws'] = df_all['o3_mid']*df_all['ws_mid']\ndf_all['so2_ws'] = df_all['so2_mid']*df_all['ws_mid']\ndf_all['no2_ws'] = df_all['no2_mid']*df_all['ws_mid']\n\ndf_all['temperature_humidity'] = df_all['temperature_mid']*df_all['humidity_mid']\n\ndf_all['cnt'] = df_all['co_cnt']*df_all['o3_cnt']*df_all['so2_cnt']*df_all['no2_cnt']*df_all['temperature_cnt']*df_all['humidity_cnt']*df_all['pressure_cnt']*df_all['ws_cnt']\n"

# %%
def encode(df, col):
    # この方法だと場合によって最大値が変化するデータでは正確な値は出ない
    # 例：月の日数が30日や31日の場合がある
    df[col + '_cos'] = np.cos(2 * np.pi * df[col] / df[col].max())
    df[col + '_sin'] = np.sin(2 * np.pi * df[col] / df[col].max())
    return df

df_all = encode(df_all, 'weekday')
df_all = encode(df_all, 'day')
df_all = encode(df_all, 'month')
df_all = encode(df_all, 'year')

# %%
'''
group =['Country_label_enc']
feature_cols = ['co_mid', 'no2_mid']

outputs = [df_all]
grp_df = df_all.groupby(group)[feature_cols]

for lag in [-3,-2, -1, 1, 2,3]:
   # shift
   outputs.append(grp_df.shift(lag).add_prefix(f'shift{lag}_'))
   # diff
   outputs.append(grp_df.diff(lag).add_prefix(f'diff{lag}_'))


# rolling
for window in [3,30]:
    tmp_df = grp_df.rolling(window, min_periods=1)
    # 移動平均を取る
    tmp_df = tmp_df.mean().add_prefix(f'rolling{window}_mean_')
    outputs.append(tmp_df.reset_index(drop=True))


df_all = df_all.loc[~df_all.index.duplicated(keep='first')]
df_all = pd.concat(outputs,axis=1)

#https://stackoverflow.com/questions/71240439/reindexing-only-valid-with-uniquely-valued-index-objects
'''
# Out:
# "\ngroup =['Country_label_enc']\nfeature_cols = ['co_mid', 'no2_mid']\n\noutputs = [df_all]\ngrp_df = df_all.groupby(group)[feature_cols]\n\nfor lag in [-3,-2, -1, 1, 2,3]:\n   # shift\n   outputs.append(grp_df.shift(lag).add_prefix(f'shift{lag}_'))\n   # diff\n   outputs.append(grp_df.diff(lag).add_prefix(f'diff{lag}_'))\n\n\n# rolling\nfor window in [3,30]:\n    tmp_df = grp_df.rolling(window, min_periods=1)\n    # 移動平均を取る\n    tmp_df = tmp_df.mean().add_prefix(f'rolling{window}_mean_')\n    outputs.append(tmp_df.reset_index(drop=True))\n\n\ndf_all = df_all.loc[~df_all.index.duplicated(keep='first')]\ndf_all = pd.concat(outputs,axis=1)\n\n#https://stackoverflow.com/questions/71240439/reindexing-only-valid-with-uniquely-valued-index-objects\n"

# %%
print(df_all)
# Out:
#             lat        lon  co_cnt  co_min  co_mid  co_max  co_var  o3_cnt  \
# 0     -27.46794  153.02809      38   0.749   2.590   2.633   0.850      29
# 1     -12.46113  130.84185      47   2.594   3.181   4.828   1.208      49
# 2     -37.81400  144.96332      17   1.190   1.197   2.200   0.248     123
# 3     -32.92953  151.78010      63   4.586  11.044  14.802  24.186      90
# 4     -31.95224  115.86140      47   4.689   8.681  11.100  10.011      83
# ...         ...        ...     ...     ...     ...     ...     ...     ...
# 53504  36.98615   35.32531      97   4.674   9.034  14.650  23.900      90
# 53505  40.19559   29.06013     123  17.621  18.156  21.877   4.390     116
# 53506  41.00500   39.72694     150   0.128  14.275  21.124   0.315     108
# 53507  51.50853   -0.12574      21   0.057   0.111   2.088   0.988      54
# 53508  20.86481  106.68345      47   0.060   0.071   0.136   0.000     134
#
#        o3_min  o3_mid  o3_max   o3_var  so2_cnt  so2_min  so2_mid  so2_max  \
# 0       2.397   4.295   5.916    3.017       11    0.149    0.468    0.900
# 1       3.092   7.572  12.332   20.524       31    0.096    0.102   16.152
# 2       0.736  12.527  23.432  125.224       36    1.392    1.464   47.652
# 3       1.917  14.141  38.374  304.731       50    2.957    3.230   14.056
# 4       0.349   2.349  38.600  353.549       47    0.422    5.794    9.972
# ...       ...     ...     ...      ...      ...      ...      ...      ...
# 53504  11.798  21.871  28.693   67.294       88    3.699    7.816   44.080
# 53505   0.882   6.559  14.794   46.421      109    4.295    8.558   59.418
# 53506   0.476   9.539  33.956  175.614      100    0.074    2.970    7.959
# 53507   0.301   2.029  24.479  138.410       40    0.230    0.478    0.884
# 53508   9.491  19.852  24.678   55.554       19    1.544    2.441    6.277
#
#        so2_var  no2_cnt  no2_min  no2_mid  no2_max  no2_var  temperature_cnt  \
# 0        0.137       36    0.000    0.529    2.188    1.167               36
# 1       61.550       45    0.099    0.301    5.411    6.401               71
# 2      515.570      111    0.972    2.751   12.230   30.518              148
# 3       25.630      176   14.959   17.471   24.221   20.883              101
# 4        9.234       80   14.911   21.140   32.584   74.298               55
# ...        ...      ...      ...      ...      ...      ...              ...
# 53504  391.178       83    0.829    5.287   42.481  417.102               92
# 53505  706.550      104    8.884   14.335   30.304  111.588              112
# 53506   14.297      263    2.800   10.818   32.341  208.883              202
# 53507    0.102       77    1.326    9.441    9.838   17.650              111
# 53508    5.352       44    1.153    8.646   14.952   44.975              427
#
#        temperature_min  temperature_mid  temperature_max  temperature_var  \
# 0               10.956           14.038           20.866           23.880
# 1               24.113           30.125           36.678           37.327
# 2                0.000            0.000           23.226          131.280
# 3               16.423           19.819           20.044            3.188
# 4               10.297           11.822           13.377            2.311
# ...                ...              ...              ...              ...
# 53504            8.354           12.533           18.784           26.241
# 53505            5.241            9.273           11.543            9.674
# 53506            6.784           12.701           16.167           21.408
# 53507           10.690           16.795           18.424           14.548
# 53508           20.111           25.368           28.187           15.394
#
#        humidity_cnt  humidity_min  humidity_mid  humidity_max  humidity_var  \
# 0                45        30.207        70.426        94.202       994.051
# 1                50        49.034        74.276        92.975       467.112
# 2               138        25.919        69.069       100.000      1292.191
# 3               111        73.504        86.920       100.000        85.028
# 4               155        51.918        76.736        96.533       484.188
# ...             ...           ...           ...           ...           ...
# 53504            94        34.495        47.605        73.066       352.286
# 53505           118        71.775        83.258       100.000       190.221
# 53506           112        43.466        75.428        87.317       466.464
# 53507            66        44.049        84.531        94.643       603.074
# 53508           107        63.503        83.249        94.011       223.148
#
#        pressure_cnt  pressure_min  pressure_mid  pressure_max  pressure_var  \
# 0                59      1004.137      1015.721      1023.398        89.588
# 1                69       938.085       970.252      1080.000         7.320
# 2               153       880.000       880.000      1018.200      4655.348
# 3               141      1011.703      1016.545      1018.364        10.898
# 4               124      1019.521      1022.992      1027.611        15.142
# ...             ...           ...           ...           ...           ...
# 53504            95       914.666       963.444      1080.000         3.863
# 53505           105       989.638      1008.551      1024.879        35.258
# 53506           111      1002.984      1009.004      1025.333        37.266
# 53507           118      1012.094      1019.240      1024.880        28.607
# 53508           280      1005.977      1008.091      1013.454         8.356
#
#        ws_cnt  ws_min  ws_mid  ws_max  ws_var  dew_cnt  dew_min  dew_mid  \
# 0          42   0.241   1.088   3.101   1.983       17    7.671   10.358
# 1          48   0.828   3.473   7.396  10.411       62   21.324   23.813
# 2         125   0.000   2.107   8.089  15.719       22   10.309   13.133
# 3          52   0.284   0.503   3.592   2.485      116    7.146   10.685
# 4         102   0.500   0.755   3.396   1.937       93    1.091    3.277
# ...       ...     ...     ...     ...     ...      ...      ...      ...
# 53504      93   0.201   2.878   7.397  12.130       86    0.451    3.112
# 53505     114   0.473   1.491   2.974   1.468      115    3.894    6.823
# 53506     179   1.001   3.605   5.040   3.965       12    5.269    8.772
# 53507      41   0.077   0.803   3.884   3.268       34   10.906   10.959
# 53508     178   0.105   2.931  15.303  22.760       58    9.825   15.037
#
#        dew_max  dew_var  utm_zone_label_enc  year  month  ...  \
# 0       15.112   13.424                  59  2019      1  ...
# 1       24.221    2.021                  53  2019      1  ...
# 2       15.422    6.355                  56  2019      1  ...
# 3       13.344    9.417                  30  2019      1  ...
# 4       12.272    4.109                  63  2019      1  ...
# ...        ...      ...                 ...   ...    ...  ...
# 53504    4.512    3.938                   6  2021     12  ...
# 53505    6.861    2.145                  26  2021     12  ...
# 53506   12.661   13.201                  38  2021     12  ...
# 53507   12.744    0.822                  18  2021     12  ...
# 53508   22.294   11.189                  31  2021     12  ...
#
#        agg_utm_zone_month_ws_mid_var  agg_utm_zone_month_so2_mid_mean  \
# 0                           1.818503                         1.765092
# 1                           1.751881                         1.058649
# 2                           1.705490                         2.930600
# 3                           2.176277                         2.920058
# 4                           2.473589                         3.014899
# ...                              ...                              ...
# 53504                       1.764856                         4.187830
# 53505                       3.525578                         6.375333
# 53506                       1.780065                         4.957051
# 53507                       3.677305                         2.396541
# 53508                       1.364541                         5.818959
#
#        agg_utm_zone_month_so2_mid_amax  agg_utm_zone_month_so2_mid_amin  \
# 0                               18.539                            0.095
# 1                                5.678                            0.098
# 2                               10.536                            0.177
# 3                               11.959                            0.267
# 4                               10.557                            0.186
# ...                                ...                              ...
# 53504                           16.156                            0.261
# 53505                           21.069                            0.337
# 53506                           15.524                            0.283
# 53507                            9.138                            0.207
# 53508                           30.609                            0.360
#
#        agg_utm_zone_month_so2_mid_std  agg_utm_zone_month_so2_mid_var  \
# 0                            2.742112                        7.519179
# 1                            1.369169                        1.874625
# 2                            2.280347                        5.199982
# 3                            1.822722                        3.322315
# 4                            1.932086                        3.732956
# ...                               ...                             ...
# 53504                        2.703100                        7.306749
# 53505                        4.446169                       19.768423
# 53506                        3.170206                       10.050207
# 53507                        1.632712                        2.665748
# 53508                        6.506570                       42.335452
#
#        agg_utm_zone_month_o3_max_mean  agg_utm_zone_month_o3_max_amax  \
# 0                           19.701211                          58.443
# 1                           21.289156                          74.567
# 2                           31.605307                         113.124
# 3                           36.718768                         104.535
# 4                           28.624159                          88.670
# ...                               ...                             ...
# 53504                       33.892420                         261.606
# 53505                       28.835381                         133.883
# 53506                       22.595932                          98.058
# 53507                       31.233342                         108.095
# 53508                       29.697192                          95.057
#
#        agg_utm_zone_month_o3_max_amin  agg_utm_zone_month_o3_max_std  \
# 0                               0.096                      15.296717
# 1                               2.562                      15.657755
# 2                               6.342                      16.646464
# 3                               6.430                      17.420901
# 4                               0.000                      20.248588
# ...                               ...                            ...
# 53504                           1.680                      22.516599
# 53505                           5.058                      15.475765
# 53506                           1.250                      15.171066
# 53507                           3.529                      14.304675
# 53508                           4.142                      15.115373
#
#        agg_utm_zone_month_o3_max_var  agg_utm_zone_month_co_min_mean  \
# 0                         233.989545                        1.175803
# 1                         245.165291                        2.238675
# 2                         277.104761                        1.436227
# 3                         303.487797                        2.026226
# 4                         410.005297                        1.780014
# ...                              ...                             ...
# 53504                     506.997226                        2.427723
# 53505                     239.499307                        8.759911
# 53506                     230.161235                        2.749277
# 53507                     204.623718                        1.555833
# 53508                     228.474499                        1.709996
#
#        agg_utm_zone_month_co_min_amax  agg_utm_zone_month_co_min_amin  \
# 0                              11.789                           0.002
# 1                              14.106                           0.000
# 2                               9.998                           0.028
# 3                              10.394                           0.000
# 4                               9.952                           0.018
# ...                               ...                             ...
# 53504                          15.361                           0.000
# 53505                          36.110                           0.060
# 53506                           8.117                           0.041
# 53507                           7.688                           0.000
# 53508                           8.354                           0.000
#
#        agg_utm_zone_month_co_min_std  agg_utm_zone_month_co_min_var  \
# 0                           1.764483                       3.113400
# 1                           2.012904                       4.051781
# 2                           1.719874                       2.957967
# 3                           1.818423                       3.306663
# 4                           1.881121                       3.538615
# ...                              ...                            ...
# 53504                       2.186005                       4.778620
# 53505                       8.953697                      80.168690
# 53506                       1.654128                       2.736140
# 53507                       1.442069                       2.079562
# 53508                       1.822142                       3.320202
#
#               Country  target_enc  diff_no2_mid_aggamin  diff_co_mid_aggamin  \
# 0           Australia   37.362265                -0.434               -2.530
# 1           Australia   37.362265                -0.116               -3.141
# 2           Australia   37.362265                -2.176               -1.118
# 3           Australia   37.362265               -16.539              -10.967
# 4           Australia   37.362265               -20.999               -8.619
# ...               ...         ...                   ...                  ...
# 53504          Turkey   60.981304                -5.191               -9.011
# 53505          Turkey   60.981304               -12.623              -18.085
# 53506          Turkey   60.981304               -10.184              -14.215
# 53507  United Kingdom   40.405919                -8.909               -0.049
# 53508         Vietnam   54.421597                -8.238               -0.018
#
#        diff_co_max_aggamin  co_minmax  o3_minmax  so2_minmax  no2_minmax  \
# 0                   -2.564      1.884      3.519       0.751       2.188
# 1                   -4.727      2.234      9.240      16.056       5.312
# 2                   -2.084      1.010     22.696      46.260      11.258
# 3                  -14.695     10.216     36.457      11.099       9.262
# 4                  -11.004      6.411     38.251       9.550      17.673
# ...                    ...        ...        ...         ...         ...
# 53504              -14.615      9.976     16.895      40.381      41.652
# 53505              -21.787      4.256     13.912      55.123      21.420
# 53506              -21.030     20.996     33.480       7.885      29.541
# 53507               -2.015      2.031     24.178       0.654       8.512
# 53508               -0.049      0.076     15.187       4.733      13.799
#
#        temperature_minmax  humidity_minmax  pressure_minmax  ws_minmax  \
# 0                   9.910           63.995           19.261      2.860
# 1                  12.565           43.941          141.915      6.568
# 2                  23.226           74.081          138.200      8.089
# 3                   3.621           26.496            6.661      3.308
# 4                   3.080           44.615            8.090      2.896
# ...                   ...              ...              ...        ...
# 53504              10.430           38.571          165.334      7.196
# 53505               6.302           28.225           35.241      2.501
# 53506               9.383           43.851           22.349      4.039
# 53507               7.734           50.594           12.786      3.807
# 53508               8.076           30.508            7.477     15.198
#
#        dew_minmax  co_mean_mid  o3_mean_mid  so2_mean_mid  no2_mean_mid  \
# 0           7.441      -0.8990      -0.1385        0.0565        0.5650
# 1           2.897       0.5300       0.1400        8.0220        2.4540
# 2           5.113       0.4980      -0.4430       23.0580        3.8500
# 3           6.198      -1.3500       6.0045        5.2765        2.1190
# 4          11.181      -0.7865      17.1255       -0.5970        2.6075
# ...           ...          ...          ...           ...           ...
# 53504       4.061       0.6280      -1.6255       16.0735       16.3680
# 53505       2.967       1.5930       1.2790       23.2985        5.2590
# 53506       7.392      -3.6490       7.6770        1.0465        6.7525
# 53507       1.838       0.9615      10.3610        0.0790       -3.8590
# 53508      12.469       0.0270      -2.7675        1.4695       -0.5935
#
#        temperature_mean_mid  humidity_mean_mid  pressure_mean_mid  \
# 0                    1.8730            -8.2215            -1.9535
# 1                    0.2705            -3.2715            38.7905
# 2                   11.6130            -6.1095            69.1000
# 3                   -1.5855            -0.1680            -1.5115
# 4                    0.0150            -2.5105             0.5740
# ...                     ...                ...                ...
# 53504                1.0360             6.1755            33.8890
# 53505               -0.8810             2.6295            -1.2925
# 53506               -1.2255           -10.0365             5.1545
# 53507               -2.2380           -15.1850            -0.7530
# 53508               -1.2190            -4.4920             1.6245
#
#        ws_mean_mid  co_humidity  o3_humidity  so2_humidity  no2_humidity  \
# 0           0.5830     1.824033     3.024797      0.329594      0.372554
# 1           0.6390     2.362720     5.624179      0.075762      0.223571
# 2           1.9375     0.826756     8.652274      1.011170      1.900088
# 3           1.4350     9.599445    12.291357      2.807516     15.185793
# 4           1.1930     6.661452     1.802529      4.446084     16.221990
# ...            ...          ...          ...           ...           ...
# 53504       0.9210     4.300636    10.411690      3.720807      2.516876
# 53505       0.2325    15.116322     5.460892      7.125220     11.935034
# 53506      -0.5845    10.767347     7.195077      2.240212      8.159801
# 53507       1.1775     0.093829     1.715134      0.404058      7.980572
# 53508       4.7730     0.059107    16.526591      2.032108      7.197709
#
#        weekday_cos  weekday_sin  day_cos       day_sin  month_cos  \
# 0              0.5     0.866025  0.97953  2.012985e-01   0.866025
# 1              0.5     0.866025  0.97953  2.012985e-01   0.866025
# 2              0.5     0.866025  0.97953  2.012985e-01   0.866025
# 3              0.5     0.866025  0.97953  2.012985e-01   0.866025
# 4              0.5     0.866025  0.97953  2.012985e-01   0.866025
# ...            ...          ...      ...           ...        ...
# 53504         -0.5    -0.866025  1.00000 -2.449294e-16   1.000000
# 53505         -0.5    -0.866025  1.00000 -2.449294e-16   1.000000
# 53506         -0.5    -0.866025  1.00000 -2.449294e-16   1.000000
# 53507         -0.5    -0.866025  1.00000 -2.449294e-16   1.000000
# 53508         -0.5    -0.866025  1.00000 -2.449294e-16   1.000000
#
#           month_sin  year_cos      year_sin
# 0      5.000000e-01  0.999981 -6.217857e-03
# 1      5.000000e-01  0.999981 -6.217857e-03
# 2      5.000000e-01  0.999981 -6.217857e-03
# 3      5.000000e-01  0.999981 -6.217857e-03
# 4      5.000000e-01  0.999981 -6.217857e-03
# ...             ...       ...           ...
# 53504 -2.449294e-16  1.000000 -2.449294e-16
# 53505 -2.449294e-16  1.000000 -2.449294e-16
# 53506 -2.449294e-16  1.000000 -2.449294e-16
# 53507 -2.449294e-16  1.000000 -2.449294e-16
# 53508 -2.449294e-16  1.000000 -2.449294e-16
#
# [249450 rows x 136 columns]

# %%
df_all = df_all.drop('Country',axis=1)

# %%
#df_all.plot.scatter('month_sin', 'month_cos').set_aspect('equal')

# %%
df_train = df_all.iloc[:len(df_train)]
df_test = df_all.iloc[len(df_train):].reset_index(drop=True)

# %%
target = train_data[config.target]

# %%
'''
# LightGBM用のデータセットに変換
trainval = opt_lgb.Dataset(df_train, target)

# ハイパーパラメータサーチ&モデル構築
params = {'objective': 'regression',
          'metric': 'rmse',
          'random_seed':42} 

# クロスバリデーションによるハイパーパラメータの探索 3fold
tuner = opt_lgb.LightGBMTunerCV(params, trainval, verbose_eval=100, early_stopping_rounds=100, folds=KFold(n_splits=5))

# ハイパーパラメータ探索の実行
tuner.run()

# サーチしたパラメータの表示
best_params = tuner.best_params
print("  Params: ")
for key, value in best_params.items():
    print("    {}: {}".format(key, value))
'''
# Out:
# '\n# LightGBM用のデータセットに変換\ntrainval = opt_lgb.Dataset(df_train, target)\n\n# ハイパーパラメータサーチ&モデル構築\nparams = {\'objective\': \'regression\',\n          \'metric\': \'rmse\',\n          \'random_seed\':42} \n\n# クロスバリデーションによるハイパーパラメータの探索 3fold\ntuner = opt_lgb.LightGBMTunerCV(params, trainval, verbose_eval=100, early_stopping_rounds=100, folds=KFold(n_splits=5))\n\n# ハイパーパラメータ探索の実行\ntuner.run()\n\n# サーチしたパラメータの表示\nbest_params = tuner.best_params\nprint("  Params: ")\nfor key, value in best_params.items():\n    print("    {}: {}".format(key, value))\n'

# %%
def group_kfold_split(df, col_group, n_splits, random_state):

    group_id = df[col_group].value_counts().reset_index()
    group_id.columns = [col_group, 'count']
    group_id_list = group_id[col_group].unique()

    kf = KFold(n_splits=n_splits, shuffle=True, random_state=random_state)
    kf_list = list(kf.split(group_id_list))
    cv_idx = [(df[col_group].isin(group_id_list[idx_trn]), df[col_group].isin(group_id_list[idx_val])) for idx_trn, idx_val in kf_list]

    return [(df[idx_trn].index.tolist(), df[idx_val].index.tolist()) for idx_trn, idx_val in cv_idx]

# %%
#cross validation strategy
kf = KFold(n_splits=config.nfold, shuffle=True, random_state=config.random_seed)
kf_cv = list(kf.split(train_data))
gkf_cv = group_kfold_split(train_data, 'City', n_splits=config.nfold, random_state=config.random_seed)

# %%
def cal_rmse(y_true, y_pred):
  return np.sqrt(mean_squared_error(y_true, y_pred))

# %%
def fit_lgb(x, y, cv, model_params, fit_params, fobj=None, feval=None):

    models = []
    n_records = y.shape[0]
    oof_pred = np.zeros(n_records, dtype=np.float32)
    fold = 0
    data_labels = [re.sub(r'[",\[\]{}:()]', '_', c) for c in x.columns.tolist()]

    model_params.update(deterministic = True)

    for trn_idx, val_idx in cv:

        fold += 1
        x_train, x_valid = x.iloc[trn_idx].values, x.iloc[val_idx].values
        y_train, y_valid = np.array(y.iloc[trn_idx]), np.array(y.iloc[val_idx])

        lgb_train = lgb.Dataset(x_train, y_train, feature_name=data_labels)
        lgb_valid = lgb.Dataset(x_valid, y_valid, feature_name=data_labels, reference=lgb_train)

        lgb_model = lgb.train(model_params,
                              train_set=lgb_train,
                              valid_sets=[lgb_train, lgb_valid],
                              fobj=fobj,
                              feval=feval,
                              verbose_eval=fit_params['verbose_eval'],
                              num_boost_round=fit_params['num_boost_rounds'],
                              callbacks=[lgb.early_stopping(fit_params['early_stopping_rounds'])],
                              )

        pred_valid = lgb_model.predict(x_valid, num_iteration=lgb_model.best_iteration)
        oof_pred[val_idx] = pred_valid
        models.append(lgb_model)

        print(f' - fold{fold}_RMSE - {cal_rmse(y_valid, pred_valid):4f}')

    print(f' - CV_RMSE - {cal_rmse(oof_pred, np.array(y)):4f}') 

    return oof_pred, models

# %%
'''
#Params: 
    objective: regression
    metric: rmse
    random_seed: 42
    feature_pre_filter: False
    lambda_l1: 0.000338595481765331
    lambda_l2: 9.60230430368646
    num_leaves: 32
    feature_fraction: 0.6799999999999999
    bagging_fraction: 1.0
    bagging_freq: 0
    min_child_samples: 20
'''
# Out:
# '\n#Params: \n    objective: regression\n    metric: rmse\n    random_seed: 42\n    feature_pre_filter: False\n    lambda_l1: 0.000338595481765331\n    lambda_l2: 9.60230430368646\n    num_leaves: 32\n    feature_fraction: 0.6799999999999999\n    bagging_fraction: 1.0\n    bagging_freq: 0\n    min_child_samples: 20\n'

# %%
lgb_model_params = {'boosting_type': 'gbdt',
                
                    'objective': 'rmse',

                    'lambda_l1': 0.000338595481765331,
                    'lambda_l2': 9.60230430368646,
                    'feature_fraction': 0.6799999999999999,

                    'learning_rate': 0.05,
                    'max_depth': -1,
                    'num_leaves': 32,
                    'min_data_in_leaf': 20,
                    'max_bin': 255,
                    
                    'reg_lambda': 1.0,
                    'reg_alpha': 1.,
                   
                    'colsample_bytree': 0.8,
                    'subsample': 0.8,
                    'subsample_freq': 1,
                    
                    'random_state': config.random_seed,
                    'verbose': -1,
                    'n_jobs': -1,
                    }

lgb_fit_params ={'num_boost_rounds': 10000,
                 'early_stopping_rounds': 100,
                 'verbose_eval': 100,
                }

# %%
oof_valid_lgb1, lgb_models1 = fit_lgb(x=df_train, y=target, cv=kf_cv,
                                      model_params=lgb_model_params, fit_params=lgb_fit_params
                                     )
# Out:
# Training until validation scores don't improve for 100 rounds.
# [100]	training's rmse: 20.9373	valid_1's rmse: 21.0961
# [200]	training's rmse: 19.8238	valid_1's rmse: 20.2118
# [300]	training's rmse: 19.2011	valid_1's rmse: 19.866
# [400]	training's rmse: 18.7522	valid_1's rmse: 19.6632
# [500]	training's rmse: 18.3742	valid_1's rmse: 19.5335
# [600]	training's rmse: 18.0406	valid_1's rmse: 19.4402
# [700]	training's rmse: 17.7323	valid_1's rmse: 19.3597
# [800]	training's rmse: 17.4496	valid_1's rmse: 19.2957
# [900]	training's rmse: 17.1796	valid_1's rmse: 19.2463
# [1000]	training's rmse: 16.9269	valid_1's rmse: 19.2043
# [1100]	training's rmse: 16.6927	valid_1's rmse: 19.1663
# [1200]	training's rmse: 16.4643	valid_1's rmse: 19.1308
# [1300]	training's rmse: 16.2451	valid_1's rmse: 19.0968
# [1400]	training's rmse: 16.0374	valid_1's rmse: 19.0731
# [1500]	training's rmse: 15.8359	valid_1's rmse: 19.0468
# [1600]	training's rmse: 15.6322	valid_1's rmse: 19.0191
# [1700]	training's rmse: 15.4398	valid_1's rmse: 18.9986
# [1800]	training's rmse: 15.254	valid_1's rmse: 18.9792
# [1900]	training's rmse: 15.0845	valid_1's rmse: 18.9587
# [2000]	training's rmse: 14.911	valid_1's rmse: 18.9436
# [2100]	training's rmse: 14.7419	valid_1's rmse: 18.9291
# [2200]	training's rmse: 14.5765	valid_1's rmse: 18.9135
# [2300]	training's rmse: 14.4117	valid_1's rmse: 18.8989
# [2400]	training's rmse: 14.2523	valid_1's rmse: 18.8882
# [2500]	training's rmse: 14.1	valid_1's rmse: 18.8716
# [2600]	training's rmse: 13.9446	valid_1's rmse: 18.8608
# [2700]	training's rmse: 13.7948	valid_1's rmse: 18.8474
# [2800]	training's rmse: 13.6525	valid_1's rmse: 18.8383
# [2900]	training's rmse: 13.509	valid_1's rmse: 18.8296
# [3000]	training's rmse: 13.3735	valid_1's rmse: 18.823
# [3100]	training's rmse: 13.2357	valid_1's rmse: 18.8158
# [3200]	training's rmse: 13.102	valid_1's rmse: 18.8099
# [3300]	training's rmse: 12.9705	valid_1's rmse: 18.7981
# [3400]	training's rmse: 12.8441	valid_1's rmse: 18.7914
# [3500]	training's rmse: 12.7136	valid_1's rmse: 18.789
# [3600]	training's rmse: 12.5868	valid_1's rmse: 18.7794
# [3700]	training's rmse: 12.464	valid_1's rmse: 18.7723
# [3800]	training's rmse: 12.3407	valid_1's rmse: 18.7647
# [3900]	training's rmse: 12.2205	valid_1's rmse: 18.7613
# [4000]	training's rmse: 12.1018	valid_1's rmse: 18.7534
# [4100]	training's rmse: 11.9862	valid_1's rmse: 18.7488
# [4200]	training's rmse: 11.873	valid_1's rmse: 18.7424
# [4300]	training's rmse: 11.7598	valid_1's rmse: 18.7364
# [4400]	training's rmse: 11.6488	valid_1's rmse: 18.7354
# [4500]	training's rmse: 11.5398	valid_1's rmse: 18.7321
# [4600]	training's rmse: 11.4328	valid_1's rmse: 18.7265
# [4700]	training's rmse: 11.3252	valid_1's rmse: 18.7226
# [4800]	training's rmse: 11.2271	valid_1's rmse: 18.7176
# [4900]	training's rmse: 11.1244	valid_1's rmse: 18.7105
# [5000]	training's rmse: 11.0208	valid_1's rmse: 18.7085
# [5100]	training's rmse: 10.9187	valid_1's rmse: 18.7057
# [5200]	training's rmse: 10.8216	valid_1's rmse: 18.7021
# [5300]	training's rmse: 10.725	valid_1's rmse: 18.697
# [5400]	training's rmse: 10.6282	valid_1's rmse: 18.6915
# [5500]	training's rmse: 10.529	valid_1's rmse: 18.6895
# [5600]	training's rmse: 10.4345	valid_1's rmse: 18.6875
# [5700]	training's rmse: 10.3434	valid_1's rmse: 18.6841
# [5800]	training's rmse: 10.2501	valid_1's rmse: 18.6812
# [5900]	training's rmse: 10.1631	valid_1's rmse: 18.6784
# [6000]	training's rmse: 10.0737	valid_1's rmse: 18.6759
# [6100]	training's rmse: 9.98403	valid_1's rmse: 18.6744
# [6200]	training's rmse: 9.89682	valid_1's rmse: 18.6718
# [6300]	training's rmse: 9.81219	valid_1's rmse: 18.6692
# [6400]	training's rmse: 9.72895	valid_1's rmse: 18.669
# [6500]	training's rmse: 9.64538	valid_1's rmse: 18.6681
# [6600]	training's rmse: 9.56415	valid_1's rmse: 18.6663
# [6700]	training's rmse: 9.48192	valid_1's rmse: 18.665
# [6800]	training's rmse: 9.40113	valid_1's rmse: 18.6649
# [6900]	training's rmse: 9.32059	valid_1's rmse: 18.6631
# [7000]	training's rmse: 9.24205	valid_1's rmse: 18.6618
# [7100]	training's rmse: 9.16433	valid_1's rmse: 18.6572
# [7200]	training's rmse: 9.08731	valid_1's rmse: 18.6539
# [7300]	training's rmse: 9.0099	valid_1's rmse: 18.652
# [7400]	training's rmse: 8.93464	valid_1's rmse: 18.651
# [7500]	training's rmse: 8.8601	valid_1's rmse: 18.6496
# Early stopping, best iteration is:
# [7433]	training's rmse: 8.91008	valid_1's rmse: 18.6494
#  - fold1_RMSE - 18.649363
# Training until validation scores don't improve for 100 rounds.
# [100]	training's rmse: 20.873	valid_1's rmse: 21.319
# [200]	training's rmse: 19.7668	valid_1's rmse: 20.503
# [300]	training's rmse: 19.1481	valid_1's rmse: 20.188
# [400]	training's rmse: 18.6885	valid_1's rmse: 19.9922
# [500]	training's rmse: 18.3146	valid_1's rmse: 19.8784
# [600]	training's rmse: 17.9866	valid_1's rmse: 19.7848
# [700]	training's rmse: 17.6775	valid_1's rmse: 19.7145
# [800]	training's rmse: 17.3921	valid_1's rmse: 19.659
# [900]	training's rmse: 17.1264	valid_1's rmse: 19.6133
# [1000]	training's rmse: 16.8668	valid_1's rmse: 19.5646
# [1100]	training's rmse: 16.6276	valid_1's rmse: 19.5222
# [1200]	training's rmse: 16.398	valid_1's rmse: 19.4943
# [1300]	training's rmse: 16.1781	valid_1's rmse: 19.4566
# [1400]	training's rmse: 15.9646	valid_1's rmse: 19.4292
# [1500]	training's rmse: 15.7715	valid_1's rmse: 19.4076
# [1600]	training's rmse: 15.5728	valid_1's rmse: 19.3806
# [1700]	training's rmse: 15.3836	valid_1's rmse: 19.36
# [1800]	training's rmse: 15.2025	valid_1's rmse: 19.3336
# [1900]	training's rmse: 15.0259	valid_1's rmse: 19.3173
# [2000]	training's rmse: 14.8495	valid_1's rmse: 19.3009
# [2100]	training's rmse: 14.6852	valid_1's rmse: 19.2849
# [2200]	training's rmse: 14.5193	valid_1's rmse: 19.2713
# [2300]	training's rmse: 14.3588	valid_1's rmse: 19.2581
# [2400]	training's rmse: 14.203	valid_1's rmse: 19.2439
# [2500]	training's rmse: 14.0556	valid_1's rmse: 19.2323
# [2600]	training's rmse: 13.9021	valid_1's rmse: 19.2238
# [2700]	training's rmse: 13.7537	valid_1's rmse: 19.2089
# [2800]	training's rmse: 13.608	valid_1's rmse: 19.1971
# [2900]	training's rmse: 13.4678	valid_1's rmse: 19.1912
# [3000]	training's rmse: 13.3301	valid_1's rmse: 19.1834
# [3100]	training's rmse: 13.1942	valid_1's rmse: 19.177
# [3200]	training's rmse: 13.0629	valid_1's rmse: 19.168
# [3300]	training's rmse: 12.931	valid_1's rmse: 19.161
# [3400]	training's rmse: 12.8015	valid_1's rmse: 19.1508
# [3500]	training's rmse: 12.6755	valid_1's rmse: 19.1455
# [3600]	training's rmse: 12.5495	valid_1's rmse: 19.1398
# [3700]	training's rmse: 12.4285	valid_1's rmse: 19.1359
# [3800]	training's rmse: 12.307	valid_1's rmse: 19.1332
# [3900]	training's rmse: 12.1889	valid_1's rmse: 19.1262
# [4000]	training's rmse: 12.0723	valid_1's rmse: 19.1215
# [4100]	training's rmse: 11.9561	valid_1's rmse: 19.1173
# [4200]	training's rmse: 11.8471	valid_1's rmse: 19.112
# [4300]	training's rmse: 11.7367	valid_1's rmse: 19.1087
# [4400]	training's rmse: 11.6239	valid_1's rmse: 19.1075
# [4500]	training's rmse: 11.5165	valid_1's rmse: 19.1047
# [4600]	training's rmse: 11.4087	valid_1's rmse: 19.1026
# [4700]	training's rmse: 11.302	valid_1's rmse: 19.1005
# [4800]	training's rmse: 11.1958	valid_1's rmse: 19.098
# [4900]	training's rmse: 11.0921	valid_1's rmse: 19.0936
# [5000]	training's rmse: 10.9931	valid_1's rmse: 19.0925
# [5100]	training's rmse: 10.8945	valid_1's rmse: 19.0907
# [5200]	training's rmse: 10.7958	valid_1's rmse: 19.0868
# [5300]	training's rmse: 10.7014	valid_1's rmse: 19.0827
# [5400]	training's rmse: 10.606	valid_1's rmse: 19.0807
# [5500]	training's rmse: 10.5134	valid_1's rmse: 19.0797
# Early stopping, best iteration is:
# [5415]	training's rmse: 10.5917	valid_1's rmse: 19.0792
#  - fold2_RMSE - 19.079209
# Training until validation scores don't improve for 100 rounds.
# [100]	training's rmse: 20.8068	valid_1's rmse: 21.6649
# [200]	training's rmse: 19.7128	valid_1's rmse: 20.7749
# [300]	training's rmse: 19.1011	valid_1's rmse: 20.4162
# [400]	training's rmse: 18.6594	valid_1's rmse: 20.2209
# [500]	training's rmse: 18.2841	valid_1's rmse: 20.0897
# [600]	training's rmse: 17.9609	valid_1's rmse: 19.9877
# [700]	training's rmse: 17.6562	valid_1's rmse: 19.9135
# [800]	training's rmse: 17.3712	valid_1's rmse: 19.8502
# [900]	training's rmse: 17.1084	valid_1's rmse: 19.7804
# [1000]	training's rmse: 16.8501	valid_1's rmse: 19.7332
# [1100]	training's rmse: 16.6148	valid_1's rmse: 19.6912
# [1200]	training's rmse: 16.3913	valid_1's rmse: 19.6534
# [1300]	training's rmse: 16.1702	valid_1's rmse: 19.6169
# [1400]	training's rmse: 15.9611	valid_1's rmse: 19.588
# [1500]	training's rmse: 15.7641	valid_1's rmse: 19.5566
# [1600]	training's rmse: 15.569	valid_1's rmse: 19.5253
# [1700]	training's rmse: 15.3765	valid_1's rmse: 19.5044
# [1800]	training's rmse: 15.1926	valid_1's rmse: 19.4828
# [1900]	training's rmse: 15.009	valid_1's rmse: 19.4605
# [2000]	training's rmse: 14.8342	valid_1's rmse: 19.4438
# [2100]	training's rmse: 14.6682	valid_1's rmse: 19.4306
# [2200]	training's rmse: 14.5038	valid_1's rmse: 19.4142
# [2300]	training's rmse: 14.3425	valid_1's rmse: 19.403
# [2400]	training's rmse: 14.1863	valid_1's rmse: 19.3933
# [2500]	training's rmse: 14.032	valid_1's rmse: 19.3771
# [2600]	training's rmse: 13.8804	valid_1's rmse: 19.3669
# [2700]	training's rmse: 13.7312	valid_1's rmse: 19.3538
# [2800]	training's rmse: 13.5871	valid_1's rmse: 19.3411
# [2900]	training's rmse: 13.4494	valid_1's rmse: 19.3309
# [3000]	training's rmse: 13.3096	valid_1's rmse: 19.3208
# [3100]	training's rmse: 13.1727	valid_1's rmse: 19.3105
# [3200]	training's rmse: 13.0398	valid_1's rmse: 19.3031
# [3300]	training's rmse: 12.9108	valid_1's rmse: 19.2947
# [3400]	training's rmse: 12.7806	valid_1's rmse: 19.2859
# [3500]	training's rmse: 12.6517	valid_1's rmse: 19.2794
# [3600]	training's rmse: 12.5303	valid_1's rmse: 19.2754
# [3700]	training's rmse: 12.4078	valid_1's rmse: 19.2657
# [3800]	training's rmse: 12.29	valid_1's rmse: 19.2566
# [3900]	training's rmse: 12.1706	valid_1's rmse: 19.252
# [4000]	training's rmse: 12.0574	valid_1's rmse: 19.2468
# [4100]	training's rmse: 11.9416	valid_1's rmse: 19.2425
# [4200]	training's rmse: 11.8286	valid_1's rmse: 19.239
# [4300]	training's rmse: 11.721	valid_1's rmse: 19.2362
# [4400]	training's rmse: 11.6129	valid_1's rmse: 19.2312
# [4500]	training's rmse: 11.5067	valid_1's rmse: 19.2249
# [4600]	training's rmse: 11.3969	valid_1's rmse: 19.2247
# [4700]	training's rmse: 11.2908	valid_1's rmse: 19.2205
# [4800]	training's rmse: 11.1881	valid_1's rmse: 19.213
# [4900]	training's rmse: 11.0826	valid_1's rmse: 19.2116
# [5000]	training's rmse: 10.9798	valid_1's rmse: 19.2055
# [5100]	training's rmse: 10.8804	valid_1's rmse: 19.2029
# [5200]	training's rmse: 10.7793	valid_1's rmse: 19.1998
# [5300]	training's rmse: 10.6808	valid_1's rmse: 19.1945
# [5400]	training's rmse: 10.5865	valid_1's rmse: 19.1926
# [5500]	training's rmse: 10.4943	valid_1's rmse: 19.1912
# [5600]	training's rmse: 10.4011	valid_1's rmse: 19.1868
# [5700]	training's rmse: 10.3076	valid_1's rmse: 19.1855
# [5800]	training's rmse: 10.2166	valid_1's rmse: 19.1842
# [5900]	training's rmse: 10.1274	valid_1's rmse: 19.1813
# [6000]	training's rmse: 10.0349	valid_1's rmse: 19.1768
# [6100]	training's rmse: 9.94889	valid_1's rmse: 19.1763
# [6200]	training's rmse: 9.86236	valid_1's rmse: 19.1749
# [6300]	training's rmse: 9.77853	valid_1's rmse: 19.1718
# [6400]	training's rmse: 9.69187	valid_1's rmse: 19.1718
# Early stopping, best iteration is:
# [6332]	training's rmse: 9.75094	valid_1's rmse: 19.1705
#  - fold3_RMSE - 19.170483
# Training until validation scores don't improve for 100 rounds.
# [100]	training's rmse: 20.8706	valid_1's rmse: 21.2826
# [200]	training's rmse: 19.7592	valid_1's rmse: 20.4467
# [300]	training's rmse: 19.1582	valid_1's rmse: 20.1062
# [400]	training's rmse: 18.7164	valid_1's rmse: 19.9196
# [500]	training's rmse: 18.3491	valid_1's rmse: 19.7995
# [600]	training's rmse: 18.0062	valid_1's rmse: 19.6906
# [700]	training's rmse: 17.6948	valid_1's rmse: 19.6113
# [800]	training's rmse: 17.4194	valid_1's rmse: 19.5532
# [900]	training's rmse: 17.1621	valid_1's rmse: 19.4967
# [1000]	training's rmse: 16.9154	valid_1's rmse: 19.4525
# [1100]	training's rmse: 16.6763	valid_1's rmse: 19.4071
# [1200]	training's rmse: 16.4426	valid_1's rmse: 19.3717
# [1300]	training's rmse: 16.2198	valid_1's rmse: 19.3431
# [1400]	training's rmse: 16.0078	valid_1's rmse: 19.3208
# [1500]	training's rmse: 15.81	valid_1's rmse: 19.2958
# [1600]	training's rmse: 15.6104	valid_1's rmse: 19.2656
# [1700]	training's rmse: 15.4187	valid_1's rmse: 19.2496
# [1800]	training's rmse: 15.2338	valid_1's rmse: 19.2212
# [1900]	training's rmse: 15.0523	valid_1's rmse: 19.2035
# [2000]	training's rmse: 14.8804	valid_1's rmse: 19.1852
# [2100]	training's rmse: 14.7106	valid_1's rmse: 19.1665
# [2200]	training's rmse: 14.5517	valid_1's rmse: 19.1533
# [2300]	training's rmse: 14.3916	valid_1's rmse: 19.1381
# [2400]	training's rmse: 14.2314	valid_1's rmse: 19.1267
# [2500]	training's rmse: 14.0751	valid_1's rmse: 19.1157
# [2600]	training's rmse: 13.9248	valid_1's rmse: 19.1035
# [2700]	training's rmse: 13.7839	valid_1's rmse: 19.0902
# [2800]	training's rmse: 13.6391	valid_1's rmse: 19.0767
# [2900]	training's rmse: 13.5002	valid_1's rmse: 19.0657
# [3000]	training's rmse: 13.3614	valid_1's rmse: 19.059
# [3100]	training's rmse: 13.2247	valid_1's rmse: 19.0483
# [3200]	training's rmse: 13.0887	valid_1's rmse: 19.0414
# [3300]	training's rmse: 12.9592	valid_1's rmse: 19.0327
# [3400]	training's rmse: 12.8342	valid_1's rmse: 19.0261
# [3500]	training's rmse: 12.7098	valid_1's rmse: 19.0193
# [3600]	training's rmse: 12.5862	valid_1's rmse: 19.0098
# [3700]	training's rmse: 12.4651	valid_1's rmse: 19.0005
# [3800]	training's rmse: 12.3468	valid_1's rmse: 18.9929
# [3900]	training's rmse: 12.224	valid_1's rmse: 18.9842
# [4000]	training's rmse: 12.1107	valid_1's rmse: 18.9793
# [4100]	training's rmse: 11.998	valid_1's rmse: 18.9764
# [4200]	training's rmse: 11.8833	valid_1's rmse: 18.9712
# [4300]	training's rmse: 11.77	valid_1's rmse: 18.9674
# [4400]	training's rmse: 11.6592	valid_1's rmse: 18.9625
# [4500]	training's rmse: 11.5513	valid_1's rmse: 18.9596
# [4600]	training's rmse: 11.4443	valid_1's rmse: 18.9563
# [4700]	training's rmse: 11.3395	valid_1's rmse: 18.9501
# [4800]	training's rmse: 11.2327	valid_1's rmse: 18.9448
# [4900]	training's rmse: 11.1322	valid_1's rmse: 18.9421
# [5000]	training's rmse: 11.0298	valid_1's rmse: 18.9383
# [5100]	training's rmse: 10.9322	valid_1's rmse: 18.9368
# [5200]	training's rmse: 10.8339	valid_1's rmse: 18.9312
# [5300]	training's rmse: 10.7385	valid_1's rmse: 18.928
# [5400]	training's rmse: 10.6445	valid_1's rmse: 18.9236
# [5500]	training's rmse: 10.5511	valid_1's rmse: 18.9182
# [5600]	training's rmse: 10.4593	valid_1's rmse: 18.9133
# [5700]	training's rmse: 10.3677	valid_1's rmse: 18.9108
# [5800]	training's rmse: 10.2762	valid_1's rmse: 18.909
# [5900]	training's rmse: 10.1849	valid_1's rmse: 18.9061
# [6000]	training's rmse: 10.0957	valid_1's rmse: 18.9019
# [6100]	training's rmse: 10.0073	valid_1's rmse: 18.8981
# [6200]	training's rmse: 9.92247	valid_1's rmse: 18.8944
# [6300]	training's rmse: 9.83993	valid_1's rmse: 18.8909
# [6400]	training's rmse: 9.75488	valid_1's rmse: 18.8889
# [6500]	training's rmse: 9.66761	valid_1's rmse: 18.8874
# [6600]	training's rmse: 9.58498	valid_1's rmse: 18.8845
# [6700]	training's rmse: 9.50085	valid_1's rmse: 18.8836
# [6800]	training's rmse: 9.42148	valid_1's rmse: 18.8824
# [6900]	training's rmse: 9.33886	valid_1's rmse: 18.8791
# [7000]	training's rmse: 9.25847	valid_1's rmse: 18.8774
# [7100]	training's rmse: 9.1815	valid_1's rmse: 18.8774
# Early stopping, best iteration is:
# [7011]	training's rmse: 9.25019	valid_1's rmse: 18.8765
#  - fold4_RMSE - 18.876504
# Training until validation scores don't improve for 100 rounds.
# [100]	training's rmse: 20.9207	valid_1's rmse: 20.9198
# [200]	training's rmse: 19.8237	valid_1's rmse: 20.1021
# [300]	training's rmse: 19.2127	valid_1's rmse: 19.774
# [400]	training's rmse: 18.7699	valid_1's rmse: 19.5953
# [500]	training's rmse: 18.3884	valid_1's rmse: 19.4809
# [600]	training's rmse: 18.0561	valid_1's rmse: 19.3931
# [700]	training's rmse: 17.7491	valid_1's rmse: 19.3106
# [800]	training's rmse: 17.4685	valid_1's rmse: 19.2501
# [900]	training's rmse: 17.2002	valid_1's rmse: 19.1963
# [1000]	training's rmse: 16.9477	valid_1's rmse: 19.1523
# [1100]	training's rmse: 16.712	valid_1's rmse: 19.1181
# [1200]	training's rmse: 16.485	valid_1's rmse: 19.0807
# [1300]	training's rmse: 16.2672	valid_1's rmse: 19.0492
# [1400]	training's rmse: 16.0537	valid_1's rmse: 19.0197
# [1500]	training's rmse: 15.8491	valid_1's rmse: 18.9967
# [1600]	training's rmse: 15.6486	valid_1's rmse: 18.9766
# [1700]	training's rmse: 15.4591	valid_1's rmse: 18.9547
# [1800]	training's rmse: 15.2689	valid_1's rmse: 18.9428
# [1900]	training's rmse: 15.093	valid_1's rmse: 18.9215
# [2000]	training's rmse: 14.9203	valid_1's rmse: 18.9029
# [2100]	training's rmse: 14.7544	valid_1's rmse: 18.8895
# [2200]	training's rmse: 14.5901	valid_1's rmse: 18.8788
# [2300]	training's rmse: 14.4258	valid_1's rmse: 18.8655
# [2400]	training's rmse: 14.2637	valid_1's rmse: 18.8548
# [2500]	training's rmse: 14.1116	valid_1's rmse: 18.8457
# [2600]	training's rmse: 13.9578	valid_1's rmse: 18.8351
# [2700]	training's rmse: 13.8093	valid_1's rmse: 18.8254
# [2800]	training's rmse: 13.6684	valid_1's rmse: 18.8165
# [2900]	training's rmse: 13.527	valid_1's rmse: 18.8111
# [3000]	training's rmse: 13.3897	valid_1's rmse: 18.8035
# [3100]	training's rmse: 13.2518	valid_1's rmse: 18.7982
# [3200]	training's rmse: 13.1177	valid_1's rmse: 18.7917
# [3300]	training's rmse: 12.9852	valid_1's rmse: 18.7812
# [3400]	training's rmse: 12.8568	valid_1's rmse: 18.773
# [3500]	training's rmse: 12.7298	valid_1's rmse: 18.7675
# [3600]	training's rmse: 12.6078	valid_1's rmse: 18.7592
# [3700]	training's rmse: 12.4884	valid_1's rmse: 18.7561
# [3800]	training's rmse: 12.3671	valid_1's rmse: 18.7497
# [3900]	training's rmse: 12.2471	valid_1's rmse: 18.7404
# [4000]	training's rmse: 12.1295	valid_1's rmse: 18.7369
# [4100]	training's rmse: 12.0142	valid_1's rmse: 18.7325
# [4200]	training's rmse: 11.9031	valid_1's rmse: 18.7302
# [4300]	training's rmse: 11.7895	valid_1's rmse: 18.7278
# [4400]	training's rmse: 11.6772	valid_1's rmse: 18.7259
# [4500]	training's rmse: 11.5671	valid_1's rmse: 18.7181
# [4600]	training's rmse: 11.4623	valid_1's rmse: 18.7118
# [4700]	training's rmse: 11.3537	valid_1's rmse: 18.7073
# [4800]	training's rmse: 11.2494	valid_1's rmse: 18.7038
# [4900]	training's rmse: 11.1464	valid_1's rmse: 18.6984
# [5000]	training's rmse: 11.0454	valid_1's rmse: 18.6965
# [5100]	training's rmse: 10.9458	valid_1's rmse: 18.6951
# [5200]	training's rmse: 10.8468	valid_1's rmse: 18.6922
# [5300]	training's rmse: 10.7496	valid_1's rmse: 18.6889
# [5400]	training's rmse: 10.6532	valid_1's rmse: 18.6871
# [5500]	training's rmse: 10.5572	valid_1's rmse: 18.6848
# [5600]	training's rmse: 10.4665	valid_1's rmse: 18.6816
# [5700]	training's rmse: 10.3754	valid_1's rmse: 18.6793
# [5800]	training's rmse: 10.2809	valid_1's rmse: 18.6761
# [5900]	training's rmse: 10.1912	valid_1's rmse: 18.6731
# [6000]	training's rmse: 10.102	valid_1's rmse: 18.6724
# [6100]	training's rmse: 10.0153	valid_1's rmse: 18.6712
# [6200]	training's rmse: 9.92861	valid_1's rmse: 18.6696
# [6300]	training's rmse: 9.8438	valid_1's rmse: 18.6665
# [6400]	training's rmse: 9.75933	valid_1's rmse: 18.6634
# [6500]	training's rmse: 9.67333	valid_1's rmse: 18.6619
# [6600]	training's rmse: 9.59102	valid_1's rmse: 18.6604
# [6700]	training's rmse: 9.50792	valid_1's rmse: 18.6582
# [6800]	training's rmse: 9.42821	valid_1's rmse: 18.6584
# [6900]	training's rmse: 9.34658	valid_1's rmse: 18.6565
# [7000]	training's rmse: 9.26489	valid_1's rmse: 18.6539
# [7100]	training's rmse: 9.1864	valid_1's rmse: 18.6508
# [7200]	training's rmse: 9.10912	valid_1's rmse: 18.6492
# [7300]	training's rmse: 9.03417	valid_1's rmse: 18.6467
# [7400]	training's rmse: 8.95869	valid_1's rmse: 18.6458
# [7500]	training's rmse: 8.88253	valid_1's rmse: 18.645
# [7600]	training's rmse: 8.80912	valid_1's rmse: 18.6433
# [7700]	training's rmse: 8.73794	valid_1's rmse: 18.6437
# Early stopping, best iteration is:
# [7614]	training's rmse: 8.79949	valid_1's rmse: 18.6424
#  - fold5_RMSE - 18.642383
#  - CV_RMSE - 18.884825

# %%
def visualize_importance(models, feat_train_df, file_name):
    
    feature_importance_df = pd.DataFrame()

    for i, model in enumerate(models):
        _df = pd.DataFrame()
        _df['feature_importance'] = model.feature_importance(importance_type='gain')
        _df['column'] = feat_train_df.columns
        _df['fold'] = i + 1
        feature_importance_df = pd.concat([feature_importance_df, _df],
                                          axis=0,
                                          ignore_index=True
                                         )
    
    mean_feature_importance = feature_importance_df.groupby('column').mean().sort_values('feature_importance', ascending=False)
    mean_feature_importance.to_csv(os.path.join(Output_Model, f'feature_importance_{file_name}.csv'), index=True)
    
    order = feature_importance_df.groupby('column')\
        .sum()[['feature_importance']]\
        .sort_values('feature_importance', ascending=False).index[:100]
    
    fig, ax = plt.subplots(figsize=(12, max(8, len(order) * 0.25)))
    sns.boxenplot(data=feature_importance_df,
                  x='feature_importance',
                  y='column',
                  order=order,
                  ax=ax,
                  palette='viridis',
                  orient='h'
                 )
    ax.tick_params(axis='x', rotation=90)
    ax.set_title('Importance')
    ax.grid()
    fig.tight_layout()
    
    return fig, ax

# %%
_ = visualize_importance(lgb_models1, df_train, 'lgb_model')

# %%
def predict_test(models, df):
    out = np.array([model.predict(df) for model in models])
    out = np.mean(out, axis=0)
    
    return out

# %%
pred_test = predict_test(lgb_models1, df_test)

# %%
y_true = target
min_values = y_true.min()
pred_test[pred_test<min_values] = min_values

# %%
#check distribution of train and test_pred data
def plot_prediction_distribution(y_true, y_pred, y_test):
    fig, ax = plt.subplots(figsize=(18, 6))
    sns.histplot(y_test, label='Test Predict', ax=ax, color='black', stat='density')
    sns.histplot(y_pred, label='Out Of Fold', ax=ax, color='C1', stat='density', alpha=0.5)
    sns.histplot(y_true, label='True Value', ax=ax, color='blue', stat='density', alpha=0.5)
    ax.legend()
    ax.grid()

# %%
plot_prediction_distribution(target, oof_valid_lgb1, pred_test)

# %%
submission = pd.read_csv(os.path.join(Input, 'submit_sample.csv'), header=None)
submission.iloc[:, 1] = pred_test
submission
# Out:
#             0           1
# 0      195942   21.547199
# 1      195943   39.394720
# 2      195944   24.892184
# 3      195945   67.757676
# 4      195946  135.137576
# ...       ...         ...
# 53504  249446   81.556498
# 53505  249447   82.594548
# 53506  249448   74.156830
# 53507  249449   34.637819
# 53508  249450   35.366496
#
# [53509 rows x 2 columns]

# %%
submission.to_csv(os.path.join(Submission, 'sub.csv'), index=False)
